# %%
from os.path import join
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from scipy.misc import imread

from datasets.visual7w.common.data_provider import getDataProvider

# %%
D = getDataProvider('visual7w-pointing',dataset_root="datasets/visual7w/datasets/visual7w-pointing/")
# Out:
# Initializing data provider for dataset visual7w-pointing...
# BasicDataProvider: reading datasets/visual7w/datasets/visual7w-pointing/dataset.json

# %%
iterator = D.iterImageQAPair(split='test')

# %%
def add_rectangle(ax, ans, color):
    ax.add_patch(patches.Rectangle((ans['x'], ans['y']),
                              ans['width'],
                              ans['height'],
                              fill=False, color=color))

# %%
for i in iterator:
    break

# %%
images_rootpath = 'datasets/visual7w/datasets/images/'
for i in iterator:
    break
image = i['image']
p = join(images_rootpath, image['filename'])
for q in image['qa_pairs']:
    answer = D.grounding_boxes[q['answer']]
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111, aspect='equal')
    add_rectangle(ax, answer,"yellow")
    for choice in q['multiple_choices']:
        ans = D.grounding_boxes[choice]
        add_rectangle(ax, ans, 'red')
    plt.imshow(imread(p))
    plt.axis('off')
    print(q['question'])
    plt.show()
# Out:
# Which area contains an L-shaped desk?
# Which box frames the bookshelf?
# Which object is hanging from the chair?
# Which is the red and blue jackets hanging on the back of the chair?
# Which desk seems rather messy?
# Which object is a living person?
# Which device is the man using?
# Which chair is covered with clothes?
# Which white computer brain is below the desk?
# Which table has a black cup sitting on it?
# Which object is hanging on the chair?

# %%
# %load_ext autoreload
# %autoreload 2
import dlib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-5d090e29e4a1> in <module>()
#       1 get_ipython().magic('load_ext autoreload')
#       2 get_ipython().magic('autoreload 2')
# ----> 3 import dlib
#
# ImportError: No module named 'dlib'

# %%
img_lbl, regions = selectivesearch.selective_search(im, scale=4, sigma=0.9, min_size=50)
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-fad5d924a440> in <module>()
# ----> 1 img_lbl, regions = selectivesearch.selective_search(im, scale=4, sigma=0.9, min_size=50)
#
# /usr/local/lib/python3.4/dist-packages/selectivesearch/selectivesearch.py in selective_search(im_orig, scale, sigma, min_size)
#     284
#     285         # get highest similarity
# --> 286         i, j = sorted(S.items(), cmp=lambda a, b: cmp(a[1], b[1]))[-1][0]
#     287
#     288         # merge corresponding regions
#
# TypeError: 'cmp' is an invalid keyword argument for this function

# %%
questions = []
iterator = D.iterQAPairs()
for i in iterator:
    questions.append(i['question'])
iterator = D.iterQAPairs('test')
for i in iterator:
    questions.append(i['question'])

# %%
words = "behind top close far left right top bottom".split()
spatial_que
questions[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-837b4ae40469> in <module>()
# ----> 1 words
#       2 questions[0]
#
# NameError: name 'words' is not defined
