# %%
from os.path import exists
from os import mkdir
from os.path import join
from PIL import Image
import json


import tensorflow as tf
import threading
import roi_pooling_op_grad
module = tf.load_op_library('/Programs/tensorflow/roi_pooling.so')
import numpy as np
import h5py

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from scipy.misc import imread, imresize

from utils import load_vocab
from time import time
import datetime


image_paths = {}
root_path = "/srv/data/datasets/mscoco/images/"

for split in 'train val'.split():
    image_ids_path = "datasets/vqa/"+split+"/img_ids.txt"
    image_ids = set([int(x.strip()) for x in open(image_ids_path).readlines()])
    print(split,len(image_ids))
    for x in image_ids:
        name = 'COCO_'+split+'2014_'+format(x, '012')+'.jpg'
        path = join(root_path,split+"2014",name)
        image_paths[x] = path
# Out:
# train 82783
# val 40504

# %%
def load_images(ps):
    tic = time()
    images = [imread(p,mode='RGB') for p in ps]
    toc = time()
    print("imread = %1.3fs" % (toc-tic))
    treated_images = []
    sizes = []
    for img in images:
        sizes.append(img.shape[:2])
        treated_img = imresize(img,(448,448),'nearest') / 255.0
        treated_images.append(treated_img)
    tic = time()
    print("Resize / scaling = %1.3fs" % (tic-toc))
    return treated_images,sizes


class Dataset(object):
    def __init__(self,h5_path,image_paths,max_q=None,max_mc=None):
        self.h5 = h5py.File(h5_path,mode='r')
        self.image_ids = self.h5['image_ids'].value
        self.questions = self.h5['questions'].value
        self.multiple_choice = self.h5['multiple_choice'].value
        self.answers = self.h5['answers'].value
        self.bounding_boxes = dict((k,v) for (k,v) in zip(self.h5['img_list'].value, 
                                                          self.h5['bounding_boxes'].value))
        self.N = len(self.image_ids)
        if max_q:
            if max_q<self.questions.shape[1]:
                self.questions = self.questions[:,:max_q]
            else:
                self.questions = np.pad(self.questions,
                                        ((0,0),(0,max_q-self.questions.shape[-1])),
                                        'constant',constant_values=a_w2i['</s>'])
        if max_mc:
            if max_mc<self.multiple_choice.shape[-1]:
                self.multiple_choice = self.multiple_choice[:,:,max_mc]
            else:
                self.multiple_choice = np.pad(self.multiple_choice,
                                              ((0,0),(0,0),(0,max_mc-self.multiple_choice.shape[-1])),
                                              'constant',constant_values=a_w2i['</s>'])
        self.max_q = self.questions.shape[1]
        self.indexes = np.arange(self.N)
        self.image_paths = image_paths
        
    def __iter__(self):
        return self
    
    def batch_gen(self,batch_size=64,shuffle=True):
        def load_image(p):
            img = imread(p,mode='RGB')
            size = img.shape[:2]
            img = imresize(img,(448,448),'nearest') / 255.0
            return img,size
        
        if shuffle:
            np.random.shuffle(self.indexes)
        n_batches = self.N // batch_size
        tiled_batch = np.arange(batch_size)[:,None]
        tiled_batch = np.tile(tiled_batch,(1,100))[:,:,None]
        load_time = 0
        for batch_id in range(n_batches):
            begin = batch_id*batch_size
            end = min((batch_id+1)*batch_size, self.N)
            idxs = self.indexes[begin:end]
            image_ids = self.image_ids[idxs]
            images,sizes = [],[]
            for i in image_ids:
                p = self.image_paths[i]
                img,size = load_image(p)
                images.append(img)
                sizes.append(size)
            images = np.stack(images)
            sizes = np.array(sizes)
            questions = self.questions[idxs]
            lengths = np.sum(np.not_equal(questions, 
                                          a_w2i['</s>']), 
                             axis=1)
            question_mask = np.zeros((self.max_q,batch_size))
            for i,q in enumerate(questions):
                question_mask[lengths[i]-1,i] = 1
            answers = self.answers[idxs]
            multiple_choice = self.multiple_choice[idxs]
            #lengths = np.sum(np.not_equal(multiple_choice,a_w2i['</s>']), axis=-1)
            #multiple_choice = multiple_choice[:,:,:lengths.max()]
            bbs = np.array([self.bounding_boxes[k] for k in image_ids])
            bbs = np.concatenate((tiled_batch,bbs),axis=-1)
            bounding_boxes = np.reshape(bbs, (bbs.shape[0]*bbs.shape[1],bbs.shape[2]))
            yield (images,questions,question_mask,answers,multiple_choice,bounding_boxes,sizes)

            
q_i2w, q_w2i = load_vocab('datasets/vqa/train/questions.vocab')
a_i2w, a_w2i = load_vocab('datasets/vqa/train/answers.vocab')
            
train_set = Dataset('datasets/vqa/train/dataset.h5',image_paths)
max_mc = train_set.multiple_choice.shape[-1]
max_q = train_set.max_q
val_set = Dataset('datasets/vqa/val/dataset.h5',image_paths,max_q=max_q,max_mc=max_mc)
Nq = len(q_i2w)
Na = len(a_i2w)

# %%
tf.reset_default_graph()
# Read the model
with open("tensorflow-vgg16/vgg16.tfmodel",
          mode='rb') as f:
    fileContent = f.read()
graph_def = tf.GraphDef()
# Put it into my graph_def
graph_def.ParseFromString(fileContent)
graph = tf.get_default_graph()

weights_names = ["import/fc6/weight:0", 
                 "import/fc7/weight:0",
                 "import/fc8/weight:0"]
biases_names = ["import/fc6/bias:0", 
                "import/fc7/bias:0",
                "import/fc8/bias:0"]
fc_shapes = [4096,4096,1000]
layer_number = 1
#di = graph.get_tensor_by_name(weights_names[layer_number-1]).get_shape()[-1].value
def pool5_tofcX(input_tensor, layer_number=layer_number):
    flatten=tf.reshape(input_tensor,(-1,7*7*512))
    tmp=flatten
    for i in range(layer_number):
        tmp=tf.matmul(tmp, graph.get_tensor_by_name(weights_names[i]))
        tmp=tf.nn.bias_add(tmp, graph.get_tensor_by_name(biases_names[i]))
        tmp = tf.nn.relu(tmp)
    return tmp

# %%
batch_size = 32
di = fc_shapes[layer_number-1]
dv = 300
dq = 300
dh = 300
datt = 300
Nq = train_set.N

Ql = {}
Ql['images'] = tf.placeholder(tf.float32, 
                              [batch_size, 448, 448, 3],
                              name="images") #batch x width x height x channels
Ql['boxes'] = tf.placeholder(tf.float32, 
                             [None,5],
                             name = "boxes")
Ql['questions'] = tf.placeholder(tf.int32, 
                                 [batch_size, max_q],
                                 name="question")
Ql['question_mask'] = tf.placeholder(tf.int32,
                                     [max_q, None],
                                     name="question_mask")
Ql['mc'] = tf.placeholder(tf.int32,
                          [batch_size, 18,None], 
                          name="mc")
Ql['answers'] = tf.placeholder(tf.float32, 
                               [batch_size,18], 
                               name="answers")

q = tf.FIFOQueue(50, [tf.float32, tf.float32, 
                       tf.int32, tf.int32, 
                       tf.int32, tf.float32], shapes=[[batch_size,448,448,3],
                                                        [batch_size*100,5],
                                                        [batch_size,max_q],
                                                        [max_q,batch_size],
                                                        [batch_size,18,max_mc],
                                                        [batch_size,18]])

enqueue_op = q.enqueue([Ql['images'], Ql['boxes'], Ql['questions'], 
                        Ql['question_mask'], Ql['mc'], Ql['answers']])
Pl = {}
Pl['images'], Pl['boxes'], Pl['questions'], Pl['question_mask'], Pl['mc'], Pl['answers'] = q.dequeue()


with tf.variable_scope('image'):
    tf.get_variable('W', shape=[di, dv],
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable(name='b',
                    initializer=tf.zeros([dv]))

with tf.variable_scope('question'):
    tf.get_variable('W',
                    initializer=tf.random_uniform([Nq, dq], -0.1, 0.1))
    
with tf.variable_scope('attention'):
    tf.get_variable('Wimg',shape=[dv,datt],
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable('Wstate',shape=[dh,datt],
                    initializer=tf.contrib.layers.xavier_initializer())
    
with tf.variable_scope('multiple_choice'):
    tf.get_variable('W',
                    initializer=tf.random_uniform([Na, dh], -0.1, 0.1))
    
with tf.variable_scope('multimodal'):
    tf.get_variable('Wv', 
                    shape = [dv,dh], 
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable(name='bv',
                    initializer=tf.zeros([dh]))
    tf.get_variable('Wq', 
                    shape = [dh,dh], 
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable(name='bq',
                    initializer=tf.zeros([dh]))
recurrent = tf.nn.rnn_cell.GRUCell(dh)

def compute_attention(V,q):
    with tf.variable_scope('attention',reuse=True):
        Wimg = tf.get_variable('Wimg')
        Wstate = tf.get_variable('Wstate')
        Vatt = tf.transpose(tf.tanh(tf.reshape(tf.matmul(tf.reshape(V, 
                                                       (batch_size*100,dv)),
                                             Wimg),
                                   (100,batch_size,datt))),(1,0,2))
        Hatt = tf.expand_dims(tf.matmul(state,Wstate),1)
        att = tf.batch_matmul(Vatt,Hatt,adj_y=True)
        patt = tf.nn.softmax(att[:,:,0])
        Vpond = tf.mul(V,tf.expand_dims(patt,-1))
        Vt = tf.reduce_sum(Vpond,reduction_indices=1)
        return Vt
    
def merge_modalities(Vatt,q_out):
    with tf.variable_scope('multimodal',reuse=True):
        Wv = tf.get_variable('Wv')
        Wq = tf.get_variable('Wq')
        bv = tf.get_variable('bv')
        bq = tf.get_variable('bq')
        
        xv = tf.nn.relu(tf.nn.xw_plus_b(Vatt,Wv,bv))
        xq = tf.nn.relu(tf.nn.xw_plus_b(q_out,Wq,bq))
        
        x = tf.tanh(xv + xq)
        return x
        
tf.import_graph_def(graph_def, 
                    input_map={'images':Pl['images']})

out_tensor = graph.get_tensor_by_name("import/conv5_3/Relu:0")
# Don't do your max pooling, but the roi_pooling
[out_pool,argmax] = module.roi_pool(out_tensor,
                                    Pl['boxes'],
                                    7,7,1.0/1) # out_pool.shape = N_Boxes x 7 x 7 x 512
boxes_emb = pool5_tofcX(out_pool,layer_number=layer_number)
with tf.variable_scope('image',reuse=True):
    W = tf.get_variable("W")
    b = tf.get_variable("b")
V = tf.tanh(tf.matmul(boxes_emb,W) + b)
V = tf.reshape(V,(batch_size,100,dv))

state = recurrent.zero_state(batch_size, tf.float32)
states = []
q_out = []
with tf.variable_scope('question',reuse=True):
    W = tf.get_variable('W')
for j in range(max_q):
    question_emb = tf.nn.embedding_lookup(W, Pl['questions'][:,j])
    if j>0:
        tf.get_variable_scope().reuse_variables()
    output,state = recurrent(question_emb, state)
    states.append(state)
    q_out.append(output)
q_out = tf.pack(q_out)
q_out = tf.reduce_sum(tf.mul(q_out, 
                             tf.to_float(tf.expand_dims(Pl['question_mask'],-1))),0)
Vatt = compute_attention(V,q_out)

x = merge_modalities(Vatt,q_out)

mc_mask = tf.to_float(tf.not_equal(Pl['mc'],a_w2i['</s>']))
norm_mask = tf.expand_dims(tf.reduce_sum(mc_mask,reduction_indices=2),-1)
with tf.variable_scope('multiple_choice'):
    W = tf.get_variable('W')
    mc_emb = tf.nn.embedding_lookup(W, Pl['mc'])
    masked_mc_out = tf.mul(tf.expand_dims(mc_mask,-1),mc_emb)
    mc_out = tf.reduce_sum(masked_mc_out,reduction_indices=2)/norm_mask
    
out_scores = tf.batch_matmul(mc_out,tf.expand_dims(x,1),adj_y=True)[:,:,0]
out_probas = tf.nn.softmax(out_scores)

normalized_ans = Pl['answers'] / tf.expand_dims(tf.reduce_sum(Pl['answers'],reduction_indices=1),-1)

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(out_scores,normalized_ans)
cost = tf.reduce_mean(cross_entropy)

optimizer = tf.train.AdamOptimizer()
#optimizer = tf.train.GradientDescentOptimizer(0.01)
gvs = optimizer.compute_gradients(cost)
# with tf.device('/cpu:0'):
cost_s = tf.scalar_summary('train loss', cost, name='train_loss')
capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad,var in gvs]
train_op = optimizer.apply_gradients(capped_gvs)

model_name = "model1"
model_rootpath = "/hhome/hbenyounes/vqa/results/vqa/"
model_path = join(model_rootpath,model_name)
if not exists(model_path):
    mkdir(model_path)

gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.9)

sess = tf.Session(config=tf.ConfigProto(log_device_placement=True,
                                        gpu_options=gpu_options))

writer = tf.train.SummaryWriter(join(model_path,'tf_log'), sess.graph)
saver = tf.train.Saver(max_to_keep=100)
init = tf.initialize_all_variables()
sess.run(init)
# Out:
# fifo_queue_Dequeue:1 (3200, 5)

# %%
def test_threading():
    accuracy = 0.
    total_time = 0
    n_batches = val_set.N//batch_size + 1
    t = threading.Thread(target=load_and_enqueue,args=(sess,enqueue_op,False,val_set))
    t.start()
    for idx in range(n_batches):
        tic = time()
        y_pred,answers = sess.run([out_probas,Pl['answers']])
        y_pred = np.argmax(y_pred,axis=1)
        accuracy += np.sum(answers[np.arange(batch_size),y_pred])
        step_time = time()-tic
        total_time += step_time
        eta = total_time*(n_batches-idx)/(idx+1)
        print("\tTest: %d/%d - accuracy = %1.3f -  ETA = %s" % (idx,
                                                                val_set.N/batch_size,
                                                                accuracy/(batch_size*(idx+1)),
                                                                datetime.timedelta(seconds=int(eta))))
    return accuracy / (batch_size*(idx+1))

def load_and_enqueue(sess,enqueue_op,shuffle,dataset):
    batch_gen = dataset.batch_gen(batch_size,shuffle)
    for (images,questions,question_mask,answers,
         multiple_choice,bounding_boxes,sizes) in batch_gen:
        feed_dict = {Ql['images']:images,
                     Ql['boxes']:bounding_boxes,
                     Ql['questions']:questions,
                     Ql['question_mask']:question_mask, 
                     Ql['answers']:answers,
                     Ql['mc']:multiple_choice}
        sess.run(enqueue_op,feed_dict=feed_dict)

# %%
n_batches = train_set.N//batch_size
n_epochs = 50
output_file = open(join(model_path,"output.txt"),'w')
best_test_acc = -1
break_all = False
for epoch in range(1,n_epochs+1):
    t = threading.Thread(target=load_and_enqueue,args=(sess,enqueue_op,True,train_set))
    t.start()
    epoch_loss = []
    total_tic = time()
    train_accuracy = 0.
    for idx in range(n_batches):
        step = idx + (epoch-1)*n_batches
        tic = time()
        _,loss_value,loss_s,y_pred,ans = sess.run([train_op,cost,cost_s,out_probas,Pl['answers']])
        writer.add_summary(loss_s,step)
        toc = time()
        step_time = toc - tic
        total_time = toc - total_tic
        eta = total_time*(n_batches-idx)/(idx+1)
        y_pred = y_pred.argmax(axis=1)
        train_accuracy += np.sum(ans[np.arange(batch_size),y_pred])
        print("Epoch %d/%d - batch %d/%d - loss = %1.3f - accuracy = %1.3f - " \
        "elapsed = %1s - ETA = %s" % (epoch,n_epochs,
                                          idx,n_batches,
                                          loss_value,train_accuracy/(batch_size*(idx+1)),
                                          str(datetime.timedelta(seconds=int(total_time))),
                                          str(datetime.timedelta(seconds=int(eta)))))
        epoch_loss.append(loss_value)
        if np.isnan(loss_value):
            print("Loss is nan, i get out")
            break_all = True
        if break_all:
            break
    if break_all:
        break
    train_accuracy = train_accuracy / (batch_size*(idx+1))
    train_loss = np.mean(epoch_loss)
    output_file.write("Epoch %d - \n\ttrain loss = %1.3f - train accuracy = %1.3f\n" % (epoch,train_loss,train_accuracy))
    output_file.flush()
    print("test")
    if not epoch%5:
        test_acc = test_threading()
        if test_acc > best_test_acc:
            print("Saving model...")
            saver.save(sess, join(model_path,'model'), global_step=epoch)
        output_file.write('\ttest accuracy = %1.3f\n' % test_acc)
        output_file.flush()
        best_test_acc = max(best_test_acc,test_acc)
output_file.close()
# Out:
# Epoch 1/50 - batch 0/7760 - loss = 2.593 - accuracy = 0.250 - elapsed = 0:00:01 - ETA = 2:28:05
# Epoch 1/50 - batch 1/7760 - loss = 2.540 - accuracy = 0.281 - elapsed = 0:00:02 - ETA = 2:27:58
# Epoch 1/50 - batch 2/7760 - loss = 2.670 - accuracy = 0.260 - elapsed = 0:00:03 - ETA = 2:27:56
# Epoch 1/50 - batch 3/7760 - loss = 2.432 - accuracy = 0.273 - elapsed = 0:00:04 - ETA = 2:27:42
# Epoch 1/50 - batch 4/7760 - loss = 2.272 - accuracy = 0.287 - elapsed = 0:00:05 - ETA = 2:27:07
# Epoch 1/50 - batch 5/7760 - loss = 2.302 - accuracy = 0.312 - elapsed = 0:00:06 - ETA = 2:27:17
# Epoch 1/50 - batch 6/7760 - loss = 2.579 - accuracy = 0.295 - elapsed = 0:00:07 - ETA = 2:26:54
# Epoch 1/50 - batch 7/7760 - loss = 2.609 - accuracy = 0.289 - elapsed = 0:00:09 - ETA = 2:26:50
# Epoch 1/50 - batch 8/7760 - loss = 2.465 - accuracy = 0.288 - elapsed = 0:00:10 - ETA = 2:26:38
# Epoch 1/50 - batch 9/7760 - loss = 2.489 - accuracy = 0.278 - elapsed = 0:00:11 - ETA = 2:26:24
# Epoch 1/50 - batch 10/7760 - loss = 2.455 - accuracy = 0.278 - elapsed = 0:00:12 - ETA = 2:26:29
# Epoch 1/50 - batch 11/7760 - loss = 2.611 - accuracy = 0.271 - elapsed = 0:00:13 - ETA = 2:26:23
# Epoch 1/50 - batch 12/7760 - loss = 2.575 - accuracy = 0.267 - elapsed = 0:00:14 - ETA = 2:26:14
# Epoch 1/50 - batch 13/7760 - loss = 2.648 - accuracy = 0.261 - elapsed = 0:00:15 - ETA = 2:26:18
# Epoch 1/50 - batch 14/7760 - loss = 2.473 - accuracy = 0.256 - elapsed = 0:00:17 - ETA = 2:26:21
# Epoch 1/50 - batch 15/7760 - loss = 2.150 - accuracy = 0.262 - elapsed = 0:00:18 - ETA = 2:26:22
# Epoch 1/50 - batch 16/7760 - loss = 2.522 - accuracy = 0.257 - elapsed = 0:00:19 - ETA = 2:26:29
# Epoch 1/50 - batch 17/7760 - loss = 2.276 - accuracy = 0.259 - elapsed = 0:00:20 - ETA = 2:26:33
# Epoch 1/50 - batch 18/7760 - loss = 1.961 - accuracy = 0.265 - elapsed = 0:00:21 - ETA = 2:26:37
# Epoch 1/50 - batch 19/7760 - loss = 2.355 - accuracy = 0.267 - elapsed = 0:00:22 - ETA = 2:26:32
# Epoch 1/50 - batch 20/7760 - loss = 2.152 - accuracy = 0.272 - elapsed = 0:00:23 - ETA = 2:26:34
# Epoch 1/50 - batch 21/7760 - loss = 2.272 - accuracy = 0.276 - elapsed = 0:00:25 - ETA = 2:26:35
# Epoch 1/50 - batch 22/7760 - loss = 2.409 - accuracy = 0.273 - elapsed = 0:00:26 - ETA = 2:26:38
# Epoch 1/50 - batch 23/7760 - loss = 2.335 - accuracy = 0.272 - elapsed = 0:00:27 - ETA = 2:26:34
# Epoch 1/50 - batch 24/7760 - loss = 1.911 - accuracy = 0.280 - elapsed = 0:00:28 - ETA = 2:26:31
# Epoch 1/50 - batch 25/7760 - loss = 2.666 - accuracy = 0.274 - elapsed = 0:00:29 - ETA = 2:26:28
# Epoch 1/50 - batch 26/7760 - loss = 2.391 - accuracy = 0.272 - elapsed = 0:00:30 - ETA = 2:26:31
# Epoch 1/50 - batch 27/7760 - loss = 1.621 - accuracy = 0.276 - elapsed = 0:00:31 - ETA = 2:26:31
# Epoch 1/50 - batch 28/7760 - loss = 1.836 - accuracy = 0.280 - elapsed = 0:00:32 - ETA = 2:26:33
# Epoch 1/50 - batch 29/7760 - loss = 1.952 - accuracy = 0.281 - elapsed = 0:00:34 - ETA = 2:26:29
# Epoch 1/50 - batch 30/7760 - loss = 1.648 - accuracy = 0.283 - elapsed = 0:00:35 - ETA = 2:26:30
# Epoch 1/50 - batch 31/7760 - loss = 1.922 - accuracy = 0.286 - elapsed = 0:00:36 - ETA = 2:26:29
# Epoch 1/50 - batch 32/7760 - loss = 2.106 - accuracy = 0.284 - elapsed = 0:00:37 - ETA = 2:26:30
# Epoch 1/50 - batch 33/7760 - loss = 2.205 - accuracy = 0.283 - elapsed = 0:00:38 - ETA = 2:26:26
# Epoch 1/50 - batch 34/7760 - loss = 1.858 - accuracy = 0.281 - elapsed = 0:00:39 - ETA = 2:26:28
# Epoch 1/50 - batch 35/7760 - loss = 2.087 - accuracy = 0.284 - elapsed = 0:00:40 - ETA = 2:26:30
# Epoch 1/50 - batch 36/7760 - loss = 2.189 - accuracy = 0.282 - elapsed = 0:00:42 - ETA = 2:26:31
# Epoch 1/50 - batch 37/7760 - loss = 1.997 - accuracy = 0.285 - elapsed = 0:00:43 - ETA = 2:26:26
# Epoch 1/50 - batch 38/7760 - loss = 2.105 - accuracy = 0.283 - elapsed = 0:00:44 - ETA = 2:26:27
# Epoch 1/50 - batch 39/7760 - loss = 1.770 - accuracy = 0.285 - elapsed = 0:00:45 - ETA = 2:26:28
# Epoch 1/50 - batch 40/7760 - loss = 2.060 - accuracy = 0.287 - elapsed = 0:00:46 - ETA = 2:26:27
# Epoch 1/50 - batch 41/7760 - loss = 2.175 - accuracy = 0.286 - elapsed = 0:00:47 - ETA = 2:26:34
# Epoch 1/50 - batch 42/7760 - loss = 1.947 - accuracy = 0.286 - elapsed = 0:00:49 - ETA = 2:26:41
# Epoch 1/50 - batch 43/7760 - loss = 1.640 - accuracy = 0.288 - elapsed = 0:00:50 - ETA = 2:26:48
# Epoch 1/50 - batch 44/7760 - loss = 2.046 - accuracy = 0.288 - elapsed = 0:00:51 - ETA = 2:26:54
# Epoch 1/50 - batch 45/7760 - loss = 1.829 - accuracy = 0.291 - elapsed = 0:00:52 - ETA = 2:26:58
# Epoch 1/50 - batch 46/7760 - loss = 2.113 - accuracy = 0.291 - elapsed = 0:00:53 - ETA = 2:27:05
# Epoch 1/50 - batch 47/7760 - loss = 1.980 - accuracy = 0.292 - elapsed = 0:00:54 - ETA = 2:27:07
# Epoch 1/50 - batch 48/7760 - loss = 1.558 - accuracy = 0.297 - elapsed = 0:00:56 - ETA = 2:27:10
# Epoch 1/50 - batch 49/7760 - loss = 1.864 - accuracy = 0.297 - elapsed = 0:00:57 - ETA = 2:27:15
# Epoch 1/50 - batch 50/7760 - loss = 1.651 - accuracy = 0.301 - elapsed = 0:00:58 - ETA = 2:27:20
# Epoch 1/50 - batch 51/7760 - loss = 1.870 - accuracy = 0.305 - elapsed = 0:00:59 - ETA = 2:27:25
# Epoch 1/50 - batch 52/7760 - loss = 2.140 - accuracy = 0.302 - elapsed = 0:01:00 - ETA = 2:27:27
# Epoch 1/50 - batch 53/7760 - loss = 1.948 - accuracy = 0.303 - elapsed = 0:01:01 - ETA = 2:27:28
# Epoch 1/50 - batch 54/7760 - loss = 1.520 - accuracy = 0.306 - elapsed = 0:01:03 - ETA = 2:27:30
# Epoch 1/50 - batch 55/7760 - loss = 2.019 - accuracy = 0.307 - elapsed = 0:01:04 - ETA = 2:27:31
# Epoch 1/50 - batch 56/7760 - loss = 1.976 - accuracy = 0.307 - elapsed = 0:01:05 - ETA = 2:27:34
# Epoch 1/50 - batch 57/7760 - loss = 1.814 - accuracy = 0.309 - elapsed = 0:01:06 - ETA = 2:27:34
# Epoch 1/50 - batch 58/7760 - loss = 1.925 - accuracy = 0.310 - elapsed = 0:01:07 - ETA = 2:27:34
# Epoch 1/50 - batch 59/7760 - loss = 2.353 - accuracy = 0.309 - elapsed = 0:01:08 - ETA = 2:27:35
# Epoch 1/50 - batch 60/7760 - loss = 2.073 - accuracy = 0.311 - elapsed = 0:01:10 - ETA = 2:27:37
# Epoch 1/50 - batch 61/7760 - loss = 1.544 - accuracy = 0.312 - elapsed = 0:01:11 - ETA = 2:27:40
# Epoch 1/50 - batch 62/7760 - loss = 1.312 - accuracy = 0.313 - elapsed = 0:01:12 - ETA = 2:27:42
# Epoch 1/50 - batch 63/7760 - loss = 2.051 - accuracy = 0.314 - elapsed = 0:01:13 - ETA = 2:27:44
# Epoch 1/50 - batch 64/7760 - loss = 1.967 - accuracy = 0.313 - elapsed = 0:01:14 - ETA = 2:27:45
# Epoch 1/50 - batch 65/7760 - loss = 2.003 - accuracy = 0.314 - elapsed = 0:01:16 - ETA = 2:27:48
# Epoch 1/50 - batch 66/7760 - loss = 1.801 - accuracy = 0.316 - elapsed = 0:01:17 - ETA = 2:27:48
# Epoch 1/50 - batch 67/7760 - loss = 1.737 - accuracy = 0.318 - elapsed = 0:01:18 - ETA = 2:27:50
# Epoch 1/50 - batch 68/7760 - loss = 1.767 - accuracy = 0.319 - elapsed = 0:01:19 - ETA = 2:27:50
# Epoch 1/50 - batch 69/7760 - loss = 1.739 - accuracy = 0.320 - elapsed = 0:01:20 - ETA = 2:27:51
# Epoch 1/50 - batch 70/7760 - loss = 1.845 - accuracy = 0.320 - elapsed = 0:01:21 - ETA = 2:27:52
# Epoch 1/50 - batch 71/7760 - loss = 1.406 - accuracy = 0.321 - elapsed = 0:01:23 - ETA = 2:27:53
# Epoch 1/50 - batch 72/7760 - loss = 1.918 - accuracy = 0.321 - elapsed = 0:01:24 - ETA = 2:27:52
# Epoch 1/50 - batch 73/7760 - loss = 1.734 - accuracy = 0.322 - elapsed = 0:01:25 - ETA = 2:27:52
# Epoch 1/50 - batch 74/7760 - loss = 1.869 - accuracy = 0.323 - elapsed = 0:01:26 - ETA = 2:27:53
# Epoch 1/50 - batch 75/7760 - loss = 1.610 - accuracy = 0.324 - elapsed = 0:01:27 - ETA = 2:27:54
# Epoch 1/50 - batch 76/7760 - loss = 1.851 - accuracy = 0.325 - elapsed = 0:01:28 - ETA = 2:27:54
# Epoch 1/50 - batch 77/7760 - loss = 1.704 - accuracy = 0.325 - elapsed = 0:01:30 - ETA = 2:27:53
# Epoch 1/50 - batch 78/7760 - loss = 1.853 - accuracy = 0.323 - elapsed = 0:01:31 - ETA = 2:27:50
# Epoch 1/50 - batch 79/7760 - loss = 1.975 - accuracy = 0.325 - elapsed = 0:01:32 - ETA = 2:27:48
# Epoch 1/50 - batch 80/7760 - loss = 1.748 - accuracy = 0.324 - elapsed = 0:01:33 - ETA = 2:27:46
# Epoch 1/50 - batch 81/7760 - loss = 1.877 - accuracy = 0.322 - elapsed = 0:01:34 - ETA = 2:27:46
# Epoch 1/50 - batch 82/7760 - loss = 1.624 - accuracy = 0.324 - elapsed = 0:01:35 - ETA = 2:27:45
# Epoch 1/50 - batch 83/7760 - loss = 1.680 - accuracy = 0.325 - elapsed = 0:01:36 - ETA = 2:27:43
# Epoch 1/50 - batch 84/7760 - loss = 2.216 - accuracy = 0.324 - elapsed = 0:01:38 - ETA = 2:27:42
# Epoch 1/50 - batch 85/7760 - loss = 1.820 - accuracy = 0.324 - elapsed = 0:01:39 - ETA = 2:27:41
# Epoch 1/50 - batch 86/7760 - loss = 1.917 - accuracy = 0.325 - elapsed = 0:01:40 - ETA = 2:27:39
# Epoch 1/50 - batch 87/7760 - loss = 1.869 - accuracy = 0.325 - elapsed = 0:01:41 - ETA = 2:27:38
# Epoch 1/50 - batch 88/7760 - loss = 2.130 - accuracy = 0.324 - elapsed = 0:01:42 - ETA = 2:27:37
# Epoch 1/50 - batch 89/7760 - loss = 1.474 - accuracy = 0.326 - elapsed = 0:01:43 - ETA = 2:27:38
# Epoch 1/50 - batch 90/7760 - loss = 1.947 - accuracy = 0.326 - elapsed = 0:01:45 - ETA = 2:27:37
# Epoch 1/50 - batch 91/7760 - loss = 2.027 - accuracy = 0.326 - elapsed = 0:01:46 - ETA = 2:27:39
# Epoch 1/50 - batch 92/7760 - loss = 1.688 - accuracy = 0.326 - elapsed = 0:01:47 - ETA = 2:27:38
# Epoch 1/50 - batch 93/7760 - loss = 1.622 - accuracy = 0.326 - elapsed = 0:01:48 - ETA = 2:27:36
# Epoch 1/50 - batch 94/7760 - loss = 1.598 - accuracy = 0.326 - elapsed = 0:01:49 - ETA = 2:27:35
# Epoch 1/50 - batch 95/7760 - loss = 1.546 - accuracy = 0.326 - elapsed = 0:01:50 - ETA = 2:27:36
# Epoch 1/50 - batch 96/7760 - loss = 1.788 - accuracy = 0.327 - elapsed = 0:01:52 - ETA = 2:27:36
# Epoch 1/50 - batch 97/7760 - loss = 1.437 - accuracy = 0.328 - elapsed = 0:01:53 - ETA = 2:27:36
# Epoch 1/50 - batch 98/7760 - loss = 1.999 - accuracy = 0.327 - elapsed = 0:01:54 - ETA = 2:27:36
# Epoch 1/50 - batch 99/7760 - loss = 1.647 - accuracy = 0.328 - elapsed = 0:01:55 - ETA = 2:27:37
# Epoch 1/50 - batch 100/7760 - loss = 1.669 - accuracy = 0.329 - elapsed = 0:01:56 - ETA = 2:27:37
# Epoch 1/50 - batch 101/7760 - loss = 1.949 - accuracy = 0.329 - elapsed = 0:01:57 - ETA = 2:27:37
# Epoch 1/50 - batch 102/7760 - loss = 1.858 - accuracy = 0.330 - elapsed = 0:01:59 - ETA = 2:27:37
# Epoch 1/50 - batch 103/7760 - loss = 1.863 - accuracy = 0.331 - elapsed = 0:02:00 - ETA = 2:27:37
# Epoch 1/50 - batch 104/7760 - loss = 1.840 - accuracy = 0.330 - elapsed = 0:02:01 - ETA = 2:27:36
# Epoch 1/50 - batch 105/7760 - loss = 1.728 - accuracy = 0.331 - elapsed = 0:02:02 - ETA = 2:27:36
# Epoch 1/50 - batch 106/7760 - loss = 1.366 - accuracy = 0.332 - elapsed = 0:02:03 - ETA = 2:27:36
# Epoch 1/50 - batch 107/7760 - loss = 1.573 - accuracy = 0.333 - elapsed = 0:02:04 - ETA = 2:27:36
# Epoch 1/50 - batch 108/7760 - loss = 1.620 - accuracy = 0.334 - elapsed = 0:02:06 - ETA = 2:27:35
# Epoch 1/50 - batch 109/7760 - loss = 1.367 - accuracy = 0.335 - elapsed = 0:02:07 - ETA = 2:27:34
# Epoch 1/50 - batch 110/7760 - loss = 2.401 - accuracy = 0.334 - elapsed = 0:02:08 - ETA = 2:27:35
# Epoch 1/50 - batch 111/7760 - loss = 1.588 - accuracy = 0.335 - elapsed = 0:02:09 - ETA = 2:27:35
# Epoch 1/50 - batch 112/7760 - loss = 2.009 - accuracy = 0.335 - elapsed = 0:02:10 - ETA = 2:27:34
# Epoch 1/50 - batch 113/7760 - loss = 1.677 - accuracy = 0.335 - elapsed = 0:02:12 - ETA = 2:27:34
# Epoch 1/50 - batch 114/7760 - loss = 1.830 - accuracy = 0.337 - elapsed = 0:02:13 - ETA = 2:27:33
# Epoch 1/50 - batch 115/7760 - loss = 1.523 - accuracy = 0.337 - elapsed = 0:02:14 - ETA = 2:27:32
# Epoch 1/50 - batch 116/7760 - loss = 1.999 - accuracy = 0.337 - elapsed = 0:02:15 - ETA = 2:27:30
# Epoch 1/50 - batch 117/7760 - loss = 1.710 - accuracy = 0.337 - elapsed = 0:02:16 - ETA = 2:27:29
# Epoch 1/50 - batch 118/7760 - loss = 1.594 - accuracy = 0.338 - elapsed = 0:02:17 - ETA = 2:27:30
# Epoch 1/50 - batch 119/7760 - loss = 1.590 - accuracy = 0.338 - elapsed = 0:02:18 - ETA = 2:27:29
# Epoch 1/50 - batch 120/7760 - loss = 1.969 - accuracy = 0.338 - elapsed = 0:02:20 - ETA = 2:27:28
# Epoch 1/50 - batch 121/7760 - loss = 1.203 - accuracy = 0.339 - elapsed = 0:02:21 - ETA = 2:27:27
# Epoch 1/50 - batch 122/7760 - loss = 1.795 - accuracy = 0.339 - elapsed = 0:02:22 - ETA = 2:27:26
# Epoch 1/50 - batch 123/7760 - loss = 2.033 - accuracy = 0.338 - elapsed = 0:02:23 - ETA = 2:27:25
# Epoch 1/50 - batch 124/7760 - loss = 1.533 - accuracy = 0.339 - elapsed = 0:02:24 - ETA = 2:27:25
# Epoch 1/50 - batch 125/7760 - loss = 1.390 - accuracy = 0.340 - elapsed = 0:02:25 - ETA = 2:27:25
# Epoch 1/50 - batch 126/7760 - loss = 1.786 - accuracy = 0.339 - elapsed = 0:02:27 - ETA = 2:27:25
# Epoch 1/50 - batch 127/7760 - loss = 1.837 - accuracy = 0.339 - elapsed = 0:02:28 - ETA = 2:27:25
# Epoch 1/50 - batch 128/7760 - loss = 1.425 - accuracy = 0.338 - elapsed = 0:02:29 - ETA = 2:27:25
# Epoch 1/50 - batch 129/7760 - loss = 1.948 - accuracy = 0.338 - elapsed = 0:02:30 - ETA = 2:27:24
# Epoch 1/50 - batch 130/7760 - loss = 1.580 - accuracy = 0.338 - elapsed = 0:02:31 - ETA = 2:27:23
# Epoch 1/50 - batch 131/7760 - loss = 1.889 - accuracy = 0.336 - elapsed = 0:02:32 - ETA = 2:27:22
# Epoch 1/50 - batch 132/7760 - loss = 1.622 - accuracy = 0.336 - elapsed = 0:02:34 - ETA = 2:27:22
# Epoch 1/50 - batch 133/7760 - loss = 1.220 - accuracy = 0.337 - elapsed = 0:02:35 - ETA = 2:27:20
# Epoch 1/50 - batch 134/7760 - loss = 1.663 - accuracy = 0.337 - elapsed = 0:02:36 - ETA = 2:27:20
# Epoch 1/50 - batch 135/7760 - loss = 1.748 - accuracy = 0.336 - elapsed = 0:02:37 - ETA = 2:27:19
# Epoch 1/50 - batch 136/7760 - loss = 1.684 - accuracy = 0.336 - elapsed = 0:02:38 - ETA = 2:27:18
# Epoch 1/50 - batch 137/7760 - loss = 1.822 - accuracy = 0.337 - elapsed = 0:02:39 - ETA = 2:27:17
# Epoch 1/50 - batch 138/7760 - loss = 1.613 - accuracy = 0.338 - elapsed = 0:02:41 - ETA = 2:27:16
# Epoch 1/50 - batch 139/7760 - loss = 1.664 - accuracy = 0.339 - elapsed = 0:02:42 - ETA = 2:27:16
# Epoch 1/50 - batch 140/7760 - loss = 1.381 - accuracy = 0.340 - elapsed = 0:02:43 - ETA = 2:27:16
# Epoch 1/50 - batch 141/7760 - loss = 1.695 - accuracy = 0.340 - elapsed = 0:02:44 - ETA = 2:27:15
# Epoch 1/50 - batch 142/7760 - loss = 1.813 - accuracy = 0.340 - elapsed = 0:02:45 - ETA = 2:27:15
# Epoch 1/50 - batch 143/7760 - loss = 1.573 - accuracy = 0.340 - elapsed = 0:02:47 - ETA = 2:27:15
# Epoch 1/50 - batch 144/7760 - loss = 1.808 - accuracy = 0.340 - elapsed = 0:02:48 - ETA = 2:27:13
# Epoch 1/50 - batch 145/7760 - loss = 1.506 - accuracy = 0.340 - elapsed = 0:02:49 - ETA = 2:27:13
# Epoch 1/50 - batch 146/7760 - loss = 1.860 - accuracy = 0.340 - elapsed = 0:02:50 - ETA = 2:27:13
# Epoch 1/50 - batch 147/7760 - loss = 1.363 - accuracy = 0.341 - elapsed = 0:02:51 - ETA = 2:27:12
# Epoch 1/50 - batch 148/7760 - loss = 1.562 - accuracy = 0.342 - elapsed = 0:02:52 - ETA = 2:27:12
# Epoch 1/50 - batch 149/7760 - loss = 1.608 - accuracy = 0.342 - elapsed = 0:02:54 - ETA = 2:27:11
# Epoch 1/50 - batch 150/7760 - loss = 1.560 - accuracy = 0.341 - elapsed = 0:02:55 - ETA = 2:27:10
# Epoch 1/50 - batch 151/7760 - loss = 1.520 - accuracy = 0.340 - elapsed = 0:02:56 - ETA = 2:27:08
# Epoch 1/50 - batch 152/7760 - loss = 1.941 - accuracy = 0.339 - elapsed = 0:02:57 - ETA = 2:27:07
# Epoch 1/50 - batch 153/7760 - loss = 1.592 - accuracy = 0.339 - elapsed = 0:02:58 - ETA = 2:27:05
# Epoch 1/50 - batch 154/7760 - loss = 1.881 - accuracy = 0.339 - elapsed = 0:02:59 - ETA = 2:27:04
# Epoch 1/50 - batch 155/7760 - loss = 1.410 - accuracy = 0.339 - elapsed = 0:03:01 - ETA = 2:27:04
# Epoch 1/50 - batch 156/7760 - loss = 1.778 - accuracy = 0.338 - elapsed = 0:03:02 - ETA = 2:27:03
# Epoch 1/50 - batch 157/7760 - loss = 1.864 - accuracy = 0.338 - elapsed = 0:03:03 - ETA = 2:27:02
# Epoch 1/50 - batch 158/7760 - loss = 2.072 - accuracy = 0.338 - elapsed = 0:03:04 - ETA = 2:27:01
# Epoch 1/50 - batch 159/7760 - loss = 1.707 - accuracy = 0.338 - elapsed = 0:03:05 - ETA = 2:27:00
# Epoch 1/50 - batch 160/7760 - loss = 1.740 - accuracy = 0.338 - elapsed = 0:03:06 - ETA = 2:27:00
# Epoch 1/50 - batch 161/7760 - loss = 1.371 - accuracy = 0.340 - elapsed = 0:03:07 - ETA = 2:26:58
# Epoch 1/50 - batch 162/7760 - loss = 1.497 - accuracy = 0.340 - elapsed = 0:03:09 - ETA = 2:26:57
# Epoch 1/50 - batch 163/7760 - loss = 1.559 - accuracy = 0.341 - elapsed = 0:03:10 - ETA = 2:26:55
# Epoch 1/50 - batch 164/7760 - loss = 1.528 - accuracy = 0.341 - elapsed = 0:03:11 - ETA = 2:26:55
# Epoch 1/50 - batch 165/7760 - loss = 1.504 - accuracy = 0.341 - elapsed = 0:03:12 - ETA = 2:26:54
# Epoch 1/50 - batch 166/7760 - loss = 1.697 - accuracy = 0.342 - elapsed = 0:03:13 - ETA = 2:26:53
# Epoch 1/50 - batch 167/7760 - loss = 1.728 - accuracy = 0.342 - elapsed = 0:03:14 - ETA = 2:26:53
# Epoch 1/50 - batch 168/7760 - loss = 1.308 - accuracy = 0.343 - elapsed = 0:03:16 - ETA = 2:26:52
# Epoch 1/50 - batch 169/7760 - loss = 1.874 - accuracy = 0.342 - elapsed = 0:03:17 - ETA = 2:26:50
# Epoch 1/50 - batch 170/7760 - loss = 1.457 - accuracy = 0.342 - elapsed = 0:03:18 - ETA = 2:26:50
# Epoch 1/50 - batch 171/7760 - loss = 1.476 - accuracy = 0.343 - elapsed = 0:03:19 - ETA = 2:26:49
# Epoch 1/50 - batch 172/7760 - loss = 1.532 - accuracy = 0.343 - elapsed = 0:03:20 - ETA = 2:26:47
# Epoch 1/50 - batch 173/7760 - loss = 1.568 - accuracy = 0.344 - elapsed = 0:03:21 - ETA = 2:26:46
# Epoch 1/50 - batch 174/7760 - loss = 1.905 - accuracy = 0.343 - elapsed = 0:03:23 - ETA = 2:26:45
# Epoch 1/50 - batch 175/7760 - loss = 1.696 - accuracy = 0.343 - elapsed = 0:03:24 - ETA = 2:26:44
# Epoch 1/50 - batch 176/7760 - loss = 1.735 - accuracy = 0.344 - elapsed = 0:03:25 - ETA = 2:26:43
# Epoch 1/50 - batch 177/7760 - loss = 1.313 - accuracy = 0.344 - elapsed = 0:03:26 - ETA = 2:26:42
# Epoch 1/50 - batch 178/7760 - loss = 1.707 - accuracy = 0.344 - elapsed = 0:03:27 - ETA = 2:26:41
# Epoch 1/50 - batch 179/7760 - loss = 1.436 - accuracy = 0.346 - elapsed = 0:03:28 - ETA = 2:26:40
# Epoch 1/50 - batch 180/7760 - loss = 1.619 - accuracy = 0.346 - elapsed = 0:03:30 - ETA = 2:26:39
# Epoch 1/50 - batch 181/7760 - loss = 1.900 - accuracy = 0.346 - elapsed = 0:03:31 - ETA = 2:26:39
# Epoch 1/50 - batch 182/7760 - loss = 1.626 - accuracy = 0.346 - elapsed = 0:03:32 - ETA = 2:26:38
# Epoch 1/50 - batch 183/7760 - loss = 1.749 - accuracy = 0.346 - elapsed = 0:03:33 - ETA = 2:26:37
# Epoch 1/50 - batch 184/7760 - loss = 1.887 - accuracy = 0.345 - elapsed = 0:03:34 - ETA = 2:26:37
# Epoch 1/50 - batch 185/7760 - loss = 1.545 - accuracy = 0.346 - elapsed = 0:03:35 - ETA = 2:26:36
# Epoch 1/50 - batch 186/7760 - loss = 1.495 - accuracy = 0.347 - elapsed = 0:03:37 - ETA = 2:26:35
# Epoch 1/50 - batch 187/7760 - loss = 1.733 - accuracy = 0.346 - elapsed = 0:03:38 - ETA = 2:26:34
# Epoch 1/50 - batch 188/7760 - loss = 1.953 - accuracy = 0.345 - elapsed = 0:03:39 - ETA = 2:26:32
# Epoch 1/50 - batch 189/7760 - loss = 1.379 - accuracy = 0.346 - elapsed = 0:03:40 - ETA = 2:26:31
# Epoch 1/50 - batch 190/7760 - loss = 1.727 - accuracy = 0.346 - elapsed = 0:03:41 - ETA = 2:26:29
# Epoch 1/50 - batch 191/7760 - loss = 1.655 - accuracy = 0.346 - elapsed = 0:03:42 - ETA = 2:26:28
# Epoch 1/50 - batch 192/7760 - loss = 1.527 - accuracy = 0.346 - elapsed = 0:03:44 - ETA = 2:26:27
# Epoch 1/50 - batch 193/7760 - loss = 1.528 - accuracy = 0.346 - elapsed = 0:03:45 - ETA = 2:26:26
# Epoch 1/50 - batch 194/7760 - loss = 1.721 - accuracy = 0.346 - elapsed = 0:03:46 - ETA = 2:26:26
# Epoch 1/50 - batch 195/7760 - loss = 1.400 - accuracy = 0.346 - elapsed = 0:03:47 - ETA = 2:26:25
# Epoch 1/50 - batch 196/7760 - loss = 1.570 - accuracy = 0.347 - elapsed = 0:03:48 - ETA = 2:26:23
# Epoch 1/50 - batch 197/7760 - loss = 1.609 - accuracy = 0.347 - elapsed = 0:03:49 - ETA = 2:26:22
# Epoch 1/50 - batch 198/7760 - loss = 1.461 - accuracy = 0.347 - elapsed = 0:03:51 - ETA = 2:26:20
# Epoch 1/50 - batch 199/7760 - loss = 1.391 - accuracy = 0.347 - elapsed = 0:03:52 - ETA = 2:26:18
# Epoch 1/50 - batch 200/7760 - loss = 1.537 - accuracy = 0.346 - elapsed = 0:03:53 - ETA = 2:26:17
# Epoch 1/50 - batch 201/7760 - loss = 1.350 - accuracy = 0.347 - elapsed = 0:03:54 - ETA = 2:26:15
# Epoch 1/50 - batch 202/7760 - loss = 1.569 - accuracy = 0.347 - elapsed = 0:03:55 - ETA = 2:26:15
# Epoch 1/50 - batch 203/7760 - loss = 1.463 - accuracy = 0.347 - elapsed = 0:03:56 - ETA = 2:26:14
# Epoch 1/50 - batch 204/7760 - loss = 1.210 - accuracy = 0.348 - elapsed = 0:03:58 - ETA = 2:26:13
# Epoch 1/50 - batch 205/7760 - loss = 1.592 - accuracy = 0.348 - elapsed = 0:03:59 - ETA = 2:26:11
# Epoch 1/50 - batch 206/7760 - loss = 1.468 - accuracy = 0.348 - elapsed = 0:04:00 - ETA = 2:26:10
# Epoch 1/50 - batch 207/7760 - loss = 1.536 - accuracy = 0.348 - elapsed = 0:04:01 - ETA = 2:26:09
# Epoch 1/50 - batch 208/7760 - loss = 1.981 - accuracy = 0.348 - elapsed = 0:04:02 - ETA = 2:26:08
# Epoch 1/50 - batch 209/7760 - loss = 1.491 - accuracy = 0.349 - elapsed = 0:04:03 - ETA = 2:26:08
# Epoch 1/50 - batch 210/7760 - loss = 1.575 - accuracy = 0.349 - elapsed = 0:04:05 - ETA = 2:26:07
# Epoch 1/50 - batch 211/7760 - loss = 1.194 - accuracy = 0.349 - elapsed = 0:04:06 - ETA = 2:26:07
# Epoch 1/50 - batch 212/7760 - loss = 1.300 - accuracy = 0.350 - elapsed = 0:04:07 - ETA = 2:26:07
# Epoch 1/50 - batch 213/7760 - loss = 1.641 - accuracy = 0.350 - elapsed = 0:04:08 - ETA = 2:26:05
# Epoch 1/50 - batch 214/7760 - loss = 1.375 - accuracy = 0.350 - elapsed = 0:04:09 - ETA = 2:26:05
# Epoch 1/50 - batch 215/7760 - loss = 1.476 - accuracy = 0.350 - elapsed = 0:04:10 - ETA = 2:26:04
# Epoch 1/50 - batch 216/7760 - loss = 1.460 - accuracy = 0.351 - elapsed = 0:04:12 - ETA = 2:26:03
# Epoch 1/50 - batch 217/7760 - loss = 1.711 - accuracy = 0.350 - elapsed = 0:04:13 - ETA = 2:26:01
# Epoch 1/50 - batch 218/7760 - loss = 1.574 - accuracy = 0.351 - elapsed = 0:04:14 - ETA = 2:26:00
# Epoch 1/50 - batch 219/7760 - loss = 1.409 - accuracy = 0.351 - elapsed = 0:04:15 - ETA = 2:25:58
# Epoch 1/50 - batch 220/7760 - loss = 1.709 - accuracy = 0.351 - elapsed = 0:04:16 - ETA = 2:25:58
# Epoch 1/50 - batch 221/7760 - loss = 1.375 - accuracy = 0.351 - elapsed = 0:04:17 - ETA = 2:25:56
# Epoch 1/50 - batch 222/7760 - loss = 1.502 - accuracy = 0.352 - elapsed = 0:04:19 - ETA = 2:25:55
# Epoch 1/50 - batch 223/7760 - loss = 1.871 - accuracy = 0.351 - elapsed = 0:04:20 - ETA = 2:25:54
# Epoch 1/50 - batch 224/7760 - loss = 1.751 - accuracy = 0.351 - elapsed = 0:04:21 - ETA = 2:25:53
# Epoch 1/50 - batch 225/7760 - loss = 1.769 - accuracy = 0.351 - elapsed = 0:04:22 - ETA = 2:25:51
# Epoch 1/50 - batch 226/7760 - loss = 1.722 - accuracy = 0.352 - elapsed = 0:04:23 - ETA = 2:25:50
# Epoch 1/50 - batch 227/7760 - loss = 1.556 - accuracy = 0.352 - elapsed = 0:04:24 - ETA = 2:25:49
# Epoch 1/50 - batch 228/7760 - loss = 1.290 - accuracy = 0.352 - elapsed = 0:04:25 - ETA = 2:25:48
# Epoch 1/50 - batch 229/7760 - loss = 1.907 - accuracy = 0.352 - elapsed = 0:04:27 - ETA = 2:25:47
# Epoch 1/50 - batch 230/7760 - loss = 1.336 - accuracy = 0.353 - elapsed = 0:04:28 - ETA = 2:25:46
# Epoch 1/50 - batch 231/7760 - loss = 1.672 - accuracy = 0.352 - elapsed = 0:04:29 - ETA = 2:25:45
# Epoch 1/50 - batch 232/7760 - loss = 1.488 - accuracy = 0.353 - elapsed = 0:04:30 - ETA = 2:25:43
# Epoch 1/50 - batch 233/7760 - loss = 1.425 - accuracy = 0.353 - elapsed = 0:04:31 - ETA = 2:25:42
# Epoch 1/50 - batch 234/7760 - loss = 1.974 - accuracy = 0.353 - elapsed = 0:04:32 - ETA = 2:25:41
# Epoch 1/50 - batch 235/7760 - loss = 1.256 - accuracy = 0.353 - elapsed = 0:04:34 - ETA = 2:25:39
# Epoch 1/50 - batch 236/7760 - loss = 1.860 - accuracy = 0.353 - elapsed = 0:04:35 - ETA = 2:25:37
# Epoch 1/50 - batch 237/7760 - loss = 1.528 - accuracy = 0.353 - elapsed = 0:04:36 - ETA = 2:25:36
# Epoch 1/50 - batch 238/7760 - loss = 1.802 - accuracy = 0.353 - elapsed = 0:04:37 - ETA = 2:25:35
# Epoch 1/50 - batch 239/7760 - loss = 1.223 - accuracy = 0.354 - elapsed = 0:04:38 - ETA = 2:25:34
# Epoch 1/50 - batch 240/7760 - loss = 1.354 - accuracy = 0.355 - elapsed = 0:04:39 - ETA = 2:25:32
# Epoch 1/50 - batch 241/7760 - loss = 1.418 - accuracy = 0.355 - elapsed = 0:04:41 - ETA = 2:25:32
# Epoch 1/50 - batch 242/7760 - loss = 1.505 - accuracy = 0.355 - elapsed = 0:04:42 - ETA = 2:25:31
# Epoch 1/50 - batch 243/7760 - loss = 1.330 - accuracy = 0.356 - elapsed = 0:04:43 - ETA = 2:25:29
# Epoch 1/50 - batch 244/7760 - loss = 1.752 - accuracy = 0.355 - elapsed = 0:04:44 - ETA = 2:25:29
# Epoch 1/50 - batch 245/7760 - loss = 1.871 - accuracy = 0.354 - elapsed = 0:04:45 - ETA = 2:25:28
# Epoch 1/50 - batch 246/7760 - loss = 1.793 - accuracy = 0.354 - elapsed = 0:04:46 - ETA = 2:25:27
# Epoch 1/50 - batch 247/7760 - loss = 1.546 - accuracy = 0.354 - elapsed = 0:04:48 - ETA = 2:25:26
# Epoch 1/50 - batch 248/7760 - loss = 1.697 - accuracy = 0.354 - elapsed = 0:04:49 - ETA = 2:25:25
# Epoch 1/50 - batch 249/7760 - loss = 1.553 - accuracy = 0.354 - elapsed = 0:04:50 - ETA = 2:25:24
# Epoch 1/50 - batch 250/7760 - loss = 1.968 - accuracy = 0.354 - elapsed = 0:04:51 - ETA = 2:25:22
# Epoch 1/50 - batch 251/7760 - loss = 1.537 - accuracy = 0.354 - elapsed = 0:04:52 - ETA = 2:25:21
# Epoch 1/50 - batch 252/7760 - loss = 1.580 - accuracy = 0.354 - elapsed = 0:04:53 - ETA = 2:25:20
# Epoch 1/50 - batch 253/7760 - loss = 1.577 - accuracy = 0.355 - elapsed = 0:04:55 - ETA = 2:25:20
# Epoch 1/50 - batch 254/7760 - loss = 1.306 - accuracy = 0.355 - elapsed = 0:04:56 - ETA = 2:25:19
# Epoch 1/50 - batch 255/7760 - loss = 1.577 - accuracy = 0.355 - elapsed = 0:04:57 - ETA = 2:25:18
# Epoch 1/50 - batch 256/7760 - loss = 1.613 - accuracy = 0.355 - elapsed = 0:04:58 - ETA = 2:25:17
# Epoch 1/50 - batch 257/7760 - loss = 1.443 - accuracy = 0.355 - elapsed = 0:04:59 - ETA = 2:25:16
# Epoch 1/50 - batch 258/7760 - loss = 2.074 - accuracy = 0.355 - elapsed = 0:05:00 - ETA = 2:25:16
# Epoch 1/50 - batch 259/7760 - loss = 1.734 - accuracy = 0.355 - elapsed = 0:05:02 - ETA = 2:25:15
# Epoch 1/50 - batch 260/7760 - loss = 1.371 - accuracy = 0.355 - elapsed = 0:05:03 - ETA = 2:25:14
# Epoch 1/50 - batch 261/7760 - loss = 1.608 - accuracy = 0.356 - elapsed = 0:05:04 - ETA = 2:25:13
# Epoch 1/50 - batch 262/7760 - loss = 1.485 - accuracy = 0.356 - elapsed = 0:05:05 - ETA = 2:25:13
# Epoch 1/50 - batch 263/7760 - loss = 1.423 - accuracy = 0.356 - elapsed = 0:05:06 - ETA = 2:25:12
# Epoch 1/50 - batch 264/7760 - loss = 1.231 - accuracy = 0.356 - elapsed = 0:05:07 - ETA = 2:25:10
# Epoch 1/50 - batch 265/7760 - loss = 1.576 - accuracy = 0.356 - elapsed = 0:05:09 - ETA = 2:25:09
# Epoch 1/50 - batch 266/7760 - loss = 1.350 - accuracy = 0.357 - elapsed = 0:05:10 - ETA = 2:25:09
# Epoch 1/50 - batch 267/7760 - loss = 1.485 - accuracy = 0.357 - elapsed = 0:05:11 - ETA = 2:25:08
# Epoch 1/50 - batch 268/7760 - loss = 1.495 - accuracy = 0.357 - elapsed = 0:05:12 - ETA = 2:25:07
# Epoch 1/50 - batch 269/7760 - loss = 1.291 - accuracy = 0.357 - elapsed = 0:05:13 - ETA = 2:25:06
# Epoch 1/50 - batch 270/7760 - loss = 1.616 - accuracy = 0.358 - elapsed = 0:05:14 - ETA = 2:25:04
# Epoch 1/50 - batch 271/7760 - loss = 1.510 - accuracy = 0.357 - elapsed = 0:05:16 - ETA = 2:25:03
# Epoch 1/50 - batch 272/7760 - loss = 1.996 - accuracy = 0.357 - elapsed = 0:05:17 - ETA = 2:25:01
# Epoch 1/50 - batch 273/7760 - loss = 1.524 - accuracy = 0.357 - elapsed = 0:05:18 - ETA = 2:25:00
# Epoch 1/50 - batch 274/7760 - loss = 1.380 - accuracy = 0.358 - elapsed = 0:05:19 - ETA = 2:24:59
# Epoch 1/50 - batch 275/7760 - loss = 1.150 - accuracy = 0.358 - elapsed = 0:05:20 - ETA = 2:24:58
# Epoch 1/50 - batch 276/7760 - loss = 1.707 - accuracy = 0.358 - elapsed = 0:05:21 - ETA = 2:24:57
# Epoch 1/50 - batch 277/7760 - loss = 1.367 - accuracy = 0.358 - elapsed = 0:05:23 - ETA = 2:24:55
# Epoch 1/50 - batch 278/7760 - loss = 1.848 - accuracy = 0.358 - elapsed = 0:05:24 - ETA = 2:24:55
# Epoch 1/50 - batch 279/7760 - loss = 1.723 - accuracy = 0.358 - elapsed = 0:05:25 - ETA = 2:24:53
# Epoch 1/50 - batch 280/7760 - loss = 1.641 - accuracy = 0.358 - elapsed = 0:05:26 - ETA = 2:24:52
# Epoch 1/50 - batch 281/7760 - loss = 1.490 - accuracy = 0.358 - elapsed = 0:05:27 - ETA = 2:24:51
# Epoch 1/50 - batch 282/7760 - loss = 2.088 - accuracy = 0.358 - elapsed = 0:05:28 - ETA = 2:24:50
# Epoch 1/50 - batch 283/7760 - loss = 1.138 - accuracy = 0.358 - elapsed = 0:05:30 - ETA = 2:24:49
# Epoch 1/50 - batch 284/7760 - loss = 1.334 - accuracy = 0.359 - elapsed = 0:05:31 - ETA = 2:24:48
# Epoch 1/50 - batch 285/7760 - loss = 1.490 - accuracy = 0.359 - elapsed = 0:05:32 - ETA = 2:24:47
# Epoch 1/50 - batch 286/7760 - loss = 1.718 - accuracy = 0.359 - elapsed = 0:05:33 - ETA = 2:24:45
# Epoch 1/50 - batch 287/7760 - loss = 1.372 - accuracy = 0.359 - elapsed = 0:05:34 - ETA = 2:24:44
# Epoch 1/50 - batch 288/7760 - loss = 1.529 - accuracy = 0.359 - elapsed = 0:05:35 - ETA = 2:24:43
# Epoch 1/50 - batch 289/7760 - loss = 1.360 - accuracy = 0.360 - elapsed = 0:05:36 - ETA = 2:24:41
# Epoch 1/50 - batch 290/7760 - loss = 1.617 - accuracy = 0.360 - elapsed = 0:05:38 - ETA = 2:24:40
# Epoch 1/50 - batch 291/7760 - loss = 1.523 - accuracy = 0.360 - elapsed = 0:05:39 - ETA = 2:24:39
# Epoch 1/50 - batch 292/7760 - loss = 1.375 - accuracy = 0.360 - elapsed = 0:05:40 - ETA = 2:24:37
# Epoch 1/50 - batch 293/7760 - loss = 1.395 - accuracy = 0.361 - elapsed = 0:05:41 - ETA = 2:24:36
# Epoch 1/50 - batch 294/7760 - loss = 1.746 - accuracy = 0.361 - elapsed = 0:05:42 - ETA = 2:24:35
# Epoch 1/50 - batch 295/7760 - loss = 1.715 - accuracy = 0.361 - elapsed = 0:05:43 - ETA = 2:24:34
# Epoch 1/50 - batch 296/7760 - loss = 1.434 - accuracy = 0.361 - elapsed = 0:05:45 - ETA = 2:24:33
# Epoch 1/50 - batch 297/7760 - loss = 1.581 - accuracy = 0.361 - elapsed = 0:05:46 - ETA = 2:24:32
# Epoch 1/50 - batch 298/7760 - loss = 1.634 - accuracy = 0.361 - elapsed = 0:05:47 - ETA = 2:24:30
# Epoch 1/50 - batch 299/7760 - loss = 1.149 - accuracy = 0.362 - elapsed = 0:05:48 - ETA = 2:24:30
# Epoch 1/50 - batch 300/7760 - loss = 1.771 - accuracy = 0.362 - elapsed = 0:05:49 - ETA = 2:24:29
# Epoch 1/50 - batch 301/7760 - loss = 1.204 - accuracy = 0.363 - elapsed = 0:05:50 - ETA = 2:24:28
# Epoch 1/50 - batch 302/7760 - loss = 2.005 - accuracy = 0.362 - elapsed = 0:05:52 - ETA = 2:24:26
# Epoch 1/50 - batch 303/7760 - loss = 1.333 - accuracy = 0.362 - elapsed = 0:05:53 - ETA = 2:24:24
# Epoch 1/50 - batch 304/7760 - loss = 1.333 - accuracy = 0.363 - elapsed = 0:05:54 - ETA = 2:24:23
# Epoch 1/50 - batch 305/7760 - loss = 1.876 - accuracy = 0.362 - elapsed = 0:05:55 - ETA = 2:24:22
# Epoch 1/50 - batch 306/7760 - loss = 1.555 - accuracy = 0.362 - elapsed = 0:05:56 - ETA = 2:24:21
# Epoch 1/50 - batch 307/7760 - loss = 1.874 - accuracy = 0.362 - elapsed = 0:05:57 - ETA = 2:24:20
# Epoch 1/50 - batch 308/7760 - loss = 1.629 - accuracy = 0.362 - elapsed = 0:05:59 - ETA = 2:24:18
# Epoch 1/50 - batch 309/7760 - loss = 1.605 - accuracy = 0.363 - elapsed = 0:06:00 - ETA = 2:24:17
# Epoch 1/50 - batch 310/7760 - loss = 1.570 - accuracy = 0.362 - elapsed = 0:06:01 - ETA = 2:24:16
# Epoch 1/50 - batch 311/7760 - loss = 1.278 - accuracy = 0.363 - elapsed = 0:06:02 - ETA = 2:24:15
# Epoch 1/50 - batch 312/7760 - loss = 1.882 - accuracy = 0.363 - elapsed = 0:06:03 - ETA = 2:24:14
# Epoch 1/50 - batch 313/7760 - loss = 1.620 - accuracy = 0.363 - elapsed = 0:06:04 - ETA = 2:24:13
# Epoch 1/50 - batch 314/7760 - loss = 1.751 - accuracy = 0.363 - elapsed = 0:06:06 - ETA = 2:24:12
# Epoch 1/50 - batch 315/7760 - loss = 1.783 - accuracy = 0.363 - elapsed = 0:06:07 - ETA = 2:24:11
# Epoch 1/50 - batch 316/7760 - loss = 1.422 - accuracy = 0.363 - elapsed = 0:06:08 - ETA = 2:24:10
# Epoch 1/50 - batch 317/7760 - loss = 1.642 - accuracy = 0.363 - elapsed = 0:06:09 - ETA = 2:24:08
# Epoch 1/50 - batch 318/7760 - loss = 1.467 - accuracy = 0.363 - elapsed = 0:06:10 - ETA = 2:24:07
# Epoch 1/50 - batch 319/7760 - loss = 1.530 - accuracy = 0.363 - elapsed = 0:06:11 - ETA = 2:24:06
# Epoch 1/50 - batch 320/7760 - loss = 1.415 - accuracy = 0.363 - elapsed = 0:06:13 - ETA = 2:24:05
# Epoch 1/50 - batch 321/7760 - loss = 1.664 - accuracy = 0.363 - elapsed = 0:06:14 - ETA = 2:24:04
# Epoch 1/50 - batch 322/7760 - loss = 1.727 - accuracy = 0.363 - elapsed = 0:06:15 - ETA = 2:24:03
# Epoch 1/50 - batch 323/7760 - loss = 1.466 - accuracy = 0.364 - elapsed = 0:06:16 - ETA = 2:24:01
# Epoch 1/50 - batch 324/7760 - loss = 1.418 - accuracy = 0.364 - elapsed = 0:06:17 - ETA = 2:24:00
# Epoch 1/50 - batch 325/7760 - loss = 1.307 - accuracy = 0.364 - elapsed = 0:06:18 - ETA = 2:23:59
# Epoch 1/50 - batch 326/7760 - loss = 1.454 - accuracy = 0.364 - elapsed = 0:06:19 - ETA = 2:23:58
# Epoch 1/50 - batch 327/7760 - loss = 1.589 - accuracy = 0.364 - elapsed = 0:06:21 - ETA = 2:23:57
# Epoch 1/50 - batch 328/7760 - loss = 1.398 - accuracy = 0.364 - elapsed = 0:06:22 - ETA = 2:23:56
# Epoch 1/50 - batch 329/7760 - loss = 1.965 - accuracy = 0.363 - elapsed = 0:06:23 - ETA = 2:23:55
# Epoch 1/50 - batch 330/7760 - loss = 1.346 - accuracy = 0.363 - elapsed = 0:06:24 - ETA = 2:23:54
# Epoch 1/50 - batch 331/7760 - loss = 1.325 - accuracy = 0.364 - elapsed = 0:06:25 - ETA = 2:23:53
# Epoch 1/50 - batch 332/7760 - loss = 1.708 - accuracy = 0.363 - elapsed = 0:06:26 - ETA = 2:23:52
# Epoch 1/50 - batch 333/7760 - loss = 1.440 - accuracy = 0.364 - elapsed = 0:06:28 - ETA = 2:23:51
# Epoch 1/50 - batch 334/7760 - loss = 1.418 - accuracy = 0.364 - elapsed = 0:06:29 - ETA = 2:23:50
# Epoch 1/50 - batch 335/7760 - loss = 1.000 - accuracy = 0.364 - elapsed = 0:06:30 - ETA = 2:23:49
# Epoch 1/50 - batch 336/7760 - loss = 1.532 - accuracy = 0.364 - elapsed = 0:06:31 - ETA = 2:23:47
# Epoch 1/50 - batch 337/7760 - loss = 1.218 - accuracy = 0.365 - elapsed = 0:06:32 - ETA = 2:23:46
# Epoch 1/50 - batch 338/7760 - loss = 1.100 - accuracy = 0.365 - elapsed = 0:06:33 - ETA = 2:23:45
# Epoch 1/50 - batch 339/7760 - loss = 1.379 - accuracy = 0.366 - elapsed = 0:06:35 - ETA = 2:23:44
# Epoch 1/50 - batch 340/7760 - loss = 1.373 - accuracy = 0.366 - elapsed = 0:06:36 - ETA = 2:23:43
# Epoch 1/50 - batch 341/7760 - loss = 1.534 - accuracy = 0.366 - elapsed = 0:06:37 - ETA = 2:23:42
# Epoch 1/50 - batch 342/7760 - loss = 1.473 - accuracy = 0.366 - elapsed = 0:06:38 - ETA = 2:23:41
# Epoch 1/50 - batch 343/7760 - loss = 1.670 - accuracy = 0.366 - elapsed = 0:06:39 - ETA = 2:23:40
# Epoch 1/50 - batch 344/7760 - loss = 1.955 - accuracy = 0.365 - elapsed = 0:06:40 - ETA = 2:23:39
# Epoch 1/50 - batch 345/7760 - loss = 1.338 - accuracy = 0.366 - elapsed = 0:06:42 - ETA = 2:23:38
# Epoch 1/50 - batch 346/7760 - loss = 1.880 - accuracy = 0.366 - elapsed = 0:06:43 - ETA = 2:23:37
# Epoch 1/50 - batch 347/7760 - loss = 1.624 - accuracy = 0.365 - elapsed = 0:06:44 - ETA = 2:23:36
# Epoch 1/50 - batch 348/7760 - loss = 1.536 - accuracy = 0.366 - elapsed = 0:06:45 - ETA = 2:23:35
# Epoch 1/50 - batch 349/7760 - loss = 1.992 - accuracy = 0.365 - elapsed = 0:06:46 - ETA = 2:23:33
# Epoch 1/50 - batch 350/7760 - loss = 2.070 - accuracy = 0.366 - elapsed = 0:06:47 - ETA = 2:23:32
# Epoch 1/50 - batch 351/7760 - loss = 1.687 - accuracy = 0.366 - elapsed = 0:06:49 - ETA = 2:23:31
# Epoch 1/50 - batch 352/7760 - loss = 1.768 - accuracy = 0.366 - elapsed = 0:06:50 - ETA = 2:23:30
# Epoch 1/50 - batch 353/7760 - loss = 2.154 - accuracy = 0.365 - elapsed = 0:06:51 - ETA = 2:23:29
# Epoch 1/50 - batch 354/7760 - loss = 1.424 - accuracy = 0.365 - elapsed = 0:06:52 - ETA = 2:23:28
# Epoch 1/50 - batch 355/7760 - loss = 1.207 - accuracy = 0.366 - elapsed = 0:06:53 - ETA = 2:23:27
# Epoch 1/50 - batch 356/7760 - loss = 1.094 - accuracy = 0.367 - elapsed = 0:06:54 - ETA = 2:23:26
# Epoch 1/50 - batch 357/7760 - loss = 1.661 - accuracy = 0.366 - elapsed = 0:06:56 - ETA = 2:23:24
# Epoch 1/50 - batch 358/7760 - loss = 1.543 - accuracy = 0.367 - elapsed = 0:06:57 - ETA = 2:23:23
# Epoch 1/50 - batch 359/7760 - loss = 1.459 - accuracy = 0.367 - elapsed = 0:06:58 - ETA = 2:23:21
# Epoch 1/50 - batch 360/7760 - loss = 1.759 - accuracy = 0.367 - elapsed = 0:06:59 - ETA = 2:23:20
# Epoch 1/50 - batch 361/7760 - loss = 1.488 - accuracy = 0.367 - elapsed = 0:07:00 - ETA = 2:23:19
# Epoch 1/50 - batch 362/7760 - loss = 1.716 - accuracy = 0.366 - elapsed = 0:07:01 - ETA = 2:23:18
# Epoch 1/50 - batch 363/7760 - loss = 1.289 - accuracy = 0.367 - elapsed = 0:07:03 - ETA = 2:23:17
# Epoch 1/50 - batch 364/7760 - loss = 1.610 - accuracy = 0.367 - elapsed = 0:07:04 - ETA = 2:23:16
# Epoch 1/50 - batch 365/7760 - loss = 1.564 - accuracy = 0.367 - elapsed = 0:07:05 - ETA = 2:23:14
# Epoch 1/50 - batch 366/7760 - loss = 1.758 - accuracy = 0.367 - elapsed = 0:07:06 - ETA = 2:23:13
# Epoch 1/50 - batch 367/7760 - loss = 1.394 - accuracy = 0.367 - elapsed = 0:07:07 - ETA = 2:23:12
# Epoch 1/50 - batch 368/7760 - loss = 1.588 - accuracy = 0.367 - elapsed = 0:07:08 - ETA = 2:23:12
# Epoch 1/50 - batch 369/7760 - loss = 1.581 - accuracy = 0.367 - elapsed = 0:07:10 - ETA = 2:23:11
# Epoch 1/50 - batch 370/7760 - loss = 2.202 - accuracy = 0.366 - elapsed = 0:07:11 - ETA = 2:23:10
# Epoch 1/50 - batch 371/7760 - loss = 1.590 - accuracy = 0.367 - elapsed = 0:07:12 - ETA = 2:23:09
# Epoch 1/50 - batch 372/7760 - loss = 1.415 - accuracy = 0.367 - elapsed = 0:07:13 - ETA = 2:23:08
# Epoch 1/50 - batch 373/7760 - loss = 1.741 - accuracy = 0.367 - elapsed = 0:07:14 - ETA = 2:23:07
# Epoch 1/50 - batch 374/7760 - loss = 1.312 - accuracy = 0.367 - elapsed = 0:07:15 - ETA = 2:23:05
# Epoch 1/50 - batch 375/7760 - loss = 1.181 - accuracy = 0.368 - elapsed = 0:07:17 - ETA = 2:23:04
# Epoch 1/50 - batch 376/7760 - loss = 1.367 - accuracy = 0.368 - elapsed = 0:07:18 - ETA = 2:23:03
# Epoch 1/50 - batch 377/7760 - loss = 1.425 - accuracy = 0.368 - elapsed = 0:07:19 - ETA = 2:23:01
# Epoch 1/50 - batch 378/7760 - loss = 1.682 - accuracy = 0.368 - elapsed = 0:07:20 - ETA = 2:23:00
# Epoch 1/50 - batch 379/7760 - loss = 1.399 - accuracy = 0.368 - elapsed = 0:07:21 - ETA = 2:22:58
# Epoch 1/50 - batch 380/7760 - loss = 1.399 - accuracy = 0.368 - elapsed = 0:07:22 - ETA = 2:22:58
# Epoch 1/50 - batch 381/7760 - loss = 1.460 - accuracy = 0.368 - elapsed = 0:07:24 - ETA = 2:22:56
# Epoch 1/50 - batch 382/7760 - loss = 1.607 - accuracy = 0.368 - elapsed = 0:07:25 - ETA = 2:22:55
# Epoch 1/50 - batch 383/7760 - loss = 1.730 - accuracy = 0.368 - elapsed = 0:07:26 - ETA = 2:22:53
# Epoch 1/50 - batch 384/7760 - loss = 1.595 - accuracy = 0.368 - elapsed = 0:07:27 - ETA = 2:22:53
# Epoch 1/50 - batch 385/7760 - loss = 1.490 - accuracy = 0.369 - elapsed = 0:07:28 - ETA = 2:22:52
# Epoch 1/50 - batch 386/7760 - loss = 1.619 - accuracy = 0.368 - elapsed = 0:07:29 - ETA = 2:22:51
# Epoch 1/50 - batch 387/7760 - loss = 1.380 - accuracy = 0.368 - elapsed = 0:07:30 - ETA = 2:22:50
# Epoch 1/50 - batch 388/7760 - loss = 1.500 - accuracy = 0.368 - elapsed = 0:07:32 - ETA = 2:22:48
# Epoch 1/50 - batch 389/7760 - loss = 1.222 - accuracy = 0.369 - elapsed = 0:07:33 - ETA = 2:22:47
# Epoch 1/50 - batch 390/7760 - loss = 1.588 - accuracy = 0.369 - elapsed = 0:07:34 - ETA = 2:22:46
# Epoch 1/50 - batch 391/7760 - loss = 1.356 - accuracy = 0.369 - elapsed = 0:07:35 - ETA = 2:22:45
# Epoch 1/50 - batch 392/7760 - loss = 1.983 - accuracy = 0.369 - elapsed = 0:07:36 - ETA = 2:22:44
# Epoch 1/50 - batch 393/7760 - loss = 1.570 - accuracy = 0.370 - elapsed = 0:07:37 - ETA = 2:22:43
# Epoch 1/50 - batch 394/7760 - loss = 1.639 - accuracy = 0.370 - elapsed = 0:07:39 - ETA = 2:22:41
# Epoch 1/50 - batch 395/7760 - loss = 1.288 - accuracy = 0.370 - elapsed = 0:07:40 - ETA = 2:22:40
# Epoch 1/50 - batch 396/7760 - loss = 1.725 - accuracy = 0.370 - elapsed = 0:07:41 - ETA = 2:22:38
# Epoch 1/50 - batch 397/7760 - loss = 1.110 - accuracy = 0.370 - elapsed = 0:07:42 - ETA = 2:22:37
# Epoch 1/50 - batch 398/7760 - loss = 1.570 - accuracy = 0.371 - elapsed = 0:07:43 - ETA = 2:22:36
# Epoch 1/50 - batch 399/7760 - loss = 1.231 - accuracy = 0.371 - elapsed = 0:07:44 - ETA = 2:22:35
# Epoch 1/50 - batch 400/7760 - loss = 1.450 - accuracy = 0.371 - elapsed = 0:07:46 - ETA = 2:22:34
# Epoch 1/50 - batch 401/7760 - loss = 1.330 - accuracy = 0.371 - elapsed = 0:07:47 - ETA = 2:22:32
# Epoch 1/50 - batch 402/7760 - loss = 1.449 - accuracy = 0.371 - elapsed = 0:07:48 - ETA = 2:22:31
# Epoch 1/50 - batch 403/7760 - loss = 1.605 - accuracy = 0.372 - elapsed = 0:07:49 - ETA = 2:22:30
# Epoch 1/50 - batch 404/7760 - loss = 1.588 - accuracy = 0.371 - elapsed = 0:07:50 - ETA = 2:22:29
# Epoch 1/50 - batch 405/7760 - loss = 1.278 - accuracy = 0.372 - elapsed = 0:07:51 - ETA = 2:22:28
# Epoch 1/50 - batch 406/7760 - loss = 1.181 - accuracy = 0.372 - elapsed = 0:07:53 - ETA = 2:22:27
# Epoch 1/50 - batch 407/7760 - loss = 1.388 - accuracy = 0.372 - elapsed = 0:07:54 - ETA = 2:22:26
# Epoch 1/50 - batch 408/7760 - loss = 1.312 - accuracy = 0.373 - elapsed = 0:07:55 - ETA = 2:22:24
# Epoch 1/50 - batch 409/7760 - loss = 0.948 - accuracy = 0.373 - elapsed = 0:07:56 - ETA = 2:22:23
# Epoch 1/50 - batch 410/7760 - loss = 1.773 - accuracy = 0.373 - elapsed = 0:07:57 - ETA = 2:22:22
# Epoch 1/50 - batch 411/7760 - loss = 1.163 - accuracy = 0.374 - elapsed = 0:07:58 - ETA = 2:22:21
# Epoch 1/50 - batch 412/7760 - loss = 1.559 - accuracy = 0.374 - elapsed = 0:08:00 - ETA = 2:22:20
# Epoch 1/50 - batch 413/7760 - loss = 1.353 - accuracy = 0.374 - elapsed = 0:08:01 - ETA = 2:22:19
# Epoch 1/50 - batch 414/7760 - loss = 1.871 - accuracy = 0.374 - elapsed = 0:08:02 - ETA = 2:22:17
# Epoch 1/50 - batch 415/7760 - loss = 1.733 - accuracy = 0.373 - elapsed = 0:08:03 - ETA = 2:22:16
# Epoch 1/50 - batch 416/7760 - loss = 1.323 - accuracy = 0.374 - elapsed = 0:08:04 - ETA = 2:22:15
# Epoch 1/50 - batch 417/7760 - loss = 1.875 - accuracy = 0.373 - elapsed = 0:08:05 - ETA = 2:22:14
# Epoch 1/50 - batch 418/7760 - loss = 1.678 - accuracy = 0.374 - elapsed = 0:08:06 - ETA = 2:22:13
# Epoch 1/50 - batch 419/7760 - loss = 1.234 - accuracy = 0.374 - elapsed = 0:08:08 - ETA = 2:22:12
# Epoch 1/50 - batch 420/7760 - loss = 1.484 - accuracy = 0.374 - elapsed = 0:08:09 - ETA = 2:22:11
# Epoch 1/50 - batch 421/7760 - loss = 1.688 - accuracy = 0.374 - elapsed = 0:08:10 - ETA = 2:22:10
# Epoch 1/50 - batch 422/7760 - loss = 1.711 - accuracy = 0.374 - elapsed = 0:08:11 - ETA = 2:22:08
# Epoch 1/50 - batch 423/7760 - loss = 1.765 - accuracy = 0.374 - elapsed = 0:08:12 - ETA = 2:22:07
# Epoch 1/50 - batch 424/7760 - loss = 1.874 - accuracy = 0.374 - elapsed = 0:08:13 - ETA = 2:22:06
# Epoch 1/50 - batch 425/7760 - loss = 1.191 - accuracy = 0.374 - elapsed = 0:08:15 - ETA = 2:22:04
# Epoch 1/50 - batch 426/7760 - loss = 1.385 - accuracy = 0.375 - elapsed = 0:08:16 - ETA = 2:22:03
# Epoch 1/50 - batch 427/7760 - loss = 1.022 - accuracy = 0.375 - elapsed = 0:08:17 - ETA = 2:22:02
# Epoch 1/50 - batch 428/7760 - loss = 1.709 - accuracy = 0.375 - elapsed = 0:08:18 - ETA = 2:22:01
# Epoch 1/50 - batch 429/7760 - loss = 1.436 - accuracy = 0.375 - elapsed = 0:08:19 - ETA = 2:22:00
# Epoch 1/50 - batch 430/7760 - loss = 1.220 - accuracy = 0.376 - elapsed = 0:08:20 - ETA = 2:21:59
# Epoch 1/50 - batch 431/7760 - loss = 1.595 - accuracy = 0.376 - elapsed = 0:08:22 - ETA = 2:21:57
# Epoch 1/50 - batch 432/7760 - loss = 1.313 - accuracy = 0.376 - elapsed = 0:08:23 - ETA = 2:21:56
# Epoch 1/50 - batch 433/7760 - loss = 1.361 - accuracy = 0.376 - elapsed = 0:08:24 - ETA = 2:21:55
# Epoch 1/50 - batch 434/7760 - loss = 1.323 - accuracy = 0.376 - elapsed = 0:08:25 - ETA = 2:21:54
# Epoch 1/50 - batch 435/7760 - loss = 1.515 - accuracy = 0.377 - elapsed = 0:08:26 - ETA = 2:21:53
# Epoch 1/50 - batch 436/7760 - loss = 1.672 - accuracy = 0.377 - elapsed = 0:08:27 - ETA = 2:21:52
# Epoch 1/50 - batch 437/7760 - loss = 1.628 - accuracy = 0.376 - elapsed = 0:08:29 - ETA = 2:21:50
# Epoch 1/50 - batch 438/7760 - loss = 1.601 - accuracy = 0.376 - elapsed = 0:08:30 - ETA = 2:21:49
# Epoch 1/50 - batch 439/7760 - loss = 1.490 - accuracy = 0.376 - elapsed = 0:08:31 - ETA = 2:21:48
# Epoch 1/50 - batch 440/7760 - loss = 1.872 - accuracy = 0.376 - elapsed = 0:08:32 - ETA = 2:21:47
# Epoch 1/50 - batch 441/7760 - loss = 2.073 - accuracy = 0.376 - elapsed = 0:08:33 - ETA = 2:21:46
# Epoch 1/50 - batch 442/7760 - loss = 1.676 - accuracy = 0.376 - elapsed = 0:08:34 - ETA = 2:21:45
# Epoch 1/50 - batch 443/7760 - loss = 1.188 - accuracy = 0.376 - elapsed = 0:08:36 - ETA = 2:21:44
# Epoch 1/50 - batch 444/7760 - loss = 1.577 - accuracy = 0.376 - elapsed = 0:08:37 - ETA = 2:21:42
# Epoch 1/50 - batch 445/7760 - loss = 1.100 - accuracy = 0.377 - elapsed = 0:08:38 - ETA = 2:21:41
# Epoch 1/50 - batch 446/7760 - loss = 1.591 - accuracy = 0.377 - elapsed = 0:08:39 - ETA = 2:21:40
# Epoch 1/50 - batch 447/7760 - loss = 1.328 - accuracy = 0.377 - elapsed = 0:08:40 - ETA = 2:21:39
# Epoch 1/50 - batch 448/7760 - loss = 1.539 - accuracy = 0.377 - elapsed = 0:08:41 - ETA = 2:21:38
# Epoch 1/50 - batch 449/7760 - loss = 1.506 - accuracy = 0.377 - elapsed = 0:08:43 - ETA = 2:21:37
# Epoch 1/50 - batch 450/7760 - loss = 1.633 - accuracy = 0.377 - elapsed = 0:08:44 - ETA = 2:21:36
# Epoch 1/50 - batch 451/7760 - loss = 1.299 - accuracy = 0.377 - elapsed = 0:08:45 - ETA = 2:21:35
# Epoch 1/50 - batch 452/7760 - loss = 1.838 - accuracy = 0.377 - elapsed = 0:08:46 - ETA = 2:21:34
# Epoch 1/50 - batch 453/7760 - loss = 1.549 - accuracy = 0.377 - elapsed = 0:08:47 - ETA = 2:21:33
# Epoch 1/50 - batch 454/7760 - loss = 1.587 - accuracy = 0.377 - elapsed = 0:08:48 - ETA = 2:21:32
# Epoch 1/50 - batch 455/7760 - loss = 1.480 - accuracy = 0.377 - elapsed = 0:08:50 - ETA = 2:21:31
# Epoch 1/50 - batch 456/7760 - loss = 1.640 - accuracy = 0.377 - elapsed = 0:08:51 - ETA = 2:21:29
# Epoch 1/50 - batch 457/7760 - loss = 1.480 - accuracy = 0.377 - elapsed = 0:08:52 - ETA = 2:21:28
# Epoch 1/50 - batch 458/7760 - loss = 1.573 - accuracy = 0.377 - elapsed = 0:08:53 - ETA = 2:21:27
# Epoch 1/50 - batch 459/7760 - loss = 1.415 - accuracy = 0.377 - elapsed = 0:08:54 - ETA = 2:21:26
# Epoch 1/50 - batch 460/7760 - loss = 1.770 - accuracy = 0.377 - elapsed = 0:08:55 - ETA = 2:21:25
# Epoch 1/50 - batch 461/7760 - loss = 1.416 - accuracy = 0.377 - elapsed = 0:08:57 - ETA = 2:21:24
# Epoch 1/50 - batch 462/7760 - loss = 1.417 - accuracy = 0.377 - elapsed = 0:08:58 - ETA = 2:21:23
# Epoch 1/50 - batch 463/7760 - loss = 1.754 - accuracy = 0.377 - elapsed = 0:08:59 - ETA = 2:21:21
# Epoch 1/50 - batch 464/7760 - loss = 1.766 - accuracy = 0.377 - elapsed = 0:09:00 - ETA = 2:21:20
# Epoch 1/50 - batch 465/7760 - loss = 1.465 - accuracy = 0.377 - elapsed = 0:09:01 - ETA = 2:21:19
# Epoch 1/50 - batch 466/7760 - loss = 1.621 - accuracy = 0.377 - elapsed = 0:09:02 - ETA = 2:21:17
# Epoch 1/50 - batch 467/7760 - loss = 1.563 - accuracy = 0.378 - elapsed = 0:09:03 - ETA = 2:21:16
# Epoch 1/50 - batch 468/7760 - loss = 1.564 - accuracy = 0.378 - elapsed = 0:09:05 - ETA = 2:21:15
# Epoch 1/50 - batch 469/7760 - loss = 1.521 - accuracy = 0.378 - elapsed = 0:09:06 - ETA = 2:21:14
# Epoch 1/50 - batch 470/7760 - loss = 1.308 - accuracy = 0.378 - elapsed = 0:09:07 - ETA = 2:21:13
# Epoch 1/50 - batch 471/7760 - loss = 1.213 - accuracy = 0.378 - elapsed = 0:09:08 - ETA = 2:21:11
# Epoch 1/50 - batch 472/7760 - loss = 1.733 - accuracy = 0.378 - elapsed = 0:09:09 - ETA = 2:21:10
# Epoch 1/50 - batch 473/7760 - loss = 1.248 - accuracy = 0.378 - elapsed = 0:09:10 - ETA = 2:21:09
# Epoch 1/50 - batch 474/7760 - loss = 1.678 - accuracy = 0.378 - elapsed = 0:09:12 - ETA = 2:21:08
# Epoch 1/50 - batch 475/7760 - loss = 1.307 - accuracy = 0.378 - elapsed = 0:09:13 - ETA = 2:21:07
# Epoch 1/50 - batch 476/7760 - loss = 1.739 - accuracy = 0.378 - elapsed = 0:09:14 - ETA = 2:21:06
# Epoch 1/50 - batch 477/7760 - loss = 1.037 - accuracy = 0.378 - elapsed = 0:09:15 - ETA = 2:21:04
# Epoch 1/50 - batch 478/7760 - loss = 1.593 - accuracy = 0.378 - elapsed = 0:09:16 - ETA = 2:21:03
# Epoch 1/50 - batch 479/7760 - loss = 1.291 - accuracy = 0.378 - elapsed = 0:09:17 - ETA = 2:21:02
# Epoch 1/50 - batch 480/7760 - loss = 1.366 - accuracy = 0.379 - elapsed = 0:09:19 - ETA = 2:21:00
# Epoch 1/50 - batch 481/7760 - loss = 1.513 - accuracy = 0.379 - elapsed = 0:09:20 - ETA = 2:21:00
# Epoch 1/50 - batch 482/7760 - loss = 1.711 - accuracy = 0.379 - elapsed = 0:09:21 - ETA = 2:20:58
# Epoch 1/50 - batch 483/7760 - loss = 1.357 - accuracy = 0.379 - elapsed = 0:09:22 - ETA = 2:20:57
# Epoch 1/50 - batch 484/7760 - loss = 1.718 - accuracy = 0.379 - elapsed = 0:09:23 - ETA = 2:20:56
# Epoch 1/50 - batch 485/7760 - loss = 1.614 - accuracy = 0.379 - elapsed = 0:09:24 - ETA = 2:20:55
# Epoch 1/50 - batch 486/7760 - loss = 1.812 - accuracy = 0.378 - elapsed = 0:09:26 - ETA = 2:20:54
# Epoch 1/50 - batch 487/7760 - loss = 1.130 - accuracy = 0.379 - elapsed = 0:09:27 - ETA = 2:20:53
# Epoch 1/50 - batch 488/7760 - loss = 1.274 - accuracy = 0.379 - elapsed = 0:09:28 - ETA = 2:20:52
# Epoch 1/50 - batch 489/7760 - loss = 1.432 - accuracy = 0.379 - elapsed = 0:09:29 - ETA = 2:20:51
# ...
# Epoch 1/50 - batch 2096/7760 - loss = 1.703 - accuracy = 0.413 - elapsed = 0:40:40 - ETA = 1:49:51
# Epoch 1/50 - batch 2097/7760 - loss = 1.293 - accuracy = 0.413 - elapsed = 0:40:41 - ETA = 1:49:49
# Epoch 1/50 - batch 2098/7760 - loss = 1.244 - accuracy = 0.413 - elapsed = 0:40:42 - ETA = 1:49:48
# Epoch 1/50 - batch 2099/7760 - loss = 1.220 - accuracy = 0.413 - elapsed = 0:40:43 - ETA = 1:49:47
# Epoch 1/50 - batch 2100/7760 - loss = 1.093 - accuracy = 0.413 - elapsed = 0:40:44 - ETA = 1:49:46
# Epoch 1/50 - batch 2101/7760 - loss = 1.621 - accuracy = 0.413 - elapsed = 0:40:46 - ETA = 1:49:45
# Epoch 1/50 - batch 2102/7760 - loss = 1.386 - accuracy = 0.413 - elapsed = 0:40:47 - ETA = 1:49:44
# Epoch 1/50 - batch 2103/7760 - loss = 1.382 - accuracy = 0.413 - elapsed = 0:40:48 - ETA = 1:49:42
# Epoch 1/50 - batch 2104/7760 - loss = 1.202 - accuracy = 0.413 - elapsed = 0:40:49 - ETA = 1:49:41
# Epoch 1/50 - batch 2105/7760 - loss = 1.476 - accuracy = 0.413 - elapsed = 0:40:50 - ETA = 1:49:40
# Epoch 1/50 - batch 2106/7760 - loss = 1.392 - accuracy = 0.413 - elapsed = 0:40:51 - ETA = 1:49:39
# Epoch 1/50 - batch 2107/7760 - loss = 1.435 - accuracy = 0.413 - elapsed = 0:40:53 - ETA = 1:49:38
# Epoch 1/50 - batch 2108/7760 - loss = 1.328 - accuracy = 0.413 - elapsed = 0:40:54 - ETA = 1:49:37
# Epoch 1/50 - batch 2109/7760 - loss = 1.707 - accuracy = 0.413 - elapsed = 0:40:55 - ETA = 1:49:36
# Epoch 1/50 - batch 2110/7760 - loss = 1.339 - accuracy = 0.413 - elapsed = 0:40:56 - ETA = 1:49:35
# Epoch 1/50 - batch 2111/7760 - loss = 1.756 - accuracy = 0.413 - elapsed = 0:40:57 - ETA = 1:49:33
# Epoch 1/50 - batch 2112/7760 - loss = 1.243 - accuracy = 0.413 - elapsed = 0:40:58 - ETA = 1:49:32
# Epoch 1/50 - batch 2113/7760 - loss = 1.451 - accuracy = 0.413 - elapsed = 0:41:00 - ETA = 1:49:31
# Epoch 1/50 - batch 2114/7760 - loss = 1.282 - accuracy = 0.413 - elapsed = 0:41:01 - ETA = 1:49:30
# Epoch 1/50 - batch 2115/7760 - loss = 1.446 - accuracy = 0.413 - elapsed = 0:41:02 - ETA = 1:49:29
# Epoch 1/50 - batch 2116/7760 - loss = 1.578 - accuracy = 0.413 - elapsed = 0:41:03 - ETA = 1:49:28
# Epoch 1/50 - batch 2117/7760 - loss = 1.907 - accuracy = 0.413 - elapsed = 0:41:04 - ETA = 1:49:27
# Epoch 1/50 - batch 2118/7760 - loss = 1.363 - accuracy = 0.413 - elapsed = 0:41:05 - ETA = 1:49:25
# Epoch 1/50 - batch 2119/7760 - loss = 1.415 - accuracy = 0.413 - elapsed = 0:41:07 - ETA = 1:49:24
# Epoch 1/50 - batch 2120/7760 - loss = 1.118 - accuracy = 0.413 - elapsed = 0:41:08 - ETA = 1:49:23
# Epoch 1/50 - batch 2121/7760 - loss = 1.622 - accuracy = 0.413 - elapsed = 0:41:09 - ETA = 1:49:22
# Epoch 1/50 - batch 2122/7760 - loss = 1.309 - accuracy = 0.413 - elapsed = 0:41:10 - ETA = 1:49:21
# Epoch 1/50 - batch 2123/7760 - loss = 1.512 - accuracy = 0.413 - elapsed = 0:41:11 - ETA = 1:49:20
# Epoch 1/50 - batch 2124/7760 - loss = 1.612 - accuracy = 0.413 - elapsed = 0:41:13 - ETA = 1:49:19
# Epoch 1/50 - batch 2125/7760 - loss = 1.588 - accuracy = 0.413 - elapsed = 0:41:14 - ETA = 1:49:17
# Epoch 1/50 - batch 2126/7760 - loss = 1.490 - accuracy = 0.413 - elapsed = 0:41:15 - ETA = 1:49:16
# Epoch 1/50 - batch 2127/7760 - loss = 1.355 - accuracy = 0.413 - elapsed = 0:41:16 - ETA = 1:49:15
# Epoch 1/50 - batch 2128/7760 - loss = 1.438 - accuracy = 0.413 - elapsed = 0:41:17 - ETA = 1:49:14
# Epoch 1/50 - batch 2129/7760 - loss = 1.435 - accuracy = 0.413 - elapsed = 0:41:18 - ETA = 1:49:13
# Epoch 1/50 - batch 2130/7760 - loss = 1.037 - accuracy = 0.413 - elapsed = 0:41:19 - ETA = 1:49:12
# Epoch 1/50 - batch 2131/7760 - loss = 1.194 - accuracy = 0.413 - elapsed = 0:41:21 - ETA = 1:49:10
# Epoch 1/50 - batch 2132/7760 - loss = 1.240 - accuracy = 0.413 - elapsed = 0:41:22 - ETA = 1:49:09
# Epoch 1/50 - batch 2133/7760 - loss = 1.373 - accuracy = 0.413 - elapsed = 0:41:23 - ETA = 1:49:08
# Epoch 1/50 - batch 2134/7760 - loss = 1.451 - accuracy = 0.413 - elapsed = 0:41:24 - ETA = 1:49:07
# Epoch 1/50 - batch 2135/7760 - loss = 1.222 - accuracy = 0.413 - elapsed = 0:41:25 - ETA = 1:49:06
# Epoch 1/50 - batch 2136/7760 - loss = 1.420 - accuracy = 0.413 - elapsed = 0:41:26 - ETA = 1:49:04
# Epoch 1/50 - batch 2137/7760 - loss = 1.554 - accuracy = 0.413 - elapsed = 0:41:28 - ETA = 1:49:03
# Epoch 1/50 - batch 2138/7760 - loss = 1.136 - accuracy = 0.413 - elapsed = 0:41:29 - ETA = 1:49:02
# Epoch 1/50 - batch 2139/7760 - loss = 1.296 - accuracy = 0.413 - elapsed = 0:41:30 - ETA = 1:49:01
# Epoch 1/50 - batch 2140/7760 - loss = 1.418 - accuracy = 0.413 - elapsed = 0:41:31 - ETA = 1:49:00
# Epoch 1/50 - batch 2141/7760 - loss = 1.456 - accuracy = 0.413 - elapsed = 0:41:32 - ETA = 1:48:59
# Epoch 1/50 - batch 2142/7760 - loss = 1.154 - accuracy = 0.413 - elapsed = 0:41:33 - ETA = 1:48:57
# Epoch 1/50 - batch 2143/7760 - loss = 1.393 - accuracy = 0.413 - elapsed = 0:41:35 - ETA = 1:48:56
# Epoch 1/50 - batch 2144/7760 - loss = 1.089 - accuracy = 0.413 - elapsed = 0:41:36 - ETA = 1:48:55
# Epoch 1/50 - batch 2145/7760 - loss = 1.519 - accuracy = 0.413 - elapsed = 0:41:37 - ETA = 1:48:54
# Epoch 1/50 - batch 2146/7760 - loss = 1.508 - accuracy = 0.413 - elapsed = 0:41:38 - ETA = 1:48:53
# Epoch 1/50 - batch 2147/7760 - loss = 1.380 - accuracy = 0.413 - elapsed = 0:41:39 - ETA = 1:48:52
# Epoch 1/50 - batch 2148/7760 - loss = 1.306 - accuracy = 0.413 - elapsed = 0:41:40 - ETA = 1:48:51
# Epoch 1/50 - batch 2149/7760 - loss = 1.355 - accuracy = 0.413 - elapsed = 0:41:42 - ETA = 1:48:49
# Epoch 1/50 - batch 2150/7760 - loss = 1.283 - accuracy = 0.413 - elapsed = 0:41:43 - ETA = 1:48:48
# Epoch 1/50 - batch 2151/7760 - loss = 1.521 - accuracy = 0.413 - elapsed = 0:41:44 - ETA = 1:48:47
# Epoch 1/50 - batch 2152/7760 - loss = 1.378 - accuracy = 0.413 - elapsed = 0:41:45 - ETA = 1:48:46
# Epoch 1/50 - batch 2153/7760 - loss = 1.649 - accuracy = 0.413 - elapsed = 0:41:46 - ETA = 1:48:45
# Epoch 1/50 - batch 2154/7760 - loss = 1.475 - accuracy = 0.413 - elapsed = 0:41:47 - ETA = 1:48:43
# Epoch 1/50 - batch 2155/7760 - loss = 1.801 - accuracy = 0.413 - elapsed = 0:41:49 - ETA = 1:48:42
# Epoch 1/50 - batch 2156/7760 - loss = 1.417 - accuracy = 0.413 - elapsed = 0:41:50 - ETA = 1:48:41
# Epoch 1/50 - batch 2157/7760 - loss = 1.491 - accuracy = 0.413 - elapsed = 0:41:51 - ETA = 1:48:40
# Epoch 1/50 - batch 2158/7760 - loss = 1.331 - accuracy = 0.413 - elapsed = 0:41:52 - ETA = 1:48:39
# Epoch 1/50 - batch 2159/7760 - loss = 1.746 - accuracy = 0.413 - elapsed = 0:41:53 - ETA = 1:48:38
# Epoch 1/50 - batch 2160/7760 - loss = 1.305 - accuracy = 0.413 - elapsed = 0:41:54 - ETA = 1:48:36
# Epoch 1/50 - batch 2161/7760 - loss = 1.485 - accuracy = 0.413 - elapsed = 0:41:56 - ETA = 1:48:35
# Epoch 1/50 - batch 2162/7760 - loss = 1.632 - accuracy = 0.413 - elapsed = 0:41:57 - ETA = 1:48:34
# Epoch 1/50 - batch 2163/7760 - loss = 1.180 - accuracy = 0.413 - elapsed = 0:41:58 - ETA = 1:48:33
# Epoch 1/50 - batch 2164/7760 - loss = 1.157 - accuracy = 0.413 - elapsed = 0:41:59 - ETA = 1:48:32
# Epoch 1/50 - batch 2165/7760 - loss = 1.781 - accuracy = 0.413 - elapsed = 0:42:00 - ETA = 1:48:31
# Epoch 1/50 - batch 2166/7760 - loss = 1.153 - accuracy = 0.413 - elapsed = 0:42:01 - ETA = 1:48:30
# Epoch 1/50 - batch 2167/7760 - loss = 1.393 - accuracy = 0.413 - elapsed = 0:42:03 - ETA = 1:48:29
# Epoch 1/50 - batch 2168/7760 - loss = 1.279 - accuracy = 0.413 - elapsed = 0:42:04 - ETA = 1:48:27
# Epoch 1/50 - batch 2169/7760 - loss = 1.389 - accuracy = 0.413 - elapsed = 0:42:05 - ETA = 1:48:26
# Epoch 1/50 - batch 2170/7760 - loss = 1.487 - accuracy = 0.413 - elapsed = 0:42:06 - ETA = 1:48:25
# Epoch 1/50 - batch 2171/7760 - loss = 1.588 - accuracy = 0.413 - elapsed = 0:42:07 - ETA = 1:48:24
# Epoch 1/50 - batch 2172/7760 - loss = 1.100 - accuracy = 0.413 - elapsed = 0:42:08 - ETA = 1:48:23
# Epoch 1/50 - batch 2173/7760 - loss = 1.255 - accuracy = 0.413 - elapsed = 0:42:10 - ETA = 1:48:22
# Epoch 1/50 - batch 2174/7760 - loss = 1.303 - accuracy = 0.414 - elapsed = 0:42:11 - ETA = 1:48:20
# Epoch 1/50 - batch 2175/7760 - loss = 1.139 - accuracy = 0.414 - elapsed = 0:42:12 - ETA = 1:48:19
# Epoch 1/50 - batch 2176/7760 - loss = 1.032 - accuracy = 0.414 - elapsed = 0:42:13 - ETA = 1:48:18
# Epoch 1/50 - batch 2177/7760 - loss = 1.558 - accuracy = 0.414 - elapsed = 0:42:14 - ETA = 1:48:17
# Epoch 1/50 - batch 2178/7760 - loss = 1.253 - accuracy = 0.414 - elapsed = 0:42:15 - ETA = 1:48:16
# Epoch 1/50 - batch 2179/7760 - loss = 1.400 - accuracy = 0.414 - elapsed = 0:42:17 - ETA = 1:48:15
# Epoch 1/50 - batch 2180/7760 - loss = 1.023 - accuracy = 0.414 - elapsed = 0:42:18 - ETA = 1:48:14
# Epoch 1/50 - batch 2181/7760 - loss = 1.478 - accuracy = 0.414 - elapsed = 0:42:19 - ETA = 1:48:12
# Epoch 1/50 - batch 2182/7760 - loss = 1.311 - accuracy = 0.414 - elapsed = 0:42:20 - ETA = 1:48:11
# Epoch 1/50 - batch 2183/7760 - loss = 1.343 - accuracy = 0.414 - elapsed = 0:42:21 - ETA = 1:48:10
# Epoch 1/50 - batch 2184/7760 - loss = 1.058 - accuracy = 0.414 - elapsed = 0:42:22 - ETA = 1:48:09
# Epoch 1/50 - batch 2185/7760 - loss = 1.410 - accuracy = 0.414 - elapsed = 0:42:24 - ETA = 1:48:08
# Epoch 1/50 - batch 2186/7760 - loss = 1.111 - accuracy = 0.414 - elapsed = 0:42:25 - ETA = 1:48:07
# Epoch 1/50 - batch 2187/7760 - loss = 1.619 - accuracy = 0.414 - elapsed = 0:42:26 - ETA = 1:48:06
# Epoch 1/50 - batch 2188/7760 - loss = 1.252 - accuracy = 0.414 - elapsed = 0:42:27 - ETA = 1:48:04
# Epoch 1/50 - batch 2189/7760 - loss = 1.422 - accuracy = 0.414 - elapsed = 0:42:28 - ETA = 1:48:03
# Epoch 1/50 - batch 2190/7760 - loss = 1.343 - accuracy = 0.414 - elapsed = 0:42:29 - ETA = 1:48:02
# Epoch 1/50 - batch 2191/7760 - loss = 1.458 - accuracy = 0.414 - elapsed = 0:42:31 - ETA = 1:48:01
# Epoch 1/50 - batch 2192/7760 - loss = 1.158 - accuracy = 0.414 - elapsed = 0:42:32 - ETA = 1:48:00
# Epoch 1/50 - batch 2193/7760 - loss = 1.585 - accuracy = 0.414 - elapsed = 0:42:33 - ETA = 1:47:59
# Epoch 1/50 - batch 2194/7760 - loss = 1.124 - accuracy = 0.414 - elapsed = 0:42:34 - ETA = 1:47:58
# Epoch 1/50 - batch 2195/7760 - loss = 1.395 - accuracy = 0.414 - elapsed = 0:42:35 - ETA = 1:47:56
# Epoch 1/50 - batch 2196/7760 - loss = 1.492 - accuracy = 0.414 - elapsed = 0:42:36 - ETA = 1:47:55
# Epoch 1/50 - batch 2197/7760 - loss = 1.712 - accuracy = 0.414 - elapsed = 0:42:38 - ETA = 1:47:54
# Epoch 1/50 - batch 2198/7760 - loss = 1.451 - accuracy = 0.414 - elapsed = 0:42:39 - ETA = 1:47:53
# Epoch 1/50 - batch 2199/7760 - loss = 1.484 - accuracy = 0.414 - elapsed = 0:42:40 - ETA = 1:47:52
# Epoch 1/50 - batch 2200/7760 - loss = 1.583 - accuracy = 0.414 - elapsed = 0:42:41 - ETA = 1:47:50
# Epoch 1/50 - batch 2201/7760 - loss = 1.436 - accuracy = 0.414 - elapsed = 0:42:42 - ETA = 1:47:49
# Epoch 1/50 - batch 2202/7760 - loss = 1.396 - accuracy = 0.414 - elapsed = 0:42:43 - ETA = 1:47:48
# Epoch 1/50 - batch 2203/7760 - loss = 1.744 - accuracy = 0.414 - elapsed = 0:42:45 - ETA = 1:47:47
# Epoch 1/50 - batch 2204/7760 - loss = 1.620 - accuracy = 0.414 - elapsed = 0:42:46 - ETA = 1:47:46
# Epoch 1/50 - batch 2205/7760 - loss = 1.627 - accuracy = 0.414 - elapsed = 0:42:47 - ETA = 1:47:45
# Epoch 1/50 - batch 2206/7760 - loss = 1.150 - accuracy = 0.414 - elapsed = 0:42:48 - ETA = 1:47:43
# Epoch 1/50 - batch 2207/7760 - loss = 1.390 - accuracy = 0.414 - elapsed = 0:42:49 - ETA = 1:47:42
# Epoch 1/50 - batch 2208/7760 - loss = 1.048 - accuracy = 0.414 - elapsed = 0:42:50 - ETA = 1:47:41
# Epoch 1/50 - batch 2209/7760 - loss = 1.448 - accuracy = 0.414 - elapsed = 0:42:52 - ETA = 1:47:40
# Epoch 1/50 - batch 2210/7760 - loss = 1.512 - accuracy = 0.414 - elapsed = 0:42:53 - ETA = 1:47:39
# Epoch 1/50 - batch 2211/7760 - loss = 1.361 - accuracy = 0.414 - elapsed = 0:42:54 - ETA = 1:47:37
# Epoch 1/50 - batch 2212/7760 - loss = 1.307 - accuracy = 0.414 - elapsed = 0:42:55 - ETA = 1:47:36
# Epoch 1/50 - batch 2213/7760 - loss = 1.514 - accuracy = 0.414 - elapsed = 0:42:56 - ETA = 1:47:35
# Epoch 1/50 - batch 2214/7760 - loss = 1.170 - accuracy = 0.414 - elapsed = 0:42:57 - ETA = 1:47:34
# Epoch 1/50 - batch 2215/7760 - loss = 1.415 - accuracy = 0.414 - elapsed = 0:42:58 - ETA = 1:47:33
# Epoch 1/50 - batch 2216/7760 - loss = 1.407 - accuracy = 0.414 - elapsed = 0:43:00 - ETA = 1:47:32
# Epoch 1/50 - batch 2217/7760 - loss = 1.289 - accuracy = 0.414 - elapsed = 0:43:01 - ETA = 1:47:30
# Epoch 1/50 - batch 2218/7760 - loss = 1.018 - accuracy = 0.414 - elapsed = 0:43:02 - ETA = 1:47:29
# Epoch 1/50 - batch 2219/7760 - loss = 1.649 - accuracy = 0.414 - elapsed = 0:43:03 - ETA = 1:47:28
# Epoch 1/50 - batch 2220/7760 - loss = 1.057 - accuracy = 0.414 - elapsed = 0:43:04 - ETA = 1:47:27
# Epoch 1/50 - batch 2221/7760 - loss = 1.728 - accuracy = 0.414 - elapsed = 0:43:05 - ETA = 1:47:26
# Epoch 1/50 - batch 2222/7760 - loss = 1.310 - accuracy = 0.414 - elapsed = 0:43:07 - ETA = 1:47:25
# Epoch 1/50 - batch 2223/7760 - loss = 1.204 - accuracy = 0.414 - elapsed = 0:43:08 - ETA = 1:47:24
# Epoch 1/50 - batch 2224/7760 - loss = 1.243 - accuracy = 0.414 - elapsed = 0:43:09 - ETA = 1:47:22
# Epoch 1/50 - batch 2225/7760 - loss = 1.337 - accuracy = 0.414 - elapsed = 0:43:10 - ETA = 1:47:21
# Epoch 1/50 - batch 2226/7760 - loss = 1.333 - accuracy = 0.414 - elapsed = 0:43:11 - ETA = 1:47:20
# Epoch 1/50 - batch 2227/7760 - loss = 1.783 - accuracy = 0.414 - elapsed = 0:43:13 - ETA = 1:47:19
# Epoch 1/50 - batch 2228/7760 - loss = 1.221 - accuracy = 0.414 - elapsed = 0:43:14 - ETA = 1:47:18
# Epoch 1/50 - batch 2229/7760 - loss = 1.796 - accuracy = 0.414 - elapsed = 0:43:15 - ETA = 1:47:17
# Epoch 1/50 - batch 2230/7760 - loss = 1.351 - accuracy = 0.414 - elapsed = 0:43:16 - ETA = 1:47:16
# Epoch 1/50 - batch 2231/7760 - loss = 1.470 - accuracy = 0.414 - elapsed = 0:43:17 - ETA = 1:47:14
# Epoch 1/50 - batch 2232/7760 - loss = 1.341 - accuracy = 0.414 - elapsed = 0:43:18 - ETA = 1:47:13
# Epoch 1/50 - batch 2233/7760 - loss = 1.685 - accuracy = 0.414 - elapsed = 0:43:20 - ETA = 1:47:12
# Epoch 1/50 - batch 2234/7760 - loss = 1.313 - accuracy = 0.414 - elapsed = 0:43:21 - ETA = 1:47:11
# Epoch 1/50 - batch 2235/7760 - loss = 1.449 - accuracy = 0.414 - elapsed = 0:43:22 - ETA = 1:47:10
# Epoch 1/50 - batch 2236/7760 - loss = 1.265 - accuracy = 0.414 - elapsed = 0:43:23 - ETA = 1:47:09
# Epoch 1/50 - batch 2237/7760 - loss = 1.368 - accuracy = 0.414 - elapsed = 0:43:24 - ETA = 1:47:08
# Epoch 1/50 - batch 2238/7760 - loss = 1.257 - accuracy = 0.414 - elapsed = 0:43:25 - ETA = 1:47:06
# Epoch 1/50 - batch 2239/7760 - loss = 1.475 - accuracy = 0.414 - elapsed = 0:43:27 - ETA = 1:47:05
# Epoch 1/50 - batch 2240/7760 - loss = 1.110 - accuracy = 0.414 - elapsed = 0:43:28 - ETA = 1:47:04
# Epoch 1/50 - batch 2241/7760 - loss = 1.492 - accuracy = 0.414 - elapsed = 0:43:29 - ETA = 1:47:03
# Epoch 1/50 - batch 2242/7760 - loss = 1.502 - accuracy = 0.414 - elapsed = 0:43:30 - ETA = 1:47:02
# Epoch 1/50 - batch 2243/7760 - loss = 1.490 - accuracy = 0.414 - elapsed = 0:43:31 - ETA = 1:47:01
# Epoch 1/50 - batch 2244/7760 - loss = 1.363 - accuracy = 0.414 - elapsed = 0:43:32 - ETA = 1:46:59
# Epoch 1/50 - batch 2245/7760 - loss = 1.550 - accuracy = 0.414 - elapsed = 0:43:34 - ETA = 1:46:58
# Epoch 1/50 - batch 2246/7760 - loss = 1.279 - accuracy = 0.414 - elapsed = 0:43:35 - ETA = 1:46:57
# Epoch 1/50 - batch 2247/7760 - loss = 1.272 - accuracy = 0.414 - elapsed = 0:43:36 - ETA = 1:46:56
# Epoch 1/50 - batch 2248/7760 - loss = 1.444 - accuracy = 0.415 - elapsed = 0:43:37 - ETA = 1:46:55
# Epoch 1/50 - batch 2249/7760 - loss = 1.225 - accuracy = 0.415 - elapsed = 0:43:38 - ETA = 1:46:54
# Epoch 1/50 - batch 2250/7760 - loss = 1.366 - accuracy = 0.415 - elapsed = 0:43:39 - ETA = 1:46:53
# Epoch 1/50 - batch 4371/7760 - loss = 1.240 - accuracy = 0.433 - elapsed = 1:24:49 - ETA = 1:05:45
# Epoch 1/50 - batch 4372/7760 - loss = 1.492 - accuracy = 0.433 - elapsed = 1:24:51 - ETA = 1:05:44
# Epoch 1/50 - batch 4373/7760 - loss = 1.030 - accuracy = 0.433 - elapsed = 1:24:52 - ETA = 1:05:43
# Epoch 1/50 - batch 4374/7760 - loss = 1.570 - accuracy = 0.433 - elapsed = 1:24:53 - ETA = 1:05:42
# Epoch 1/50 - batch 4375/7760 - loss = 1.127 - accuracy = 0.433 - elapsed = 1:24:54 - ETA = 1:05:40
# Epoch 1/50 - batch 4376/7760 - loss = 1.600 - accuracy = 0.433 - elapsed = 1:24:55 - ETA = 1:05:39

# %%
def test():
    accuracy = 0.
    val_gen = val_set.batch_gen(batch_size,shuffle=True)
    total_time = 0
    n_batches = val_set.N//batch_size + 1
    for idx,(images,questions,question_mask,answers,
             multiple_choice,bounding_boxes,sizes) in enumerate(val_gen):
        tic = time()
        feed_dict = {Pl['images']:images,
                     Pl['boxes']:bounding_boxes,
                     Pl['questions']:questions,
                     Pl['question_mask']:question_mask, 
                     Pl['answers']:answers,
                     Pl['mc']:multiple_choice}
        y_pred = sess.run(out_probas,feed_dict=feed_dict).argmax(axis=1)
        accuracy += np.sum(answers[np.arange(batch_size),y_pred])
        step_time = time()-tic
        total_time += step_time
        eta = total_time*(n_batches-idx)/(idx+1)
        print("\tTest: %d/%d - accuracy = %1.3f -  ETA = %s" % (idx,
                                                                val_set.N/batch_size,
                                                                accuracy/(batch_size*(idx+1)),
                                                                datetime.timedelta(seconds=int(eta))))
    return accuracy / (batch_size*(idx+1))

# %%
break_all = False
n_epochs = 100
n_batches = train_set.N//batch_size
output_file = open(join(model_path,"output.txt"),'w')
loss_value = 0
best_test_acc = -1
for epoch in range(1,1+n_epochs):
    train_gen = train_set.batch_gen(batch_size,shuffle=True)
    epoch_loss = []
    total_tic = time()
    train_accuracy = 0.
    for idx,(images,questions,question_mask,answers,
             multiple_choice,bounding_boxes,sizes) in enumerate(train_gen):
        tic = time()
        step = idx + (epoch-1)*n_batches
        
        feed_dict = {Pl['images']:images,
                     Pl['boxes']:bounding_boxes,
                     Pl['questions']:questions,
                     Pl['question_mask']:question_mask, 
                     Pl['answers']:answers,
                     Pl['mc']:multiple_choice}
        
        _,loss_value,loss_s,y_pred = sess.run([train_op,cost,cost_s,out_probas],feed_dict=feed_dict)
        y_pred = y_pred.argmax(axis=1)
        train_accuracy += np.sum(answers[np.arange(batch_size),y_pred])
        writer.add_summary(loss_s,step)
        toc = time()
        step_time = toc - tic
        total_time = toc - total_tic
        eta = total_time*(n_batches-idx)/(idx+1)
        print("Epoch %d/%d - batch %d/%d - loss = %1.3f - accuracy = %1.3f - " \
        "step time = %1.1fs - ETA = %s" % (epoch,n_epochs,
                                          idx,n_batches,
                                          loss_value,train_accuracy/(batch_size*(idx+1)),step_time,
                                          str(datetime.timedelta(seconds=int(eta)))))
        epoch_loss.append(loss_value)
        if np.isnan(loss_value):
            print("Loss is nan, i get out")
            break_all = True
        if break_all:
            break
    if break_all:
        break
    train_accuracy = train_accuracy / (batch_size*(idx+1))
    train_loss = np.mean(epoch_loss)
    output_file.write("Epoch %d - \n\ttrain loss = %1.3f - train accuracy = %1.3f\n" % (epoch,train_loss,train_accuracy))
    output_file.flush()
    print("test")
    if not epoch%5:
        test_acc = test()
        if test_acc > best_test_acc:
            print("Saving model...")
            saver.save(sess, join(model_path,'model'), global_step=epoch)
        output_file.write('\ttest accuracy = %1.3f\n' % test_acc)
        output_file.flush()
        best_test_acc = max(best_test_acc,test_acc)
output_file.close()
# Out:
# Epoch 1/100 - batch 0/7760 - loss = 2.834 - accuracy = 0.188 - step time = 3.5s - ETA = 9:36:29
# Epoch 1/100 - batch 1/7760 - loss = 2.533 - accuracy = 0.250 - step time = 1.2s - ETA = 7:17:39
# Epoch 1/100 - batch 2/7760 - loss = 2.813 - accuracy = 0.229 - step time = 1.2s - ETA = 6:25:53
# Epoch 1/100 - batch 3/7760 - loss = 2.767 - accuracy = 0.219 - step time = 1.2s - ETA = 6:01:06
# Epoch 1/100 - batch 4/7760 - loss = 2.488 - accuracy = 0.206 - step time = 1.2s - ETA = 5:47:04
# Epoch 1/100 - batch 5/7760 - loss = 2.582 - accuracy = 0.208 - step time = 1.2s - ETA = 5:37:10
# Epoch 1/100 - batch 6/7760 - loss = 2.428 - accuracy = 0.228 - step time = 1.2s - ETA = 5:28:36
# Epoch 1/100 - batch 7/7760 - loss = 2.397 - accuracy = 0.238 - step time = 1.2s - ETA = 5:22:04
# Epoch 1/100 - batch 8/7760 - loss = 2.547 - accuracy = 0.243 - step time = 1.2s - ETA = 5:17:13
# Epoch 1/100 - batch 9/7760 - loss = 2.522 - accuracy = 0.241 - step time = 1.2s - ETA = 5:14:20
# Epoch 1/100 - batch 10/7760 - loss = 2.701 - accuracy = 0.233 - step time = 1.2s - ETA = 5:13:44
# Epoch 1/100 - batch 11/7760 - loss = 2.378 - accuracy = 0.237 - step time = 1.2s - ETA = 5:11:06
# Epoch 1/100 - batch 12/7760 - loss = 2.485 - accuracy = 0.240 - step time = 1.2s - ETA = 5:09:13
