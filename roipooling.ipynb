# %%
from os.path import exists
from os import mkdir
from os.path import join
from PIL import Image
import json


import tensorflow as tf
import roi_pooling_op_grad
module = tf.load_op_library('/Programs/tensorflow/roi_pooling.so')
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

from utils import load_vocab
from time import time
import datetime

# %%
def load_image(p):
    img = Image.open(p)
    if img.mode is not 'RGB':
        img = img.convert('RGB')
    treated_img = img.resize((448,448))
    treated_img = np.array(treated_img) / 255.0
    assert (0 <= treated_img).all() and (treated_img <= 1.0).all()
    return treated_img,img


def load_dataset(idxs_path,mc=False):
    dataset = []
    for l in open(idxs_path, 'r',encoding='latin1'):
        l = l.lower().strip().strip('.').strip('?')
        if mc:
            l = [[int(i) for i in ans.strip().split()] for ans in l.strip().split('|')]
        else:
            l = [int(i) for i in l.strip().split()]
        dataset.append(l)
    return dataset

class Dataset(object):
    def __init__(self, i_path, q_path, mc_path, a_path, bb_path, n_max=np.Inf):
        self.i_path = i_path
        self.q_path = q_path
        self.a_path = a_path
        self.mc_path = mc_path
        self.bb_path = bb_path
        print('Parse questions file')
        q_data = load_dataset(self.q_path)
        self.max_q = len(max(q_data, key=lambda x:len(x)))
        print('Parse answers file')
        a_data = load_dataset(self.a_path)
        print('Parse MC file')
        mc_data = load_dataset(self.mc_path,mc=True)
        self.max_mc = 0
        for mc in mc_data:
            for x in mc:
                self.max_mc = max(self.max_mc,len(x))
        print('Parse BB file')
        self.bboxes = {}
        for l in open(self.bb_path):
            if l.endswith('\n'):
                l = json.loads(l)
                self.bboxes.update(l)
        print("Construct data array")
        self.data = []
        self.max_bb = -np.Inf
        for i_id,q,mc,a in zip(open(i_path),q_data,mc_data,a_data):
            i_id = i_id.strip()
            if i_id not in self.bboxes:
                continue
            bb = self.bboxes[i_id]
            self.max_bb = max(self.max_bb,len(bb))
            datum = (i_id,bb,q,mc,a)
            self.data.append(datum)
        self.data = np.array(self.data, dtype=object)
        del q_data,a_data
        self.N = len(self.data)
        self.indexes = np.arange(self.N)
    
    def __iter__(self):
        return self
    
    def batch_gen(self,batch_size=64,shuffle=True):
        if shuffle:
            np.random.shuffle(self.indexes)
        n_batches = self.N // batch_size
        for batch_id in range(n_batches):
            begin = batch_id*batch_size
            end = min((batch_id+1)*batch_size, self.N)
            B = self.data[self.indexes[begin:end]]
            yield B

print("Loading train set")
train_set = Dataset("datasets/vqa/train/img_ids.txt",
                   "datasets/vqa/train/questions.idxs", 
                   "datasets/vqa/train/mcs.idxs", 
                   "datasets/vqa/train/answers.idxs",
                   "datasets/vqa/train/bounding_boxes.json")
val_set = Dataset("datasets/vqa/val/img_ids.txt",
                   "datasets/vqa/val/questions.idxs", 
                   "datasets/vqa/val/mcs.idxs", 
                   "datasets/vqa/val/answers.idxs",
                   "datasets/vqa/val/bounding_boxes.json")
max_bb = train_set.max_bb
max_q = train_set.max_q
max_mc = train_set.max_mc
# Out:
# Loading train set
# Parse questions file
# Parse answers file
# Parse MC file
# Parse BB file
# Construct data array
# Parse questions file
# Parse answers file
# Parse MC file
# Parse BB file
# Construct data array

# %%
D = 0
C = 0
train_gen = train_set.batch_gen()
for batch in train_gen:
    for batch_id,(i_id,bb,q,mc,a) in enumerate(batch):
        if sum([x==a for x in mc]) == 0:
            C += 1
        if min(len(x) for x in mc) == 0:
            D += 1
print(C,D)
# Out:
# 0 3

# %%
q_i2w, q_w2i = load_vocab('datasets/vqa/train/questions.vocab')
a_i2w, a_w2i = load_vocab('datasets/vqa/train/answers.vocab')
Nq = len(q_i2w)
Na = len(a_i2w)

# %%
image_paths = {}
root_path = "/srv/data/datasets/mscoco/images/"

for split in 'train val'.split():
    image_ids_path = "datasets/vqa/"+split+"/img_ids.txt"
    image_ids = set([int(x.strip()) for x in open(image_ids_path).readlines()])
    print(split,len(image_ids))
    for x in image_ids:
        name = 'COCO_'+split+'2014_'+format(x, '012')+'.jpg'
        path = join(root_path,split+"2014",name)
        image_paths[str(x)] = path
# Out:
# train 82783
# val 40504

# %%
tf.reset_default_graph()
# Read the model
with open("tensorflow-vgg16/vgg16.tfmodel",
          mode='rb') as f:
    fileContent = f.read()
graph_def = tf.GraphDef()
# Put it into my graph_def
graph_def.ParseFromString(fileContent)
graph = tf.get_default_graph()

weights_names = ["import/fc6/weight:0", 
                 "import/fc7/weight:0",
                 "import/fc8/weight:0"]
biases_names = ["import/fc6/bias:0", 
                "import/fc7/bias:0",
                "import/fc8/bias:0"]
fc_shapes = [4096,4096,1000]
layer_number = 2
#di = graph.get_tensor_by_name(weights_names[layer_number-1]).get_shape()[-1].value
def pool5_tofcX(input_tensor, layer_number=layer_number):
    flatten=tf.reshape(input_tensor,(-1,7*7*512))
    tmp=flatten
    for i in range(layer_number):
        tmp=tf.matmul(tmp, graph.get_tensor_by_name(weights_names[i]))
        tmp=tf.nn.bias_add(tmp, graph.get_tensor_by_name(biases_names[i]))
        tmp = tf.nn.relu(tmp)
    return tmp

# %%
batch_size = 32
di = fc_shapes[layer_number-1]
dv = 300
dq = 200
dh = 200
datt = 200
Nq = train_set.N
with tf.variable_scope('image'):
    tf.get_variable('W', shape=[di, dv],
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable(name='b',
                    initializer=tf.zeros([dv]))

with tf.variable_scope('question'):
    tf.get_variable('W',
                    initializer=tf.random_uniform([Nq, dq], -0.1, 0.1))
    
with tf.variable_scope('attention'):
    tf.get_variable('Wimg',shape=[dv,datt],
                    initializer=tf.contrib.layers.xavier_initializer())
    tf.get_variable('Wstate',shape=[dh,datt],
                    initializer=tf.contrib.layers.xavier_initializer())
    
with tf.variable_scope('multiple_choice'):
    tf.get_variable('W',
                    initializer=tf.random_uniform([Na, dh], -0.1, 0.1))

rnn = tf.nn.rnn_cell.GRUCell(dh)

Pl = {}
Pl['images'] = tf.placeholder(tf.float32, 
                              [batch_size, 448, 448, 3],
                              name="images") #batch x width x height x channels
Pl['boxes'] = tf.placeholder(tf.float32, 
                             [None,5],
                             name = "boxes")
Pl['n_boxes'] = tf.placeholder(tf.float32,
                               [None],
                               name="n_boxes")
Pl['questions'] = tf.placeholder(tf.int32, 
                                 [batch_size, max_q],
                                 name="question")
Pl['question_mask'] = tf.placeholder(tf.int32,
                                     [max_q, None],
                                     name="question_mask")

Pl['mc'] = tf.placeholder(tf.int32,
                          [batch_size, 18,None], 
                          name="mc")
Pl['answers'] = tf.placeholder(tf.float32, 
                               [batch_size,18], 
                               name="answers")


def compute_attention(V,state):
    with tf.variable_scope('attention',reuse=True):
        Wimg = tf.get_variable('Wimg')
        Wstate = tf.get_variable('Wstate')
        Vatt = tf.transpose(tf.tanh(tf.reshape(tf.matmul(tf.reshape(V, 
                                                       (batch_size*max_bb,dv)),
                                             Wimg),
                                   (max_bb,batch_size,datt))),(1,0,2))
        Hatt = tf.expand_dims(tf.matmul(state,Wstate),1)
        att = tf.batch_matmul(Vatt,Hatt,adj_y=True)
        patt = tf.nn.softmax(att[:,:,0])
        Vpond = tf.mul(V,tf.expand_dims(patt,-1))
        Vt = tf.reduce_sum(Vpond,reduction_indices=1)
        return Vt

tf.import_graph_def(graph_def, 
                    input_map={'images':Pl['images']})

out_tensor = graph.get_tensor_by_name("import/conv5_3/Relu:0")
# Don't do your max pooling, but the roi_pooling
[out_pool,argmax] = module.roi_pool(out_tensor,
                                    Pl['boxes'],
                                    7,7,1.0/1) # out_pool.shape = N_Boxes x 7 x 7 x 512
boxes_emb = pool5_tofcX(out_pool,layer_number=layer_number)
with tf.variable_scope('image',reuse=True):
    W = tf.get_variable("W")
    b = tf.get_variable("b")
V = tf.tanh(tf.matmul(boxes_emb,W) + b)
V = tf.reshape(V,(batch_size,100,dv))

state = rnn.zero_state(batch_size, tf.float32)
states = []
q_out = []
with tf.variable_scope('question',reuse=True):
    W = tf.get_variable('W')
for j in range(max_q):
    question_emb = tf.nn.embedding_lookup(W, Pl['questions'][:,j])
    if j>0:
        tf.get_variable_scope().reuse_variables()
    Vt = compute_attention(V,state)
    output,state = rnn(tf.concat(1,[question_emb,Vt]), state)
    states.append(state)
    q_out.append(output)
q_out = tf.pack(q_out)
q_out = tf.reduce_sum(tf.mul(q_out, 
                             tf.to_float(tf.expand_dims(Pl['question_mask'],-1))),0)

mc_mask = tf.to_float(tf.not_equal(Pl['mc'],a_w2i['</s>']))
norm_mask = tf.expand_dims(tf.reduce_sum(mc_mask,reduction_indices=2),-1)
with tf.variable_scope('multiple_choice'):
    W = tf.get_variable('W')
    mc_emb = tf.nn.embedding_lookup(W, Pl['mc'])
    masked_mc_out = tf.mul(tf.expand_dims(mc_mask,-1),mc_emb)
    mc_out = tf.reduce_sum(masked_mc_out,reduction_indices=2)/norm_mask
    
out_scores = tf.batch_matmul(mc_out,tf.expand_dims(q_out,1),adj_y=True)[:,:,0]
out_probas = tf.nn.softmax(out_scores)

normalized_ans = Pl['answers'] / tf.expand_dims(tf.reduce_sum(Pl['answers'],reduction_indices=1),-1)
cross_entropy = normalized_ans*tf.log(out_probas) + (1.-normalized_ans)*tf.log(1.-out_probas)
cost = -tf.reduce_sum(cross_entropy)/batch_size

optimizer = tf.train.AdamOptimizer()
#optimizer = tf.train.GradientDescentOptimizer(0.01)
gvs = optimizer.compute_gradients(cost)
# with tf.device('/cpu:0'):
cost_s = tf.scalar_summary('train loss', cost, name='train_loss')
capped_gvs = [(tf.clip_by_value(grad, -1., 1.), var) for grad,var in gvs]
train_op = optimizer.apply_gradients(capped_gvs)
# Out:
# boxes:0 (?, 5)

# %%
model_name = "model1"
model_rootpath = "/hhome/hbenyounes/vqa/results/vqa/"
model_path = join(model_rootpath,model_name)
if not exists(model_path):
    mkdir(model_path)

gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.7)

sess = tf.Session(config=tf.ConfigProto(log_device_placement=True,
                                        gpu_options=gpu_options))

writer = tf.train.SummaryWriter(join(model_path,'tf_log'), sess.graph)
saver = tf.train.Saver(max_to_keep=100)
init = tf.initialize_all_variables()
sess.run(init)

# %%
def create_feeddict(batch):
    boxes = np.zeros((batch_size*max_bb,5),dtype='int')
    images = np.zeros((batch_size,448,448,3))
    question_mask = np.zeros((max_q,batch_size),dtype="float")
    questions = np.zeros((batch_size,max_q), dtype='int')
    answers = np.zeros((batch_size,18),dtype="float")
    multiple_choice = []
    mc_len = 0
    for batch_id,(i_id,bb,q,mc,a) in enumerate(batch):
        # b = (i_id,bb,q,mc,a)
        p = image_paths[i_id]
        im_l,im = load_image(p)
        images[batch_id] = im_l
        box = np.array([[batch_id] + bb[i % len(bb)] for i in range(100)])
        box[:,[1,3]] = (box[:,[1,3]]*im_l.shape[1]/im.size[1])/16
        box[:,[2,4]] = (box[:,[2,4]]*im_l.shape[0]/im.size[0])/16 + box[:,[1,3]]
        boxes[batch_id*max_bb:(batch_id+1)*max_bb] = box
        questions[batch_id] = np.pad(q,(0,max_q-len(q)),'constant')
        question_mask[len(q)-1,batch_id] = 1
        multiple_choice.append(mc)
        for i,x in enumerate(mc):
            if len(x) == 0:
                x = [a_w2i["<unk>"]]
                mc[i] = [a_w2i["<unk>"]]
            answers[batch_id,i] = 1*(a==x)
        mc_len = max(mc_len,len(max([x for x in mc], key=len)))
        
    multiple_choice = np.array([[np.pad(m,(0,mc_len+1-len(m)),
                                        'constant',
                                        constant_values=a_w2i['</s>']) for m in mc] for mc in multiple_choice])
    feed_dict = {Pl['images']: images,
                 Pl['boxes']:boxes, 
                 Pl['questions']:questions,
                 Pl['question_mask']:question_mask, 
                 Pl['answers']:answers,
                 Pl['mc']:multiple_choice}
    
    return feed_dict

def test():
    accuracy = 0.
    val_gen = val_set.batch_gen(batch_size,shuffle=True)
    total_time = 0
    for idx,batch in enumerate(val_gen):
        tic = time()
        feed_dict = create_feeddict(batch)
        y_pred = sess.run(out_probas,feed_dict=feed_dict).argmax(axis=1)
        accuracy += np.sum(feed_dict[Pl['answers']][np.arange(batch_size),y_pred])
        step_time = time()-tic
        total_time += step_time
        eta = total_time*(n_batches-idx)/(idx+1)
        print("\tTest: %d/%d - accuracy = %1.3f -  ETA = %s" % (idx,
                                                                val_set.N/batch_size,
                                                                accuracy/(batch_size*(idx+1)),
                                                                datetime.timedelta(seconds=int(eta))))
    return accuracy / (batch_size*(idx+1))

# %%
break_all = False
n_epochs = 100
n_batches = train_set.N//batch_size + 1
output_file = open(join(model_path,"output.txt"),'w')
loss_value = 0
for epoch in range(1,1+n_epochs):
    train_gen = train_set.batch_gen(batch_size,shuffle=True)
    epoch_loss = []
    total_time = 0.
    for idx,batch in enumerate(train_gen):
        tic = time()
        step = idx + (epoch-1)*n_batches
        feed_dict = create_feeddict(batch)
        _,loss_value,loss_s = sess.run([train_op,cost,cost_s],feed_dict=feed_dict)
        writer.add_summary(loss_s,step)
        step_time = time() - tic
        total_time += step_time
        eta = total_time*(n_batches-idx)/(idx+1)
        print("Epoch %d/%d - batch %d/%d - loss = %1.3f - " \
        "step time = %1.1fs - ETA = %s" % (epoch,n_epochs,
                                          idx,n_batches,
                                          loss_value,step_time,
                                          str(datetime.timedelta(seconds=int(eta)))))
        epoch_loss.append(loss_value)
        if np.isnan(loss_value):
            print("Loss is nan, i get out")
            break_all = True
        if break_all:
            break
    if break_all:
        break
    print("test")
    test_acc = test()
    train_loss = np.mean(epoch_loss)
    output_file.write("Epoch %d - train loss = %1.3f - test accuracy = %1.3f\n" % (epoch,train_loss,test_acc))
    output_file.flush()
    saver.save(sess, join(model_path,'model'), global_step=epoch)
output_file.close()
# Out:
# Epoch 1/100 - batch 0/7761 - loss = 3.874 - step time = 5.6s - ETA = 12:08:42
# Epoch 1/100 - batch 1/7761 - loss = 3.948 - step time = 3.0s - ETA = 9:17:01
# Epoch 1/100 - batch 2/7761 - loss = 3.624 - step time = 2.9s - ETA = 8:18:27
# Epoch 1/100 - batch 3/7761 - loss = 3.558 - step time = 4.6s - ETA = 8:43:05
# Epoch 1/100 - batch 4/7761 - loss = 3.623 - step time = 4.3s - ETA = 8:49:03
# Epoch 1/100 - batch 5/7761 - loss = 3.946 - step time = 2.9s - ETA = 8:22:14
# Epoch 1/100 - batch 6/7761 - loss = 3.732 - step time = 2.8s - ETA = 8:01:45
# Epoch 1/100 - batch 7/7761 - loss = 3.813 - step time = 2.8s - ETA = 7:46:22
# Epoch 1/100 - batch 8/7761 - loss = 3.591 - step time = 2.8s - ETA = 7:34:47
# Epoch 1/100 - batch 9/7761 - loss = 3.880 - step time = 2.8s - ETA = 7:25:13
# Epoch 1/100 - batch 10/7761 - loss = 3.624 - step time = 2.6s - ETA = 7:14:52
# Epoch 1/100 - batch 11/7761 - loss = 3.777 - step time = 2.5s - ETA = 7:05:37
# Epoch 1/100 - batch 12/7761 - loss = 3.613 - step time = 2.6s - ETA = 6:58:11
# Epoch 1/100 - batch 13/7761 - loss = 3.833 - step time = 2.4s - ETA = 6:50:43
# Epoch 1/100 - batch 14/7761 - loss = 3.653 - step time = 2.6s - ETA = 6:45:27
# Epoch 1/100 - batch 15/7761 - loss = 3.387 - step time = 2.6s - ETA = 6:40:52
# Epoch 1/100 - batch 16/7761 - loss = 3.444 - step time = 2.5s - ETA = 6:36:04
# Epoch 1/100 - batch 17/7761 - loss = 3.360 - step time = 2.7s - ETA = 6:33:02
# Epoch 1/100 - batch 18/7761 - loss = 3.276 - step time = 2.6s - ETA = 6:30:05
# Epoch 1/100 - batch 19/7761 - loss = 3.628 - step time = 2.5s - ETA = 6:26:29
# Epoch 1/100 - batch 20/7761 - loss = 3.296 - step time = 2.6s - ETA = 6:23:46
# Epoch 1/100 - batch 21/7761 - loss = 3.379 - step time = 2.4s - ETA = 6:20:23
# Epoch 1/100 - batch 22/7761 - loss = 3.279 - step time = 2.6s - ETA = 6:18:39
# Epoch 1/100 - batch 23/7761 - loss = 3.561 - step time = 2.5s - ETA = 6:16:12
# Epoch 1/100 - batch 24/7761 - loss = 3.426 - step time = 2.4s - ETA = 6:13:30
# Epoch 1/100 - batch 25/7761 - loss = 3.400 - step time = 2.6s - ETA = 6:12:11

# %%
break_all = False
n_epochs = 100
n_batches = train_set.N//batch_size + 1
loss_value = 0
total_time = 0.
output_file = open(join(model_path,"output.txt"),'w')
epoch = 1
train_gen = train_set.batch_gen(batch_size,shuffle=False)
for idx,batch in enumerate(train_gen):
    if idx<5645:
        continue
    tic = time()
    step = idx + (epoch-1)*n_batches
    feed_dict = create_feeddict(batch)
    _,loss_value,loss_s = sess.run([train_op,cost,cost_s],feed_dict=feed_dict)
    writer.add_summary(loss_s,step)
    step_time = time() - tic
    total_time += step_time
    eta = total_time*(n_batches-idx)/(idx+1)
    print("Epoch %d/%d - batch %d/%d - loss = %1.3f - " \
    "step time = %1.1fs - ETA = %s" % (epoch,n_epochs,
                                      idx,n_batches,
                                      loss_value,step_time,
                                      str(datetime.timedelta(seconds=int(eta)))))
    epoch_loss.append(loss_value)
    if np.isnan(loss_value):
        print("Loss is nan, i get out")
        break_all = True
    if break_all:
        break
print("test")

# %%
test_acc = test()
train_loss = np.mean(epoch_loss)
output_file.write("Epoch %d - train loss = %1.3f - test accuracy = %1.3f\n" % (epoch,train_loss,test_acc))
output_file.flush()
saver.save(sess, join(model_path,'model'), global_step=epoch)
output_file.close()
# Out:
# 	Test: 0/3797 - accuracy = 0.438 -  ETA = 4:27:44
# 	Test: 1/3797 - accuracy = 0.438 -  ETA = 4:25:38
# 	Test: 2/3797 - accuracy = 0.427 -  ETA = 4:24:52
# 	Test: 3/3797 - accuracy = 0.453 -  ETA = 4:23:52
# 	Test: 4/3797 - accuracy = 0.463 -  ETA = 4:25:16
# 	Test: 5/3797 - accuracy = 0.479 -  ETA = 4:31:50
# 	Test: 6/3797 - accuracy = 0.469 -  ETA = 4:33:20
# 	Test: 7/3797 - accuracy = 0.465 -  ETA = 4:31:22
# 	Test: 8/3797 - accuracy = 0.465 -  ETA = 4:29:57
# 	Test: 9/3797 - accuracy = 0.459 -  ETA = 4:27:43
# 	Test: 10/3797 - accuracy = 0.455 -  ETA = 4:25:29
# 	Test: 11/3797 - accuracy = 0.451 -  ETA = 4:24:40
# 	Test: 12/3797 - accuracy = 0.452 -  ETA = 4:23:19
# 	Test: 13/3797 - accuracy = 0.435 -  ETA = 4:22:09
# 	Test: 14/3797 - accuracy = 0.435 -  ETA = 4:21:50
# 	Test: 15/3797 - accuracy = 0.443 -  ETA = 4:21:44
# 	Test: 16/3797 - accuracy = 0.458 -  ETA = 4:22:08
# 	Test: 17/3797 - accuracy = 0.457 -  ETA = 4:22:26
# 	Test: 18/3797 - accuracy = 0.462 -  ETA = 4:22:18
# 	Test: 19/3797 - accuracy = 0.461 -  ETA = 4:23:06
# 	Test: 20/3797 - accuracy = 0.460 -  ETA = 4:23:04
# 	Test: 21/3797 - accuracy = 0.453 -  ETA = 4:22:17
# 	Test: 22/3797 - accuracy = 0.459 -  ETA = 4:22:36
# 	Test: 23/3797 - accuracy = 0.460 -  ETA = 4:22:14
# 	Test: 24/3797 - accuracy = 0.459 -  ETA = 4:21:47
# 	Test: 25/3797 - accuracy = 0.459 -  ETA = 4:22:08
# 	Test: 26/3797 - accuracy = 0.457 -  ETA = 4:22:11
# 	Test: 27/3797 - accuracy = 0.460 -  ETA = 4:21:54
# 	Test: 28/3797 - accuracy = 0.461 -  ETA = 4:22:03
# 	Test: 29/3797 - accuracy = 0.464 -  ETA = 4:22:00
# 	Test: 30/3797 - accuracy = 0.462 -  ETA = 4:21:51
# 	Test: 31/3797 - accuracy = 0.465 -  ETA = 4:21:11
# 	Test: 32/3797 - accuracy = 0.464 -  ETA = 4:21:06
# 	Test: 33/3797 - accuracy = 0.469 -  ETA = 4:20:57
# 	Test: 34/3797 - accuracy = 0.475 -  ETA = 4:21:11
# 	Test: 35/3797 - accuracy = 0.478 -  ETA = 4:21:46
# 	Test: 36/3797 - accuracy = 0.478 -  ETA = 4:21:18
# 	Test: 37/3797 - accuracy = 0.479 -  ETA = 4:20:56
# 	Test: 38/3797 - accuracy = 0.482 -  ETA = 4:21:07
# 	Test: 39/3797 - accuracy = 0.484 -  ETA = 4:20:49
# 	Test: 40/3797 - accuracy = 0.486 -  ETA = 4:20:24
# 	Test: 41/3797 - accuracy = 0.482 -  ETA = 4:20:02
# 	Test: 42/3797 - accuracy = 0.481 -  ETA = 4:19:32
# 	Test: 43/3797 - accuracy = 0.480 -  ETA = 4:19:22
# 	Test: 44/3797 - accuracy = 0.479 -  ETA = 4:19:01
# 	Test: 45/3797 - accuracy = 0.484 -  ETA = 4:18:40
# 	Test: 46/3797 - accuracy = 0.485 -  ETA = 4:18:41
# 	Test: 47/3797 - accuracy = 0.485 -  ETA = 4:18:11
# 	Test: 48/3797 - accuracy = 0.484 -  ETA = 4:18:08
# 	Test: 49/3797 - accuracy = 0.487 -  ETA = 4:18:08
# 	Test: 50/3797 - accuracy = 0.485 -  ETA = 4:17:48
# 	Test: 51/3797 - accuracy = 0.482 -  ETA = 4:17:24
# 	Test: 52/3797 - accuracy = 0.483 -  ETA = 4:17:03
# 	Test: 53/3797 - accuracy = 0.483 -  ETA = 4:16:51
# 	Test: 54/3797 - accuracy = 0.484 -  ETA = 4:16:41
# 	Test: 55/3797 - accuracy = 0.483 -  ETA = 4:16:27
# 	Test: 56/3797 - accuracy = 0.482 -  ETA = 4:16:09
# 	Test: 57/3797 - accuracy = 0.481 -  ETA = 4:15:49
# 	Test: 58/3797 - accuracy = 0.483 -  ETA = 4:15:36
# 	Test: 59/3797 - accuracy = 0.482 -  ETA = 4:15:25
# 	Test: 60/3797 - accuracy = 0.483 -  ETA = 4:15:08
# 	Test: 61/3797 - accuracy = 0.484 -  ETA = 4:15:02
# 	Test: 62/3797 - accuracy = 0.483 -  ETA = 4:14:47
# 	Test: 63/3797 - accuracy = 0.482 -  ETA = 4:14:33
# 	Test: 64/3797 - accuracy = 0.482 -  ETA = 4:14:16
# 	Test: 65/3797 - accuracy = 0.480 -  ETA = 4:14:21
# 	Test: 66/3797 - accuracy = 0.481 -  ETA = 4:14:09
# 	Test: 67/3797 - accuracy = 0.483 -  ETA = 4:14:38
# 	Test: 68/3797 - accuracy = 0.484 -  ETA = 4:14:28
# 	Test: 69/3797 - accuracy = 0.483 -  ETA = 4:14:22
# 	Test: 70/3797 - accuracy = 0.482 -  ETA = 4:14:19
# 	Test: 71/3797 - accuracy = 0.484 -  ETA = 4:14:20
# 	Test: 72/3797 - accuracy = 0.483 -  ETA = 4:14:21
# 	Test: 73/3797 - accuracy = 0.483 -  ETA = 4:14:19
# 	Test: 74/3797 - accuracy = 0.482 -  ETA = 4:14:18
# 	Test: 75/3797 - accuracy = 0.481 -  ETA = 4:14:12
# 	Test: 76/3797 - accuracy = 0.481 -  ETA = 4:14:08
# 	Test: 77/3797 - accuracy = 0.484 -  ETA = 4:13:56
# 	Test: 78/3797 - accuracy = 0.483 -  ETA = 4:13:48
# 	Test: 79/3797 - accuracy = 0.484 -  ETA = 4:13:39
# 	Test: 80/3797 - accuracy = 0.484 -  ETA = 4:13:38
# 	Test: 81/3797 - accuracy = 0.482 -  ETA = 4:13:43
# 	Test: 82/3797 - accuracy = 0.485 -  ETA = 4:13:41
# 	Test: 83/3797 - accuracy = 0.485 -  ETA = 4:13:37
# 	Test: 84/3797 - accuracy = 0.485 -  ETA = 4:13:30
# 	Test: 85/3797 - accuracy = 0.485 -  ETA = 4:13:22
# 	Test: 86/3797 - accuracy = 0.487 -  ETA = 4:13:21
# 	Test: 87/3797 - accuracy = 0.487 -  ETA = 4:13:15
# 	Test: 88/3797 - accuracy = 0.486 -  ETA = 4:13:10
# 	Test: 89/3797 - accuracy = 0.487 -  ETA = 4:13:11
# 	Test: 90/3797 - accuracy = 0.488 -  ETA = 4:13:03
# 	Test: 91/3797 - accuracy = 0.488 -  ETA = 4:12:58
# 	Test: 92/3797 - accuracy = 0.488 -  ETA = 4:12:56
# 	Test: 93/3797 - accuracy = 0.486 -  ETA = 4:12:55
# 	Test: 94/3797 - accuracy = 0.486 -  ETA = 4:12:48
# 	Test: 95/3797 - accuracy = 0.486 -  ETA = 4:12:40
# 	Test: 96/3797 - accuracy = 0.486 -  ETA = 4:12:43
# 	Test: 97/3797 - accuracy = 0.487 -  ETA = 4:12:37
# 	Test: 98/3797 - accuracy = 0.487 -  ETA = 4:12:38
# 	Test: 99/3797 - accuracy = 0.489 -  ETA = 4:12:27
# 	Test: 100/3797 - accuracy = 0.488 -  ETA = 4:12:27
# 	Test: 101/3797 - accuracy = 0.488 -  ETA = 4:12:23
# 	Test: 102/3797 - accuracy = 0.487 -  ETA = 4:12:28
# 	Test: 103/3797 - accuracy = 0.488 -  ETA = 4:12:23
# 	Test: 104/3797 - accuracy = 0.488 -  ETA = 4:12:19
# 	Test: 105/3797 - accuracy = 0.487 -  ETA = 4:12:16
# 	Test: 106/3797 - accuracy = 0.488 -  ETA = 4:12:12
# 	Test: 107/3797 - accuracy = 0.489 -  ETA = 4:12:08
# 	Test: 108/3797 - accuracy = 0.488 -  ETA = 4:12:03
# 	Test: 109/3797 - accuracy = 0.488 -  ETA = 4:11:57
# 	Test: 110/3797 - accuracy = 0.488 -  ETA = 4:11:52
# 	Test: 111/3797 - accuracy = 0.487 -  ETA = 4:11:47
# 	Test: 112/3797 - accuracy = 0.487 -  ETA = 4:11:46
# 	Test: 113/3797 - accuracy = 0.487 -  ETA = 4:11:43
# 	Test: 114/3797 - accuracy = 0.487 -  ETA = 4:11:35
# 	Test: 115/3797 - accuracy = 0.488 -  ETA = 4:11:29
# 	Test: 116/3797 - accuracy = 0.489 -  ETA = 4:11:27
# 	Test: 117/3797 - accuracy = 0.489 -  ETA = 4:11:29
# 	Test: 118/3797 - accuracy = 0.489 -  ETA = 4:11:30
# 	Test: 119/3797 - accuracy = 0.489 -  ETA = 4:11:28
# 	Test: 120/3797 - accuracy = 0.489 -  ETA = 4:11:27
# 	Test: 121/3797 - accuracy = 0.490 -  ETA = 4:11:23
# 	Test: 122/3797 - accuracy = 0.489 -  ETA = 4:11:22
# 	Test: 123/3797 - accuracy = 0.489 -  ETA = 4:11:20
# 	Test: 124/3797 - accuracy = 0.488 -  ETA = 4:11:15
# 	Test: 125/3797 - accuracy = 0.488 -  ETA = 4:11:22
# 	Test: 126/3797 - accuracy = 0.487 -  ETA = 4:11:20
# 	Test: 127/3797 - accuracy = 0.487 -  ETA = 4:11:22
# 	Test: 128/3797 - accuracy = 0.488 -  ETA = 4:11:20
# 	Test: 129/3797 - accuracy = 0.488 -  ETA = 4:11:13
# 	Test: 130/3797 - accuracy = 0.487 -  ETA = 4:11:11
# 	Test: 131/3797 - accuracy = 0.487 -  ETA = 4:11:04
# 	Test: 132/3797 - accuracy = 0.488 -  ETA = 4:10:58
# 	Test: 133/3797 - accuracy = 0.488 -  ETA = 4:10:54
# 	Test: 134/3797 - accuracy = 0.488 -  ETA = 4:10:50
# 	Test: 135/3797 - accuracy = 0.488 -  ETA = 4:10:48
# 	Test: 136/3797 - accuracy = 0.489 -  ETA = 4:10:44
# 	Test: 137/3797 - accuracy = 0.490 -  ETA = 4:10:42
# 	Test: 138/3797 - accuracy = 0.491 -  ETA = 4:10:40
# 	Test: 139/3797 - accuracy = 0.492 -  ETA = 4:10:37
# 	Test: 140/3797 - accuracy = 0.492 -  ETA = 4:10:34
# 	Test: 141/3797 - accuracy = 0.492 -  ETA = 4:10:31
# 	Test: 142/3797 - accuracy = 0.491 -  ETA = 4:10:29
# 	Test: 143/3797 - accuracy = 0.491 -  ETA = 4:10:25
# 	Test: 144/3797 - accuracy = 0.490 -  ETA = 4:10:25
# 	Test: 145/3797 - accuracy = 0.491 -  ETA = 4:10:22
# 	Test: 146/3797 - accuracy = 0.491 -  ETA = 4:10:18
# 	Test: 147/3797 - accuracy = 0.492 -  ETA = 4:10:14
# 	Test: 148/3797 - accuracy = 0.492 -  ETA = 4:10:12
# 	Test: 149/3797 - accuracy = 0.492 -  ETA = 4:10:06
# 	Test: 150/3797 - accuracy = 0.491 -  ETA = 4:10:09
# 	Test: 151/3797 - accuracy = 0.491 -  ETA = 4:10:04
# 	Test: 152/3797 - accuracy = 0.491 -  ETA = 4:10:01
# 	Test: 153/3797 - accuracy = 0.489 -  ETA = 4:10:01
# 	Test: 154/3797 - accuracy = 0.490 -  ETA = 4:10:00
# 	Test: 155/3797 - accuracy = 0.488 -  ETA = 4:09:56
# 	Test: 156/3797 - accuracy = 0.487 -  ETA = 4:09:52
# 	Test: 157/3797 - accuracy = 0.487 -  ETA = 4:09:57
# 	Test: 158/3797 - accuracy = 0.488 -  ETA = 4:09:52
# 	Test: 159/3797 - accuracy = 0.488 -  ETA = 4:09:58
# 	Test: 160/3797 - accuracy = 0.489 -  ETA = 4:09:54
# 	Test: 161/3797 - accuracy = 0.489 -  ETA = 4:09:50
# 	Test: 162/3797 - accuracy = 0.489 -  ETA = 4:09:47
# 	Test: 163/3797 - accuracy = 0.488 -  ETA = 4:09:44
# 	Test: 164/3797 - accuracy = 0.488 -  ETA = 4:09:44
# 	Test: 165/3797 - accuracy = 0.488 -  ETA = 4:09:44
# 	Test: 166/3797 - accuracy = 0.488 -  ETA = 4:09:45
# 	Test: 167/3797 - accuracy = 0.488 -  ETA = 4:09:47
# 	Test: 168/3797 - accuracy = 0.487 -  ETA = 4:09:46
# 	Test: 169/3797 - accuracy = 0.487 -  ETA = 4:09:44
# 	Test: 170/3797 - accuracy = 0.487 -  ETA = 4:09:42
# 	Test: 171/3797 - accuracy = 0.488 -  ETA = 4:09:39
# 	Test: 172/3797 - accuracy = 0.487 -  ETA = 4:09:37
# 	Test: 173/3797 - accuracy = 0.488 -  ETA = 4:09:31
# 	Test: 174/3797 - accuracy = 0.488 -  ETA = 4:09:29
# 	Test: 175/3797 - accuracy = 0.489 -  ETA = 4:09:25
# 	Test: 176/3797 - accuracy = 0.490 -  ETA = 4:09:23
# 	Test: 177/3797 - accuracy = 0.491 -  ETA = 4:09:22
# 	Test: 178/3797 - accuracy = 0.490 -  ETA = 4:09:24
# 	Test: 179/3797 - accuracy = 0.491 -  ETA = 4:09:20
# 	Test: 180/3797 - accuracy = 0.491 -  ETA = 4:09:16
# 	Test: 181/3797 - accuracy = 0.492 -  ETA = 4:09:16
# 	Test: 182/3797 - accuracy = 0.492 -  ETA = 4:09:15
# 	Test: 183/3797 - accuracy = 0.492 -  ETA = 4:09:18
# 	Test: 184/3797 - accuracy = 0.493 -  ETA = 4:09:16
# 	Test: 185/3797 - accuracy = 0.493 -  ETA = 4:09:16
# 	Test: 186/3797 - accuracy = 0.493 -  ETA = 4:09:12
# 	Test: 187/3797 - accuracy = 0.493 -  ETA = 4:09:16
# 	Test: 188/3797 - accuracy = 0.493 -  ETA = 4:09:13
# 	Test: 189/3797 - accuracy = 0.493 -  ETA = 4:09:08
# 	Test: 190/3797 - accuracy = 0.493 -  ETA = 4:09:06
# 	Test: 191/3797 - accuracy = 0.493 -  ETA = 4:09:03
# 	Test: 192/3797 - accuracy = 0.493 -  ETA = 4:09:00
# 	Test: 193/3797 - accuracy = 0.492 -  ETA = 4:08:57
# 	Test: 194/3797 - accuracy = 0.492 -  ETA = 4:08:56
# 	Test: 195/3797 - accuracy = 0.492 -  ETA = 4:08:49
# 	Test: 196/3797 - accuracy = 0.492 -  ETA = 4:08:43
# 	Test: 197/3797 - accuracy = 0.491 -  ETA = 4:08:40
# 	Test: 198/3797 - accuracy = 0.492 -  ETA = 4:08:35
# 	Test: 199/3797 - accuracy = 0.492 -  ETA = 4:08:34
# 	Test: 200/3797 - accuracy = 0.492 -  ETA = 4:08:30
# 	Test: 201/3797 - accuracy = 0.491 -  ETA = 4:08:26
# 	Test: 202/3797 - accuracy = 0.492 -  ETA = 4:08:22
# 	Test: 203/3797 - accuracy = 0.491 -  ETA = 4:08:18
# 	Test: 204/3797 - accuracy = 0.491 -  ETA = 4:08:16
# 	Test: 205/3797 - accuracy = 0.492 -  ETA = 4:08:12
# 	Test: 206/3797 - accuracy = 0.491 -  ETA = 4:08:06
# 	Test: 207/3797 - accuracy = 0.491 -  ETA = 4:08:01
# 	Test: 208/3797 - accuracy = 0.492 -  ETA = 4:07:58
# 	Test: 209/3797 - accuracy = 0.492 -  ETA = 4:07:52
# 	Test: 210/3797 - accuracy = 0.492 -  ETA = 4:07:47
# 	Test: 211/3797 - accuracy = 0.491 -  ETA = 4:07:42
# 	Test: 212/3797 - accuracy = 0.491 -  ETA = 4:07:39
# 	Test: 213/3797 - accuracy = 0.491 -  ETA = 4:07:35
# 	Test: 214/3797 - accuracy = 0.490 -  ETA = 4:07:32
# 	Test: 215/3797 - accuracy = 0.491 -  ETA = 4:07:31
# 	Test: 216/3797 - accuracy = 0.490 -  ETA = 4:07:28
# 	Test: 217/3797 - accuracy = 0.490 -  ETA = 4:07:23
# 	Test: 218/3797 - accuracy = 0.490 -  ETA = 4:07:19
# 	Test: 219/3797 - accuracy = 0.490 -  ETA = 4:07:18
# 	Test: 220/3797 - accuracy = 0.491 -  ETA = 4:07:23
# 	Test: 221/3797 - accuracy = 0.490 -  ETA = 4:07:19
# 	Test: 222/3797 - accuracy = 0.491 -  ETA = 4:07:17
# 	Test: 223/3797 - accuracy = 0.491 -  ETA = 4:07:17
# 	Test: 224/3797 - accuracy = 0.491 -  ETA = 4:07:14
# 	Test: 225/3797 - accuracy = 0.491 -  ETA = 4:07:09
# 	Test: 226/3797 - accuracy = 0.491 -  ETA = 4:07:08
# 	Test: 227/3797 - accuracy = 0.491 -  ETA = 4:07:05
# 	Test: 228/3797 - accuracy = 0.491 -  ETA = 4:07:03
# 	Test: 229/3797 - accuracy = 0.490 -  ETA = 4:07:00
# 	Test: 230/3797 - accuracy = 0.491 -  ETA = 4:07:02
# 	Test: 231/3797 - accuracy = 0.491 -  ETA = 4:06:59
# 	Test: 232/3797 - accuracy = 0.490 -  ETA = 4:06:55
# 	Test: 233/3797 - accuracy = 0.490 -  ETA = 4:06:52
# 	Test: 234/3797 - accuracy = 0.490 -  ETA = 4:06:48
# 	Test: 235/3797 - accuracy = 0.491 -  ETA = 4:06:43
# 	Test: 236/3797 - accuracy = 0.490 -  ETA = 4:06:43
# 	Test: 237/3797 - accuracy = 0.491 -  ETA = 4:06:41
# 	Test: 238/3797 - accuracy = 0.491 -  ETA = 4:06:38
# 	Test: 239/3797 - accuracy = 0.491 -  ETA = 4:06:35
# 	Test: 240/3797 - accuracy = 0.491 -  ETA = 4:06:31
# 	Test: 241/3797 - accuracy = 0.491 -  ETA = 4:06:29
# 	Test: 242/3797 - accuracy = 0.491 -  ETA = 4:06:26
# 	Test: 243/3797 - accuracy = 0.491 -  ETA = 4:06:23
# 	Test: 244/3797 - accuracy = 0.491 -  ETA = 4:06:20
# 	Test: 245/3797 - accuracy = 0.491 -  ETA = 4:06:17
# 	Test: 246/3797 - accuracy = 0.491 -  ETA = 4:06:13
# 	Test: 247/3797 - accuracy = 0.491 -  ETA = 4:06:08
# 	Test: 248/3797 - accuracy = 0.492 -  ETA = 4:06:05
# 	Test: 249/3797 - accuracy = 0.492 -  ETA = 4:06:07
# 	Test: 250/3797 - accuracy = 0.492 -  ETA = 4:06:05
# 	Test: 251/3797 - accuracy = 0.492 -  ETA = 4:06:07
# 	Test: 252/3797 - accuracy = 0.492 -  ETA = 4:06:06
# 	Test: 253/3797 - accuracy = 0.492 -  ETA = 4:06:01
# 	Test: 254/3797 - accuracy = 0.491 -  ETA = 4:05:57
# 	Test: 255/3797 - accuracy = 0.491 -  ETA = 4:05:52
# 	Test: 256/3797 - accuracy = 0.491 -  ETA = 4:05:50
# 	Test: 257/3797 - accuracy = 0.490 -  ETA = 4:05:47
# 	Test: 258/3797 - accuracy = 0.491 -  ETA = 4:05:44
# 	Test: 259/3797 - accuracy = 0.491 -  ETA = 4:05:44
# 	Test: 260/3797 - accuracy = 0.491 -  ETA = 4:05:41
# 	Test: 261/3797 - accuracy = 0.490 -  ETA = 4:05:38
# 	Test: 262/3797 - accuracy = 0.490 -  ETA = 4:05:34
# 	Test: 263/3797 - accuracy = 0.490 -  ETA = 4:05:31
# 	Test: 264/3797 - accuracy = 0.489 -  ETA = 4:05:30
# 	Test: 265/3797 - accuracy = 0.488 -  ETA = 4:05:29
# 	Test: 266/3797 - accuracy = 0.488 -  ETA = 4:05:25
# 	Test: 267/3797 - accuracy = 0.488 -  ETA = 4:05:24
# 	Test: 268/3797 - accuracy = 0.487 -  ETA = 4:05:20
# 	Test: 269/3797 - accuracy = 0.487 -  ETA = 4:05:19
# 	Test: 270/3797 - accuracy = 0.487 -  ETA = 4:05:16
# 	Test: 271/3797 - accuracy = 0.488 -  ETA = 4:05:13
# 	Test: 272/3797 - accuracy = 0.488 -  ETA = 4:05:10
# 	Test: 273/3797 - accuracy = 0.489 -  ETA = 4:05:08
# 	Test: 274/3797 - accuracy = 0.489 -  ETA = 4:05:06
# 	Test: 275/3797 - accuracy = 0.489 -  ETA = 4:05:03
# 	Test: 276/3797 - accuracy = 0.489 -  ETA = 4:05:00
# 	Test: 277/3797 - accuracy = 0.489 -  ETA = 4:04:59
# 	Test: 278/3797 - accuracy = 0.489 -  ETA = 4:04:57
# 	Test: 279/3797 - accuracy = 0.489 -  ETA = 4:04:53
# 	Test: 280/3797 - accuracy = 0.490 -  ETA = 4:04:56
# 	Test: 281/3797 - accuracy = 0.490 -  ETA = 4:04:54
# 	Test: 282/3797 - accuracy = 0.489 -  ETA = 4:05:10
# 	Test: 283/3797 - accuracy = 0.489 -  ETA = 4:05:08
# 	Test: 284/3797 - accuracy = 0.489 -  ETA = 4:05:04
# 	Test: 285/3797 - accuracy = 0.489 -  ETA = 4:05:03
# 	Test: 286/3797 - accuracy = 0.489 -  ETA = 4:05:01
# 	Test: 287/3797 - accuracy = 0.489 -  ETA = 4:04:57
# 	Test: 288/3797 - accuracy = 0.489 -  ETA = 4:04:54
# 	Test: 289/3797 - accuracy = 0.489 -  ETA = 4:04:52
# 	Test: 290/3797 - accuracy = 0.489 -  ETA = 4:04:48
# 	Test: 291/3797 - accuracy = 0.489 -  ETA = 4:04:48
# 	Test: 292/3797 - accuracy = 0.490 -  ETA = 4:04:43
# 	Test: 293/3797 - accuracy = 0.490 -  ETA = 4:04:41
# 	Test: 294/3797 - accuracy = 0.490 -  ETA = 4:04:38
# 	Test: 295/3797 - accuracy = 0.490 -  ETA = 4:04:35
# 	Test: 296/3797 - accuracy = 0.490 -  ETA = 4:04:33
# 	Test: 297/3797 - accuracy = 0.490 -  ETA = 4:04:28
# 	Test: 298/3797 - accuracy = 0.490 -  ETA = 4:04:25
# 	Test: 299/3797 - accuracy = 0.490 -  ETA = 4:04:23
# 	Test: 300/3797 - accuracy = 0.490 -  ETA = 4:04:19
# 	Test: 301/3797 - accuracy = 0.490 -  ETA = 4:04:17
# 	Test: 302/3797 - accuracy = 0.490 -  ETA = 4:04:14
# 	Test: 303/3797 - accuracy = 0.490 -  ETA = 4:04:11
# 	Test: 304/3797 - accuracy = 0.490 -  ETA = 4:04:07
# 	Test: 305/3797 - accuracy = 0.491 -  ETA = 4:04:06
# 	Test: 306/3797 - accuracy = 0.491 -  ETA = 4:04:01
# 	Test: 307/3797 - accuracy = 0.490 -  ETA = 4:03:57
# 	Test: 308/3797 - accuracy = 0.491 -  ETA = 4:03:54
# 	Test: 309/3797 - accuracy = 0.490 -  ETA = 4:03:53
# 	Test: 310/3797 - accuracy = 0.491 -  ETA = 4:03:50
# 	Test: 311/3797 - accuracy = 0.490 -  ETA = 4:03:44
# 	Test: 312/3797 - accuracy = 0.491 -  ETA = 4:03:40
# 	Test: 313/3797 - accuracy = 0.491 -  ETA = 4:03:48
# 	Test: 314/3797 - accuracy = 0.491 -  ETA = 4:03:46
# 	Test: 315/3797 - accuracy = 0.491 -  ETA = 4:03:42
# 	Test: 316/3797 - accuracy = 0.491 -  ETA = 4:03:38
# 	Test: 317/3797 - accuracy = 0.491 -  ETA = 4:03:35
# 	Test: 318/3797 - accuracy = 0.490 -  ETA = 4:03:31
# 	Test: 319/3797 - accuracy = 0.490 -  ETA = 4:03:27
# 	Test: 320/3797 - accuracy = 0.489 -  ETA = 4:03:22
# 	Test: 321/3797 - accuracy = 0.489 -  ETA = 4:03:18
# 	Test: 322/3797 - accuracy = 0.489 -  ETA = 4:03:13
# 	Test: 323/3797 - accuracy = 0.489 -  ETA = 4:03:09
# 	Test: 324/3797 - accuracy = 0.489 -  ETA = 4:03:05
# 	Test: 325/3797 - accuracy = 0.488 -  ETA = 4:03:02
# 	Test: 326/3797 - accuracy = 0.488 -  ETA = 4:02:58
# 	Test: 327/3797 - accuracy = 0.489 -  ETA = 4:02:54
# 	Test: 328/3797 - accuracy = 0.489 -  ETA = 4:02:50
# 	Test: 329/3797 - accuracy = 0.489 -  ETA = 4:02:50
# 	Test: 330/3797 - accuracy = 0.489 -  ETA = 4:02:48
# 	Test: 331/3797 - accuracy = 0.489 -  ETA = 4:02:45
# 	Test: 332/3797 - accuracy = 0.488 -  ETA = 4:02:41
# 	Test: 333/3797 - accuracy = 0.488 -  ETA = 4:02:39
# 	Test: 334/3797 - accuracy = 0.489 -  ETA = 4:02:37
# 	Test: 335/3797 - accuracy = 0.489 -  ETA = 4:02:36
# 	Test: 336/3797 - accuracy = 0.489 -  ETA = 4:02:35
# 	Test: 337/3797 - accuracy = 0.489 -  ETA = 4:02:31
# 	Test: 338/3797 - accuracy = 0.489 -  ETA = 4:02:27
# 	Test: 339/3797 - accuracy = 0.489 -  ETA = 4:02:24
# 	Test: 340/3797 - accuracy = 0.489 -  ETA = 4:02:19
# 	Test: 341/3797 - accuracy = 0.489 -  ETA = 4:02:15
# 	Test: 342/3797 - accuracy = 0.489 -  ETA = 4:02:15
# 	Test: 343/3797 - accuracy = 0.489 -  ETA = 4:02:12
# 	Test: 344/3797 - accuracy = 0.489 -  ETA = 4:02:09
# 	Test: 345/3797 - accuracy = 0.489 -  ETA = 4:02:10
# 	Test: 346/3797 - accuracy = 0.489 -  ETA = 4:02:08
# 	Test: 347/3797 - accuracy = 0.489 -  ETA = 4:02:07
# 	Test: 348/3797 - accuracy = 0.489 -  ETA = 4:02:03
# 	Test: 349/3797 - accuracy = 0.489 -  ETA = 4:02:01
# 	Test: 350/3797 - accuracy = 0.489 -  ETA = 4:01:57
# 	Test: 351/3797 - accuracy = 0.489 -  ETA = 4:01:53
# 	Test: 352/3797 - accuracy = 0.489 -  ETA = 4:01:49
# 	Test: 353/3797 - accuracy = 0.489 -  ETA = 4:01:47
# 	Test: 354/3797 - accuracy = 0.489 -  ETA = 4:01:43
# 	Test: 355/3797 - accuracy = 0.489 -  ETA = 4:01:41
# 	Test: 356/3797 - accuracy = 0.488 -  ETA = 4:01:37
# 	Test: 357/3797 - accuracy = 0.488 -  ETA = 4:01:34
# 	Test: 358/3797 - accuracy = 0.488 -  ETA = 4:01:31
# 	Test: 359/3797 - accuracy = 0.488 -  ETA = 4:01:29
# 	Test: 360/3797 - accuracy = 0.488 -  ETA = 4:01:28
# 	Test: 361/3797 - accuracy = 0.487 -  ETA = 4:01:25
# 	Test: 362/3797 - accuracy = 0.487 -  ETA = 4:01:20
# 	Test: 363/3797 - accuracy = 0.487 -  ETA = 4:01:17
# 	Test: 364/3797 - accuracy = 0.487 -  ETA = 4:01:13
# 	Test: 365/3797 - accuracy = 0.487 -  ETA = 4:01:10
# 	Test: 366/3797 - accuracy = 0.487 -  ETA = 4:01:06
# 	Test: 367/3797 - accuracy = 0.487 -  ETA = 4:01:03
# 	Test: 368/3797 - accuracy = 0.487 -  ETA = 4:00:59
# 	Test: 369/3797 - accuracy = 0.487 -  ETA = 4:00:55
# 	Test: 370/3797 - accuracy = 0.487 -  ETA = 4:00:52
# 	Test: 371/3797 - accuracy = 0.487 -  ETA = 4:00:49
# 	Test: 372/3797 - accuracy = 0.487 -  ETA = 4:00:45
# 	Test: 373/3797 - accuracy = 0.487 -  ETA = 4:00:42
# 	Test: 374/3797 - accuracy = 0.487 -  ETA = 4:00:39
# 	Test: 375/3797 - accuracy = 0.487 -  ETA = 4:00:40
# 	Test: 376/3797 - accuracy = 0.487 -  ETA = 4:00:44
# 	Test: 377/3797 - accuracy = 0.487 -  ETA = 4:00:40
# 	Test: 378/3797 - accuracy = 0.487 -  ETA = 4:00:36
# 	Test: 379/3797 - accuracy = 0.487 -  ETA = 4:00:34
# 	Test: 380/3797 - accuracy = 0.487 -  ETA = 4:00:30
# 	Test: 381/3797 - accuracy = 0.487 -  ETA = 4:00:27
# 	Test: 382/3797 - accuracy = 0.487 -  ETA = 4:00:23
# 	Test: 383/3797 - accuracy = 0.487 -  ETA = 4:00:20
# 	Test: 384/3797 - accuracy = 0.487 -  ETA = 4:00:15
# 	Test: 385/3797 - accuracy = 0.487 -  ETA = 4:00:16
# 	Test: 386/3797 - accuracy = 0.487 -  ETA = 4:00:11
# 	Test: 387/3797 - accuracy = 0.487 -  ETA = 4:00:07
# 	Test: 388/3797 - accuracy = 0.487 -  ETA = 4:00:02
# 	Test: 389/3797 - accuracy = 0.486 -  ETA = 3:59:57
# 	Test: 390/3797 - accuracy = 0.486 -  ETA = 3:59:54
# 	Test: 391/3797 - accuracy = 0.486 -  ETA = 3:59:51
# 	Test: 392/3797 - accuracy = 0.486 -  ETA = 3:59:48
# 	Test: 393/3797 - accuracy = 0.486 -  ETA = 3:59:43
# 	Test: 394/3797 - accuracy = 0.486 -  ETA = 3:59:39
# 	Test: 395/3797 - accuracy = 0.486 -  ETA = 3:59:35
# 	Test: 396/3797 - accuracy = 0.486 -  ETA = 3:59:31
# 	Test: 397/3797 - accuracy = 0.486 -  ETA = 3:59:27
# 	Test: 398/3797 - accuracy = 0.486 -  ETA = 3:59:24
# 	Test: 399/3797 - accuracy = 0.486 -  ETA = 3:59:20
# 	Test: 400/3797 - accuracy = 0.486 -  ETA = 3:59:17
# 	Test: 401/3797 - accuracy = 0.486 -  ETA = 3:59:13
# 	Test: 402/3797 - accuracy = 0.486 -  ETA = 3:59:10
# 	Test: 403/3797 - accuracy = 0.486 -  ETA = 3:59:06
# 	Test: 404/3797 - accuracy = 0.486 -  ETA = 3:59:02
# 	Test: 405/3797 - accuracy = 0.486 -  ETA = 3:58:59
# 	Test: 406/3797 - accuracy = 0.486 -  ETA = 3:58:54
# 	Test: 407/3797 - accuracy = 0.486 -  ETA = 3:58:50
# 	Test: 408/3797 - accuracy = 0.486 -  ETA = 3:58:54
# 	Test: 409/3797 - accuracy = 0.486 -  ETA = 3:58:50
# 	Test: 410/3797 - accuracy = 0.486 -  ETA = 3:58:46
# 	Test: 411/3797 - accuracy = 0.486 -  ETA = 3:58:42
# 	Test: 412/3797 - accuracy = 0.486 -  ETA = 3:58:38
# 	Test: 413/3797 - accuracy = 0.486 -  ETA = 3:58:35
# 	Test: 414/3797 - accuracy = 0.486 -  ETA = 3:58:31
# 	Test: 415/3797 - accuracy = 0.486 -  ETA = 3:58:27
# 	Test: 416/3797 - accuracy = 0.486 -  ETA = 3:58:22
# 	Test: 417/3797 - accuracy = 0.486 -  ETA = 3:58:18
# 	Test: 418/3797 - accuracy = 0.486 -  ETA = 3:58:15
# 	Test: 419/3797 - accuracy = 0.486 -  ETA = 3:58:10
# 	Test: 420/3797 - accuracy = 0.486 -  ETA = 3:58:07
# 	Test: 421/3797 - accuracy = 0.486 -  ETA = 3:58:03
# 	Test: 422/3797 - accuracy = 0.486 -  ETA = 3:57:59
# 	Test: 423/3797 - accuracy = 0.486 -  ETA = 3:57:54
# 	Test: 424/3797 - accuracy = 0.486 -  ETA = 3:57:50
# 	Test: 425/3797 - accuracy = 0.487 -  ETA = 3:57:46
# 	Test: 426/3797 - accuracy = 0.486 -  ETA = 3:57:42
# 	Test: 427/3797 - accuracy = 0.486 -  ETA = 3:57:39
# 	Test: 428/3797 - accuracy = 0.486 -  ETA = 3:57:35
# 	Test: 429/3797 - accuracy = 0.486 -  ETA = 3:57:32
# 	Test: 430/3797 - accuracy = 0.486 -  ETA = 3:57:28
# 	Test: 431/3797 - accuracy = 0.486 -  ETA = 3:57:25
# 	Test: 432/3797 - accuracy = 0.487 -  ETA = 3:57:22
# 	Test: 433/3797 - accuracy = 0.487 -  ETA = 3:57:18
# 	Test: 434/3797 - accuracy = 0.486 -  ETA = 3:57:13
# 	Test: 435/3797 - accuracy = 0.486 -  ETA = 3:57:10
# 	Test: 436/3797 - accuracy = 0.486 -  ETA = 3:57:06
# 	Test: 437/3797 - accuracy = 0.486 -  ETA = 3:57:05
# 	Test: 438/3797 - accuracy = 0.486 -  ETA = 3:57:03
# 	Test: 439/3797 - accuracy = 0.486 -  ETA = 3:56:59
# 	Test: 440/3797 - accuracy = 0.486 -  ETA = 3:56:55
# 	Test: 441/3797 - accuracy = 0.486 -  ETA = 3:56:52
# 	Test: 442/3797 - accuracy = 0.486 -  ETA = 3:56:49
# 	Test: 443/3797 - accuracy = 0.486 -  ETA = 3:56:46
# 	Test: 444/3797 - accuracy = 0.485 -  ETA = 3:56:43
# 	Test: 445/3797 - accuracy = 0.485 -  ETA = 3:56:40
# 	Test: 446/3797 - accuracy = 0.485 -  ETA = 3:56:36
# 	Test: 447/3797 - accuracy = 0.485 -  ETA = 3:56:33
# 	Test: 448/3797 - accuracy = 0.485 -  ETA = 3:56:28
# 	Test: 449/3797 - accuracy = 0.485 -  ETA = 3:56:25
# 	Test: 450/3797 - accuracy = 0.485 -  ETA = 3:56:21
# 	Test: 451/3797 - accuracy = 0.485 -  ETA = 3:56:17
# 	Test: 452/3797 - accuracy = 0.485 -  ETA = 3:56:13
# 	Test: 453/3797 - accuracy = 0.485 -  ETA = 3:56:08
# 	Test: 454/3797 - accuracy = 0.485 -  ETA = 3:56:04
# 	Test: 455/3797 - accuracy = 0.485 -  ETA = 3:56:01
# 	Test: 456/3797 - accuracy = 0.485 -  ETA = 3:55:57
# 	Test: 457/3797 - accuracy = 0.485 -  ETA = 3:55:53
# 	Test: 458/3797 - accuracy = 0.485 -  ETA = 3:55:48
# 	Test: 459/3797 - accuracy = 0.485 -  ETA = 3:55:45
# 	Test: 460/3797 - accuracy = 0.485 -  ETA = 3:55:43
# 	Test: 461/3797 - accuracy = 0.485 -  ETA = 3:55:40
# 	Test: 462/3797 - accuracy = 0.485 -  ETA = 3:55:36
# 	Test: 463/3797 - accuracy = 0.485 -  ETA = 3:55:33
# 	Test: 464/3797 - accuracy = 0.485 -  ETA = 3:55:31
# 	Test: 465/3797 - accuracy = 0.485 -  ETA = 3:55:28
# 	Test: 466/3797 - accuracy = 0.485 -  ETA = 3:55:27
# 	Test: 467/3797 - accuracy = 0.485 -  ETA = 3:55:24
# 	Test: 468/3797 - accuracy = 0.485 -  ETA = 3:55:19
# 	Test: 469/3797 - accuracy = 0.485 -  ETA = 3:55:16
# 	Test: 470/3797 - accuracy = 0.485 -  ETA = 3:55:13
# 	Test: 471/3797 - accuracy = 0.485 -  ETA = 3:55:09
# 	Test: 472/3797 - accuracy = 0.485 -  ETA = 3:55:05
# 	Test: 473/3797 - accuracy = 0.485 -  ETA = 3:55:04
# 	Test: 474/3797 - accuracy = 0.485 -  ETA = 3:55:02
# 	Test: 475/3797 - accuracy = 0.485 -  ETA = 3:55:00
# 	Test: 476/3797 - accuracy = 0.485 -  ETA = 3:54:56
# 	Test: 477/3797 - accuracy = 0.485 -  ETA = 3:54:53
# 	Test: 478/3797 - accuracy = 0.486 -  ETA = 3:54:50
# 	Test: 479/3797 - accuracy = 0.485 -  ETA = 3:54:46
# 	Test: 480/3797 - accuracy = 0.485 -  ETA = 3:54:42
# 	Test: 481/3797 - accuracy = 0.485 -  ETA = 3:54:39
# 	Test: 482/3797 - accuracy = 0.485 -  ETA = 3:54:35
# 	Test: 483/3797 - accuracy = 0.485 -  ETA = 3:54:32
# 	Test: 484/3797 - accuracy = 0.485 -  ETA = 3:54:30
# 	Test: 485/3797 - accuracy = 0.485 -  ETA = 3:54:26
# 	Test: 486/3797 - accuracy = 0.485 -  ETA = 3:54:22
# 	Test: 487/3797 - accuracy = 0.485 -  ETA = 3:54:19
# 	Test: 488/3797 - accuracy = 0.485 -  ETA = 3:54:15
# 	Test: 489/3797 - accuracy = 0.485 -  ETA = 3:54:14
# 	Test: 490/3797 - accuracy = 0.485 -  ETA = 3:54:10
# 	Test: 491/3797 - accuracy = 0.485 -  ETA = 3:54:06
# 	Test: 492/3797 - accuracy = 0.485 -  ETA = 3:54:03
# 	Test: 493/3797 - accuracy = 0.485 -  ETA = 3:53:59
# 	Test: 494/3797 - accuracy = 0.485 -  ETA = 3:53:56
# 	Test: 495/3797 - accuracy = 0.485 -  ETA = 3:53:53
# 	Test: 496/3797 - accuracy = 0.485 -  ETA = 3:53:49
# 	Test: 497/3797 - accuracy = 0.485 -  ETA = 3:53:46
# 	Test: 498/3797 - accuracy = 0.485 -  ETA = 3:53:44
# 	Test: 499/3797 - accuracy = 0.485 -  ETA = 3:53:41
# 	Test: 500/3797 - accuracy = 0.485 -  ETA = 3:53:38
# 	Test: 501/3797 - accuracy = 0.485 -  ETA = 3:53:35
# 	Test: 502/3797 - accuracy = 0.485 -  ETA = 3:53:32
# 	Test: 503/3797 - accuracy = 0.485 -  ETA = 3:53:28
# 	Test: 504/3797 - accuracy = 0.485 -  ETA = 3:53:24
# 	Test: 505/3797 - accuracy = 0.485 -  ETA = 3:53:20
# 	Test: 506/3797 - accuracy = 0.485 -  ETA = 3:53:16
# 	Test: 507/3797 - accuracy = 0.486 -  ETA = 3:53:12
# 	Test: 508/3797 - accuracy = 0.486 -  ETA = 3:53:09
# 	Test: 509/3797 - accuracy = 0.486 -  ETA = 3:53:05
# 	Test: 510/3797 - accuracy = 0.486 -  ETA = 3:53:02
# 	Test: 511/3797 - accuracy = 0.486 -  ETA = 3:52:59
# 	Test: 512/3797 - accuracy = 0.486 -  ETA = 3:52:56
# 	Test: 513/3797 - accuracy = 0.486 -  ETA = 3:52:51
# 	Test: 514/3797 - accuracy = 0.486 -  ETA = 3:52:47
# 	Test: 515/3797 - accuracy = 0.486 -  ETA = 3:52:45
# 	Test: 516/3797 - accuracy = 0.486 -  ETA = 3:52:42
# 	Test: 517/3797 - accuracy = 0.486 -  ETA = 3:52:39
# 	Test: 518/3797 - accuracy = 0.486 -  ETA = 3:52:35
# 	Test: 519/3797 - accuracy = 0.486 -  ETA = 3:52:32
# 	Test: 520/3797 - accuracy = 0.486 -  ETA = 3:52:28
# 	Test: 521/3797 - accuracy = 0.486 -  ETA = 3:52:25
# 	Test: 522/3797 - accuracy = 0.486 -  ETA = 3:52:24
# 	Test: 523/3797 - accuracy = 0.486 -  ETA = 3:52:20
# 	Test: 524/3797 - accuracy = 0.485 -  ETA = 3:52:18
# 	Test: 525/3797 - accuracy = 0.485 -  ETA = 3:52:14
# 	Test: 526/3797 - accuracy = 0.485 -  ETA = 3:52:11
# 	Test: 527/3797 - accuracy = 0.486 -  ETA = 3:52:08
# 	Test: 528/3797 - accuracy = 0.486 -  ETA = 3:52:05
# 	Test: 529/3797 - accuracy = 0.485 -  ETA = 3:52:03
# 	Test: 530/3797 - accuracy = 0.485 -  ETA = 3:52:01
# 	Test: 531/3797 - accuracy = 0.485 -  ETA = 3:51:58
# 	Test: 532/3797 - accuracy = 0.485 -  ETA = 3:51:55
# 	Test: 533/3797 - accuracy = 0.485 -  ETA = 3:51:51
# 	Test: 534/3797 - accuracy = 0.485 -  ETA = 3:51:47
# 	Test: 535/3797 - accuracy = 0.485 -  ETA = 3:51:43
# 	Test: 536/3797 - accuracy = 0.485 -  ETA = 3:51:40
# 	Test: 537/3797 - accuracy = 0.484 -  ETA = 3:51:36
# 	Test: 538/3797 - accuracy = 0.485 -  ETA = 3:51:33
# 	Test: 539/3797 - accuracy = 0.485 -  ETA = 3:51:35
# 	Test: 540/3797 - accuracy = 0.485 -  ETA = 3:51:34
# 	Test: 541/3797 - accuracy = 0.485 -  ETA = 3:51:33
# 	Test: 542/3797 - accuracy = 0.486 -  ETA = 3:51:30
# 	Test: 543/3797 - accuracy = 0.485 -  ETA = 3:51:26
# 	Test: 544/3797 - accuracy = 0.486 -  ETA = 3:51:22
# 	Test: 545/3797 - accuracy = 0.486 -  ETA = 3:51:19
# 	Test: 546/3797 - accuracy = 0.486 -  ETA = 3:51:15
# 	Test: 547/3797 - accuracy = 0.486 -  ETA = 3:51:12
# 	Test: 548/3797 - accuracy = 0.486 -  ETA = 3:51:11
# 	Test: 549/3797 - accuracy = 0.486 -  ETA = 3:51:08
# 	Test: 550/3797 - accuracy = 0.486 -  ETA = 3:51:05
# 	Test: 551/3797 - accuracy = 0.486 -  ETA = 3:51:02
# 	Test: 552/3797 - accuracy = 0.485 -  ETA = 3:51:01
# 	Test: 553/3797 - accuracy = 0.486 -  ETA = 3:50:58
# 	Test: 554/3797 - accuracy = 0.486 -  ETA = 3:50:55
# 	Test: 555/3797 - accuracy = 0.486 -  ETA = 3:50:53
# 	Test: 556/3797 - accuracy = 0.486 -  ETA = 3:50:49
# 	Test: 557/3797 - accuracy = 0.486 -  ETA = 3:50:47
# 	Test: 558/3797 - accuracy = 0.486 -  ETA = 3:50:43
# 	Test: 559/3797 - accuracy = 0.486 -  ETA = 3:50:40
# 	Test: 560/3797 - accuracy = 0.486 -  ETA = 3:50:39
# 	Test: 561/3797 - accuracy = 0.486 -  ETA = 3:50:37
# 	Test: 562/3797 - accuracy = 0.486 -  ETA = 3:50:34
# 	Test: 563/3797 - accuracy = 0.486 -  ETA = 3:50:31
# 	Test: 564/3797 - accuracy = 0.486 -  ETA = 3:50:28
# 	Test: 565/3797 - accuracy = 0.486 -  ETA = 3:50:25
# 	Test: 566/3797 - accuracy = 0.486 -  ETA = 3:50:22
# 	Test: 567/3797 - accuracy = 0.485 -  ETA = 3:50:18
# 	Test: 568/3797 - accuracy = 0.485 -  ETA = 3:50:17
# 	Test: 569/3797 - accuracy = 0.485 -  ETA = 3:50:15
# 	Test: 570/3797 - accuracy = 0.485 -  ETA = 3:50:13
# 	Test: 571/3797 - accuracy = 0.485 -  ETA = 3:50:14
# 	Test: 572/3797 - accuracy = 0.485 -  ETA = 3:50:12
# 	Test: 573/3797 - accuracy = 0.485 -  ETA = 3:50:09
# 	Test: 574/3797 - accuracy = 0.485 -  ETA = 3:50:06
# 	Test: 575/3797 - accuracy = 0.485 -  ETA = 3:50:03
# 	Test: 576/3797 - accuracy = 0.485 -  ETA = 3:50:00
# 	Test: 577/3797 - accuracy = 0.485 -  ETA = 3:49:57
# 	Test: 578/3797 - accuracy = 0.485 -  ETA = 3:49:53
# 	Test: 579/3797 - accuracy = 0.485 -  ETA = 3:49:50
# 	Test: 580/3797 - accuracy = 0.485 -  ETA = 3:49:47
# 	Test: 581/3797 - accuracy = 0.485 -  ETA = 3:49:46
# 	Test: 582/3797 - accuracy = 0.485 -  ETA = 3:49:42
# 	Test: 583/3797 - accuracy = 0.484 -  ETA = 3:49:39
# 	Test: 584/3797 - accuracy = 0.485 -  ETA = 3:49:36
# 	Test: 585/3797 - accuracy = 0.485 -  ETA = 3:49:33
# 	Test: 586/3797 - accuracy = 0.485 -  ETA = 3:49:30
# 	Test: 587/3797 - accuracy = 0.485 -  ETA = 3:49:28
# 	Test: 588/3797 - accuracy = 0.485 -  ETA = 3:49:24
# 	Test: 589/3797 - accuracy = 0.485 -  ETA = 3:49:21
# 	Test: 590/3797 - accuracy = 0.485 -  ETA = 3:49:18
# 	Test: 591/3797 - accuracy = 0.484 -  ETA = 3:49:14
# 	Test: 592/3797 - accuracy = 0.484 -  ETA = 3:49:11
# 	Test: 593/3797 - accuracy = 0.484 -  ETA = 3:49:07
# 	Test: 594/3797 - accuracy = 0.484 -  ETA = 3:49:04
# 	Test: 595/3797 - accuracy = 0.485 -  ETA = 3:49:01
# 	Test: 596/3797 - accuracy = 0.485 -  ETA = 3:49:00
# 	Test: 597/3797 - accuracy = 0.485 -  ETA = 3:48:58
# 	Test: 598/3797 - accuracy = 0.485 -  ETA = 3:48:55
# 	Test: 599/3797 - accuracy = 0.485 -  ETA = 3:48:52
# 	Test: 600/3797 - accuracy = 0.485 -  ETA = 3:48:49
# 	Test: 601/3797 - accuracy = 0.485 -  ETA = 3:48:50
# 	Test: 602/3797 - accuracy = 0.485 -  ETA = 3:48:46
# 	Test: 603/3797 - accuracy = 0.486 -  ETA = 3:48:47
# 	Test: 604/3797 - accuracy = 0.486 -  ETA = 3:48:42
# 	Test: 605/3797 - accuracy = 0.486 -  ETA = 3:48:39
# 	Test: 606/3797 - accuracy = 0.485 -  ETA = 3:48:36
# 	Test: 607/3797 - accuracy = 0.486 -  ETA = 3:48:34
# 	Test: 608/3797 - accuracy = 0.485 -  ETA = 3:48:31
# 	Test: 609/3797 - accuracy = 0.485 -  ETA = 3:48:27
# 	Test: 610/3797 - accuracy = 0.485 -  ETA = 3:48:25
# 	Test: 611/3797 - accuracy = 0.486 -  ETA = 3:48:21
# 	Test: 612/3797 - accuracy = 0.486 -  ETA = 3:48:18
# 	Test: 613/3797 - accuracy = 0.486 -  ETA = 3:48:14
# 	Test: 614/3797 - accuracy = 0.486 -  ETA = 3:48:11
# 	Test: 615/3797 - accuracy = 0.486 -  ETA = 3:48:08
# 	Test: 616/3797 - accuracy = 0.486 -  ETA = 3:48:06
# 	Test: 617/3797 - accuracy = 0.486 -  ETA = 3:48:02
# 	Test: 618/3797 - accuracy = 0.486 -  ETA = 3:47:59
# 	Test: 619/3797 - accuracy = 0.486 -  ETA = 3:48:00
# 	Test: 620/3797 - accuracy = 0.486 -  ETA = 3:47:58
# 	Test: 621/3797 - accuracy = 0.486 -  ETA = 3:47:55
# 	Test: 622/3797 - accuracy = 0.486 -  ETA = 3:47:52
# 	Test: 623/3797 - accuracy = 0.486 -  ETA = 3:47:48
# 	Test: 624/3797 - accuracy = 0.486 -  ETA = 3:47:45
# 	Test: 625/3797 - accuracy = 0.486 -  ETA = 3:47:41
# 	Test: 626/3797 - accuracy = 0.486 -  ETA = 3:47:38
# 	Test: 627/3797 - accuracy = 0.486 -  ETA = 3:47:35
# 	Test: 628/3797 - accuracy = 0.486 -  ETA = 3:47:32
# 	Test: 629/3797 - accuracy = 0.486 -  ETA = 3:47:29
# 	Test: 630/3797 - accuracy = 0.486 -  ETA = 3:47:25
# 	Test: 631/3797 - accuracy = 0.486 -  ETA = 3:47:22
# 	Test: 632/3797 - accuracy = 0.486 -  ETA = 3:47:20
# 	Test: 633/3797 - accuracy = 0.486 -  ETA = 3:47:17
# 	Test: 634/3797 - accuracy = 0.486 -  ETA = 3:47:14
# 	Test: 635/3797 - accuracy = 0.486 -  ETA = 3:47:10
# 	Test: 636/3797 - accuracy = 0.486 -  ETA = 3:47:08
# 	Test: 637/3797 - accuracy = 0.487 -  ETA = 3:47:05
# 	Test: 638/3797 - accuracy = 0.487 -  ETA = 3:47:02
# 	Test: 639/3797 - accuracy = 0.487 -  ETA = 3:46:59
# 	Test: 640/3797 - accuracy = 0.487 -  ETA = 3:46:55
# 	Test: 641/3797 - accuracy = 0.487 -  ETA = 3:46:53
# 	Test: 642/3797 - accuracy = 0.487 -  ETA = 3:46:51
# 	Test: 643/3797 - accuracy = 0.487 -  ETA = 3:46:49
# 	Test: 644/3797 - accuracy = 0.487 -  ETA = 3:46:45
# 	Test: 645/3797 - accuracy = 0.488 -  ETA = 3:46:44
# 	Test: 646/3797 - accuracy = 0.487 -  ETA = 3:46:42
# 	Test: 647/3797 - accuracy = 0.488 -  ETA = 3:46:38
# 	Test: 648/3797 - accuracy = 0.487 -  ETA = 3:46:36
# 	Test: 649/3797 - accuracy = 0.487 -  ETA = 3:46:33
# 	Test: 650/3797 - accuracy = 0.487 -  ETA = 3:46:29
# 	Test: 651/3797 - accuracy = 0.488 -  ETA = 3:46:26
# 	Test: 652/3797 - accuracy = 0.487 -  ETA = 3:46:24
# 	Test: 653/3797 - accuracy = 0.487 -  ETA = 3:46:20
# 	Test: 654/3797 - accuracy = 0.487 -  ETA = 3:46:18
# 	Test: 655/3797 - accuracy = 0.488 -  ETA = 3:46:16
# 	Test: 656/3797 - accuracy = 0.487 -  ETA = 3:46:12
# 	Test: 657/3797 - accuracy = 0.487 -  ETA = 3:46:09
# 	Test: 658/3797 - accuracy = 0.487 -  ETA = 3:46:06
# 	Test: 659/3797 - accuracy = 0.488 -  ETA = 3:46:03
# 	Test: 660/3797 - accuracy = 0.488 -  ETA = 3:46:00
# 	Test: 661/3797 - accuracy = 0.488 -  ETA = 3:45:57
# 	Test: 662/3797 - accuracy = 0.487 -  ETA = 3:45:54
# 	Test: 663/3797 - accuracy = 0.487 -  ETA = 3:45:51
# 	Test: 664/3797 - accuracy = 0.487 -  ETA = 3:45:48
# 	Test: 665/3797 - accuracy = 0.487 -  ETA = 3:45:45
# 	Test: 666/3797 - accuracy = 0.487 -  ETA = 3:45:43
# 	Test: 667/3797 - accuracy = 0.487 -  ETA = 3:45:39
# 	Test: 668/3797 - accuracy = 0.488 -  ETA = 3:45:37
# 	Test: 669/3797 - accuracy = 0.488 -  ETA = 3:45:34
# 	Test: 670/3797 - accuracy = 0.488 -  ETA = 3:45:30
# 	Test: 671/3797 - accuracy = 0.488 -  ETA = 3:45:28
# 	Test: 672/3797 - accuracy = 0.488 -  ETA = 3:45:25
# 	Test: 673/3797 - accuracy = 0.488 -  ETA = 3:45:23
# 	Test: 674/3797 - accuracy = 0.488 -  ETA = 3:45:20
# 	Test: 675/3797 - accuracy = 0.488 -  ETA = 3:45:17
# 	Test: 676/3797 - accuracy = 0.488 -  ETA = 3:45:14
# 	Test: 677/3797 - accuracy = 0.488 -  ETA = 3:45:10
# 	Test: 678/3797 - accuracy = 0.488 -  ETA = 3:45:07
# 	Test: 679/3797 - accuracy = 0.488 -  ETA = 3:45:03
# 	Test: 680/3797 - accuracy = 0.488 -  ETA = 3:45:00
# 	Test: 681/3797 - accuracy = 0.488 -  ETA = 3:44:57
# 	Test: 682/3797 - accuracy = 0.488 -  ETA = 3:44:55
# 	Test: 683/3797 - accuracy = 0.488 -  ETA = 3:44:52
# 	Test: 684/3797 - accuracy = 0.488 -  ETA = 3:44:51
# 	Test: 685/3797 - accuracy = 0.488 -  ETA = 3:44:49
# 	Test: 686/3797 - accuracy = 0.488 -  ETA = 3:44:46
# 	Test: 687/3797 - accuracy = 0.488 -  ETA = 3:44:44
# 	Test: 688/3797 - accuracy = 0.488 -  ETA = 3:44:41
# 	Test: 689/3797 - accuracy = 0.488 -  ETA = 3:44:39
# 	Test: 690/3797 - accuracy = 0.488 -  ETA = 3:44:35
# 	Test: 691/3797 - accuracy = 0.488 -  ETA = 3:44:32
# 	Test: 692/3797 - accuracy = 0.488 -  ETA = 3:44:29
# 	Test: 693/3797 - accuracy = 0.489 -  ETA = 3:44:26
# 	Test: 694/3797 - accuracy = 0.489 -  ETA = 3:44:22
# 	Test: 695/3797 - accuracy = 0.488 -  ETA = 3:44:19
# 	Test: 696/3797 - accuracy = 0.488 -  ETA = 3:44:16
# 	Test: 697/3797 - accuracy = 0.488 -  ETA = 3:44:15
# 	Test: 698/3797 - accuracy = 0.488 -  ETA = 3:44:13
# 	Test: 699/3797 - accuracy = 0.488 -  ETA = 3:44:11
# 	Test: 700/3797 - accuracy = 0.488 -  ETA = 3:44:08
# 	Test: 701/3797 - accuracy = 0.489 -  ETA = 3:44:05
# 	Test: 702/3797 - accuracy = 0.489 -  ETA = 3:44:03
# 	Test: 703/3797 - accuracy = 0.489 -  ETA = 3:43:59
# 	Test: 704/3797 - accuracy = 0.489 -  ETA = 3:43:57
# 	Test: 705/3797 - accuracy = 0.489 -  ETA = 3:43:55
# 	Test: 706/3797 - accuracy = 0.489 -  ETA = 3:43:53
# 	Test: 707/3797 - accuracy = 0.489 -  ETA = 3:43:50
# 	Test: 708/3797 - accuracy = 0.489 -  ETA = 3:43:47
# 	Test: 709/3797 - accuracy = 0.489 -  ETA = 3:43:45
# 	Test: 710/3797 - accuracy = 0.489 -  ETA = 3:43:41
# 	Test: 711/3797 - accuracy = 0.489 -  ETA = 3:43:37
# 	Test: 712/3797 - accuracy = 0.489 -  ETA = 3:43:34
# 	Test: 713/3797 - accuracy = 0.489 -  ETA = 3:43:31
# 	Test: 714/3797 - accuracy = 0.489 -  ETA = 3:43:30
# 	Test: 715/3797 - accuracy = 0.489 -  ETA = 3:43:27
# 	Test: 716/3797 - accuracy = 0.489 -  ETA = 3:43:25
# 	Test: 717/3797 - accuracy = 0.489 -  ETA = 3:43:23
# 	Test: 718/3797 - accuracy = 0.489 -  ETA = 3:43:21
# 	Test: 719/3797 - accuracy = 0.489 -  ETA = 3:43:18
# 	Test: 720/3797 - accuracy = 0.489 -  ETA = 3:43:15
# 	Test: 721/3797 - accuracy = 0.489 -  ETA = 3:43:12
# 	Test: 722/3797 - accuracy = 0.489 -  ETA = 3:43:09
# 	Test: 723/3797 - accuracy = 0.489 -  ETA = 3:43:06
# 	Test: 724/3797 - accuracy = 0.489 -  ETA = 3:43:03
# 	Test: 725/3797 - accuracy = 0.489 -  ETA = 3:43:00
# 	Test: 726/3797 - accuracy = 0.489 -  ETA = 3:42:57
# 	Test: 727/3797 - accuracy = 0.489 -  ETA = 3:42:54
# 	Test: 728/3797 - accuracy = 0.489 -  ETA = 3:42:50
# 	Test: 729/3797 - accuracy = 0.489 -  ETA = 3:42:47
# 	Test: 730/3797 - accuracy = 0.489 -  ETA = 3:42:44
# 	Test: 731/3797 - accuracy = 0.489 -  ETA = 3:42:42
# 	Test: 732/3797 - accuracy = 0.489 -  ETA = 3:42:41
# 	Test: 733/3797 - accuracy = 0.489 -  ETA = 3:42:39
# 	Test: 734/3797 - accuracy = 0.489 -  ETA = 3:42:37
# 	Test: 735/3797 - accuracy = 0.489 -  ETA = 3:42:35
# 	Test: 736/3797 - accuracy = 0.489 -  ETA = 3:42:33
# 	Test: 737/3797 - accuracy = 0.489 -  ETA = 3:42:30
# 	Test: 738/3797 - accuracy = 0.489 -  ETA = 3:42:27
# 	Test: 739/3797 - accuracy = 0.489 -  ETA = 3:42:25
# 	Test: 740/3797 - accuracy = 0.489 -  ETA = 3:42:22
# 	Test: 741/3797 - accuracy = 0.489 -  ETA = 3:42:19
# 	Test: 742/3797 - accuracy = 0.489 -  ETA = 3:42:18
# 	Test: 743/3797 - accuracy = 0.489 -  ETA = 3:42:16
# 	Test: 744/3797 - accuracy = 0.489 -  ETA = 3:42:13
# 	Test: 745/3797 - accuracy = 0.489 -  ETA = 3:42:10
# 	Test: 746/3797 - accuracy = 0.488 -  ETA = 3:42:08
# 	Test: 747/3797 - accuracy = 0.489 -  ETA = 3:42:06
# 	Test: 748/3797 - accuracy = 0.489 -  ETA = 3:42:04
# 	Test: 749/3797 - accuracy = 0.489 -  ETA = 3:42:02
# 	Test: 750/3797 - accuracy = 0.489 -  ETA = 3:41:59
# 	Test: 751/3797 - accuracy = 0.489 -  ETA = 3:41:58
# 	Test: 752/3797 - accuracy = 0.489 -  ETA = 3:41:55
# 	Test: 753/3797 - accuracy = 0.489 -  ETA = 3:41:52
# 	Test: 754/3797 - accuracy = 0.489 -  ETA = 3:41:50
# 	Test: 755/3797 - accuracy = 0.489 -  ETA = 3:41:47
# 	Test: 756/3797 - accuracy = 0.489 -  ETA = 3:41:45
# 	Test: 757/3797 - accuracy = 0.489 -  ETA = 3:41:42
# 	Test: 758/3797 - accuracy = 0.489 -  ETA = 3:41:40
# 	Test: 759/3797 - accuracy = 0.489 -  ETA = 3:41:36
# 	Test: 760/3797 - accuracy = 0.489 -  ETA = 3:41:33
# 	Test: 761/3797 - accuracy = 0.489 -  ETA = 3:41:31
# 	Test: 762/3797 - accuracy = 0.489 -  ETA = 3:41:28
# 	Test: 763/3797 - accuracy = 0.489 -  ETA = 3:41:25
# 	Test: 764/3797 - accuracy = 0.489 -  ETA = 3:41:22
# 	Test: 765/3797 - accuracy = 0.489 -  ETA = 3:41:20
# 	Test: 766/3797 - accuracy = 0.489 -  ETA = 3:41:17
# 	Test: 767/3797 - accuracy = 0.488 -  ETA = 3:41:15
# 	Test: 768/3797 - accuracy = 0.488 -  ETA = 3:41:13
# 	Test: 769/3797 - accuracy = 0.488 -  ETA = 3:41:10
# 	Test: 770/3797 - accuracy = 0.488 -  ETA = 3:41:07
# 	Test: 771/3797 - accuracy = 0.488 -  ETA = 3:41:05
# 	Test: 772/3797 - accuracy = 0.488 -  ETA = 3:41:01
# 	Test: 773/3797 - accuracy = 0.488 -  ETA = 3:40:58
# 	Test: 774/3797 - accuracy = 0.488 -  ETA = 3:40:56
# 	Test: 775/3797 - accuracy = 0.488 -  ETA = 3:40:53
# 	Test: 776/3797 - accuracy = 0.488 -  ETA = 3:40:52
# 	Test: 777/3797 - accuracy = 0.488 -  ETA = 3:40:49
# 	Test: 778/3797 - accuracy = 0.488 -  ETA = 3:40:46
# 	Test: 779/3797 - accuracy = 0.488 -  ETA = 3:40:44
# 	Test: 780/3797 - accuracy = 0.488 -  ETA = 3:40:41
# 	Test: 781/3797 - accuracy = 0.488 -  ETA = 3:40:39
# 	Test: 782/3797 - accuracy = 0.488 -  ETA = 3:40:36
# 	Test: 783/3797 - accuracy = 0.488 -  ETA = 3:40:34
# 	Test: 784/3797 - accuracy = 0.488 -  ETA = 3:40:30
# 	Test: 785/3797 - accuracy = 0.488 -  ETA = 3:40:27
# 	Test: 786/3797 - accuracy = 0.488 -  ETA = 3:40:25
# 	Test: 787/3797 - accuracy = 0.488 -  ETA = 3:40:21
# 	Test: 788/3797 - accuracy = 0.488 -  ETA = 3:40:18
# 	Test: 789/3797 - accuracy = 0.488 -  ETA = 3:40:15
# 	Test: 790/3797 - accuracy = 0.488 -  ETA = 3:40:12
# 	Test: 791/3797 - accuracy = 0.488 -  ETA = 3:40:10
# 	Test: 792/3797 - accuracy = 0.488 -  ETA = 3:40:07
# 	Test: 793/3797 - accuracy = 0.488 -  ETA = 3:40:04
# 	Test: 794/3797 - accuracy = 0.488 -  ETA = 3:40:01
# 	Test: 795/3797 - accuracy = 0.488 -  ETA = 3:39:59
# 	Test: 796/3797 - accuracy = 0.488 -  ETA = 3:39:57
# 	Test: 797/3797 - accuracy = 0.488 -  ETA = 3:39:55
# 	Test: 798/3797 - accuracy = 0.488 -  ETA = 3:39:53
# 	Test: 799/3797 - accuracy = 0.488 -  ETA = 3:39:51
# 	Test: 800/3797 - accuracy = 0.488 -  ETA = 3:39:48
# 	Test: 801/3797 - accuracy = 0.488 -  ETA = 3:39:47
# 	Test: 802/3797 - accuracy = 0.488 -  ETA = 3:39:45
# 	Test: 803/3797 - accuracy = 0.488 -  ETA = 3:39:42
# 	Test: 804/3797 - accuracy = 0.488 -  ETA = 3:39:40
# 	Test: 805/3797 - accuracy = 0.488 -  ETA = 3:39:37
# 	Test: 806/3797 - accuracy = 0.488 -  ETA = 3:39:34
# 	Test: 807/3797 - accuracy = 0.488 -  ETA = 3:39:31
# 	Test: 808/3797 - accuracy = 0.488 -  ETA = 3:39:29
# 	Test: 809/3797 - accuracy = 0.488 -  ETA = 3:39:26
# 	Test: 810/3797 - accuracy = 0.488 -  ETA = 3:39:22
# 	Test: 811/3797 - accuracy = 0.488 -  ETA = 3:39:19
# 	Test: 812/3797 - accuracy = 0.488 -  ETA = 3:39:17
# 	Test: 813/3797 - accuracy = 0.488 -  ETA = 3:39:14
# 	Test: 814/3797 - accuracy = 0.488 -  ETA = 3:39:11
# 	Test: 815/3797 - accuracy = 0.488 -  ETA = 3:39:08
# 	Test: 816/3797 - accuracy = 0.488 -  ETA = 3:39:05
# 	Test: 817/3797 - accuracy = 0.488 -  ETA = 3:39:03
# 	Test: 818/3797 - accuracy = 0.488 -  ETA = 3:39:00
# 	Test: 819/3797 - accuracy = 0.488 -  ETA = 3:38:57
# 	Test: 820/3797 - accuracy = 0.488 -  ETA = 3:38:55
# 	Test: 821/3797 - accuracy = 0.488 -  ETA = 3:38:52
# 	Test: 822/3797 - accuracy = 0.488 -  ETA = 3:38:49
# 	Test: 823/3797 - accuracy = 0.488 -  ETA = 3:38:46
# 	Test: 824/3797 - accuracy = 0.488 -  ETA = 3:38:43
# 	Test: 825/3797 - accuracy = 0.488 -  ETA = 3:38:39
# 	Test: 826/3797 - accuracy = 0.488 -  ETA = 3:38:36
# 	Test: 827/3797 - accuracy = 0.488 -  ETA = 3:38:33
# 	Test: 828/3797 - accuracy = 0.488 -  ETA = 3:38:30
# 	Test: 829/3797 - accuracy = 0.488 -  ETA = 3:38:27
# 	Test: 830/3797 - accuracy = 0.488 -  ETA = 3:38:23
# 	Test: 831/3797 - accuracy = 0.488 -  ETA = 3:38:20
# 	Test: 832/3797 - accuracy = 0.488 -  ETA = 3:38:17
# 	Test: 833/3797 - accuracy = 0.488 -  ETA = 3:38:14
# 	Test: 834/3797 - accuracy = 0.488 -  ETA = 3:38:11
# 	Test: 835/3797 - accuracy = 0.488 -  ETA = 3:38:08
# 	Test: 836/3797 - accuracy = 0.488 -  ETA = 3:38:05
# 	Test: 837/3797 - accuracy = 0.488 -  ETA = 3:38:02
# 	Test: 838/3797 - accuracy = 0.488 -  ETA = 3:38:00
# 	Test: 839/3797 - accuracy = 0.488 -  ETA = 3:37:57
# 	Test: 840/3797 - accuracy = 0.488 -  ETA = 3:37:55
# 	Test: 841/3797 - accuracy = 0.488 -  ETA = 3:37:53
# 	Test: 842/3797 - accuracy = 0.488 -  ETA = 3:37:50
# 	Test: 843/3797 - accuracy = 0.488 -  ETA = 3:37:49
# 	Test: 844/3797 - accuracy = 0.488 -  ETA = 3:37:47
# 	Test: 845/3797 - accuracy = 0.488 -  ETA = 3:37:44
# 	Test: 846/3797 - accuracy = 0.488 -  ETA = 3:37:42
# 	Test: 847/3797 - accuracy = 0.488 -  ETA = 3:37:39
# 	Test: 848/3797 - accuracy = 0.488 -  ETA = 3:37:37
# 	Test: 849/3797 - accuracy = 0.487 -  ETA = 3:37:35
# 	Test: 850/3797 - accuracy = 0.487 -  ETA = 3:37:32
# 	Test: 851/3797 - accuracy = 0.487 -  ETA = 3:37:31
# 	Test: 852/3797 - accuracy = 0.487 -  ETA = 3:37:29
# 	Test: 853/3797 - accuracy = 0.487 -  ETA = 3:37:27
# 	Test: 854/3797 - accuracy = 0.487 -  ETA = 3:37:24
# 	Test: 855/3797 - accuracy = 0.487 -  ETA = 3:37:22
# 	Test: 856/3797 - accuracy = 0.487 -  ETA = 3:37:19
# 	Test: 857/3797 - accuracy = 0.487 -  ETA = 3:37:17
# 	Test: 858/3797 - accuracy = 0.487 -  ETA = 3:37:15
# 	Test: 859/3797 - accuracy = 0.487 -  ETA = 3:37:13
# 	Test: 860/3797 - accuracy = 0.487 -  ETA = 3:37:11
# 	Test: 861/3797 - accuracy = 0.487 -  ETA = 3:37:09
# 	Test: 862/3797 - accuracy = 0.487 -  ETA = 3:37:07
# 	Test: 863/3797 - accuracy = 0.487 -  ETA = 3:37:04
# 	Test: 864/3797 - accuracy = 0.487 -  ETA = 3:37:03
# 	Test: 865/3797 - accuracy = 0.487 -  ETA = 3:37:00
# 	Test: 866/3797 - accuracy = 0.487 -  ETA = 3:36:58
# 	Test: 867/3797 - accuracy = 0.487 -  ETA = 3:36:58
# 	Test: 868/3797 - accuracy = 0.487 -  ETA = 3:36:58
# 	Test: 869/3797 - accuracy = 0.486 -  ETA = 3:36:55
# 	Test: 870/3797 - accuracy = 0.486 -  ETA = 3:36:53
# 	Test: 871/3797 - accuracy = 0.486 -  ETA = 3:36:52
# 	Test: 872/3797 - accuracy = 0.486 -  ETA = 3:36:50
# 	Test: 873/3797 - accuracy = 0.486 -  ETA = 3:36:47
# 	Test: 874/3797 - accuracy = 0.486 -  ETA = 3:36:45
# 	Test: 875/3797 - accuracy = 0.486 -  ETA = 3:36:44
# 	Test: 876/3797 - accuracy = 0.486 -  ETA = 3:36:42
# 	Test: 877/3797 - accuracy = 0.486 -  ETA = 3:36:40
# 	Test: 878/3797 - accuracy = 0.486 -  ETA = 3:36:38
# 	Test: 879/3797 - accuracy = 0.486 -  ETA = 3:36:36
# 	Test: 880/3797 - accuracy = 0.486 -  ETA = 3:36:34
# 	Test: 881/3797 - accuracy = 0.486 -  ETA = 3:36:31
# 	Test: 882/3797 - accuracy = 0.486 -  ETA = 3:36:29
# 	Test: 883/3797 - accuracy = 0.486 -  ETA = 3:36:27
# 	Test: 884/3797 - accuracy = 0.486 -  ETA = 3:36:25
# 	Test: 885/3797 - accuracy = 0.486 -  ETA = 3:36:22
# 	Test: 886/3797 - accuracy = 0.486 -  ETA = 3:36:20
# 	Test: 887/3797 - accuracy = 0.486 -  ETA = 3:36:18
# 	Test: 888/3797 - accuracy = 0.486 -  ETA = 3:36:15
# 	Test: 889/3797 - accuracy = 0.486 -  ETA = 3:36:13
# 	Test: 890/3797 - accuracy = 0.486 -  ETA = 3:36:12
# 	Test: 891/3797 - accuracy = 0.486 -  ETA = 3:36:10
# 	Test: 892/3797 - accuracy = 0.486 -  ETA = 3:36:07
# 	Test: 893/3797 - accuracy = 0.486 -  ETA = 3:36:05
# 	Test: 894/3797 - accuracy = 0.486 -  ETA = 3:36:03
# 	Test: 895/3797 - accuracy = 0.486 -  ETA = 3:36:01
# 	Test: 896/3797 - accuracy = 0.486 -  ETA = 3:35:59
# 	Test: 897/3797 - accuracy = 0.486 -  ETA = 3:35:57
# 	Test: 898/3797 - accuracy = 0.486 -  ETA = 3:35:55
# 	Test: 899/3797 - accuracy = 0.486 -  ETA = 3:35:53
# 	Test: 900/3797 - accuracy = 0.487 -  ETA = 3:35:51
# 	Test: 901/3797 - accuracy = 0.486 -  ETA = 3:35:49
# 	Test: 902/3797 - accuracy = 0.486 -  ETA = 3:35:47
# 	Test: 903/3797 - accuracy = 0.486 -  ETA = 3:35:45
# 	Test: 904/3797 - accuracy = 0.486 -  ETA = 3:35:43
# 	Test: 905/3797 - accuracy = 0.486 -  ETA = 3:35:41
# 	Test: 906/3797 - accuracy = 0.486 -  ETA = 3:35:38
# 	Test: 907/3797 - accuracy = 0.486 -  ETA = 3:35:36
# 	Test: 908/3797 - accuracy = 0.486 -  ETA = 3:35:33
# 	Test: 909/3797 - accuracy = 0.486 -  ETA = 3:35:30
# 	Test: 910/3797 - accuracy = 0.486 -  ETA = 3:35:29
# 	Test: 911/3797 - accuracy = 0.486 -  ETA = 3:35:26
# 	Test: 912/3797 - accuracy = 0.486 -  ETA = 3:35:24
# 	Test: 913/3797 - accuracy = 0.486 -  ETA = 3:35:22
# 	Test: 914/3797 - accuracy = 0.486 -  ETA = 3:35:20
# 	Test: 915/3797 - accuracy = 0.486 -  ETA = 3:35:17
# 	Test: 916/3797 - accuracy = 0.486 -  ETA = 3:35:15
# 	Test: 917/3797 - accuracy = 0.486 -  ETA = 3:35:14
# 	Test: 918/3797 - accuracy = 0.486 -  ETA = 3:35:11
# 	Test: 919/3797 - accuracy = 0.486 -  ETA = 3:35:09
# 	Test: 920/3797 - accuracy = 0.486 -  ETA = 3:35:06
# 	Test: 921/3797 - accuracy = 0.486 -  ETA = 3:35:05
# 	Test: 922/3797 - accuracy = 0.486 -  ETA = 3:35:02
# 	Test: 923/3797 - accuracy = 0.486 -  ETA = 3:34:59
# 	Test: 924/3797 - accuracy = 0.486 -  ETA = 3:34:57
# ...
# 	Test: 3015/3797 - accuracy = 0.489 -  ETA = 2:20:13
# 	Test: 3016/3797 - accuracy = 0.489 -  ETA = 2:20:11
# 	Test: 3017/3797 - accuracy = 0.489 -  ETA = 2:20:09
# 	Test: 3018/3797 - accuracy = 0.489 -  ETA = 2:20:07
# 	Test: 3019/3797 - accuracy = 0.489 -  ETA = 2:20:05
# 	Test: 3020/3797 - accuracy = 0.489 -  ETA = 2:20:03
# 	Test: 3021/3797 - accuracy = 0.489 -  ETA = 2:20:01
# 	Test: 3022/3797 - accuracy = 0.489 -  ETA = 2:19:59
# 	Test: 3023/3797 - accuracy = 0.489 -  ETA = 2:19:57
# 	Test: 3024/3797 - accuracy = 0.489 -  ETA = 2:19:55
# 	Test: 3025/3797 - accuracy = 0.489 -  ETA = 2:19:53
# 	Test: 3026/3797 - accuracy = 0.489 -  ETA = 2:19:51
# 	Test: 3027/3797 - accuracy = 0.489 -  ETA = 2:19:49
# 	Test: 3028/3797 - accuracy = 0.489 -  ETA = 2:19:47
# 	Test: 3029/3797 - accuracy = 0.489 -  ETA = 2:19:45
# 	Test: 3030/3797 - accuracy = 0.489 -  ETA = 2:19:43
# 	Test: 3031/3797 - accuracy = 0.489 -  ETA = 2:19:41
# 	Test: 3032/3797 - accuracy = 0.489 -  ETA = 2:19:39
# 	Test: 3033/3797 - accuracy = 0.489 -  ETA = 2:19:37
# 	Test: 3034/3797 - accuracy = 0.489 -  ETA = 2:19:35
# 	Test: 3035/3797 - accuracy = 0.489 -  ETA = 2:19:33
# 	Test: 3036/3797 - accuracy = 0.489 -  ETA = 2:19:31
# 	Test: 3037/3797 - accuracy = 0.489 -  ETA = 2:19:29
# 	Test: 3038/3797 - accuracy = 0.489 -  ETA = 2:19:27
# 	Test: 3039/3797 - accuracy = 0.489 -  ETA = 2:19:25
# 	Test: 3040/3797 - accuracy = 0.489 -  ETA = 2:19:23
# 	Test: 3041/3797 - accuracy = 0.489 -  ETA = 2:19:21
# 	Test: 3042/3797 - accuracy = 0.489 -  ETA = 2:19:19
# 	Test: 3043/3797 - accuracy = 0.489 -  ETA = 2:19:17
# 	Test: 3044/3797 - accuracy = 0.489 -  ETA = 2:19:15
# 	Test: 3045/3797 - accuracy = 0.489 -  ETA = 2:19:13
# 	Test: 3046/3797 - accuracy = 0.489 -  ETA = 2:19:11
# 	Test: 3047/3797 - accuracy = 0.489 -  ETA = 2:19:10
# 	Test: 3048/3797 - accuracy = 0.489 -  ETA = 2:19:08
# 	Test: 3049/3797 - accuracy = 0.489 -  ETA = 2:19:06
# 	Test: 3050/3797 - accuracy = 0.489 -  ETA = 2:19:04
# 	Test: 3051/3797 - accuracy = 0.489 -  ETA = 2:19:02
# 	Test: 3052/3797 - accuracy = 0.489 -  ETA = 2:19:00
# 	Test: 3053/3797 - accuracy = 0.489 -  ETA = 2:18:58
# 	Test: 3054/3797 - accuracy = 0.489 -  ETA = 2:18:56
# 	Test: 3055/3797 - accuracy = 0.489 -  ETA = 2:18:54
# 	Test: 3056/3797 - accuracy = 0.489 -  ETA = 2:18:52
# 	Test: 3057/3797 - accuracy = 0.489 -  ETA = 2:18:50
# 	Test: 3058/3797 - accuracy = 0.489 -  ETA = 2:18:48
# 	Test: 3059/3797 - accuracy = 0.489 -  ETA = 2:18:46
# 	Test: 3060/3797 - accuracy = 0.489 -  ETA = 2:18:44
# 	Test: 3061/3797 - accuracy = 0.489 -  ETA = 2:18:42
# 	Test: 3062/3797 - accuracy = 0.489 -  ETA = 2:18:40
# 	Test: 3063/3797 - accuracy = 0.489 -  ETA = 2:18:38
# 	Test: 3064/3797 - accuracy = 0.489 -  ETA = 2:18:36
# 	Test: 3065/3797 - accuracy = 0.489 -  ETA = 2:18:35
# 	Test: 3066/3797 - accuracy = 0.489 -  ETA = 2:18:33
# 	Test: 3067/3797 - accuracy = 0.489 -  ETA = 2:18:31
# 	Test: 3068/3797 - accuracy = 0.489 -  ETA = 2:18:29
# 	Test: 3069/3797 - accuracy = 0.489 -  ETA = 2:18:27
# 	Test: 3070/3797 - accuracy = 0.489 -  ETA = 2:18:25
# 	Test: 3071/3797 - accuracy = 0.489 -  ETA = 2:18:23
# 	Test: 3072/3797 - accuracy = 0.489 -  ETA = 2:18:21
# 	Test: 3073/3797 - accuracy = 0.489 -  ETA = 2:18:19
# 	Test: 3074/3797 - accuracy = 0.489 -  ETA = 2:18:17
# 	Test: 3075/3797 - accuracy = 0.489 -  ETA = 2:18:15
# 	Test: 3076/3797 - accuracy = 0.489 -  ETA = 2:18:13
# 	Test: 3077/3797 - accuracy = 0.489 -  ETA = 2:18:11
# 	Test: 3078/3797 - accuracy = 0.489 -  ETA = 2:18:09
# 	Test: 3079/3797 - accuracy = 0.489 -  ETA = 2:18:07
# 	Test: 3080/3797 - accuracy = 0.489 -  ETA = 2:18:05
# 	Test: 3081/3797 - accuracy = 0.489 -  ETA = 2:18:03
# 	Test: 3082/3797 - accuracy = 0.489 -  ETA = 2:18:01
# 	Test: 3083/3797 - accuracy = 0.489 -  ETA = 2:17:59
# 	Test: 3084/3797 - accuracy = 0.489 -  ETA = 2:17:57
# 	Test: 3085/3797 - accuracy = 0.489 -  ETA = 2:17:55
# 	Test: 3086/3797 - accuracy = 0.489 -  ETA = 2:17:53
# 	Test: 3087/3797 - accuracy = 0.489 -  ETA = 2:17:51
# 	Test: 3088/3797 - accuracy = 0.489 -  ETA = 2:17:49
# 	Test: 3089/3797 - accuracy = 0.489 -  ETA = 2:17:47
# 	Test: 3090/3797 - accuracy = 0.489 -  ETA = 2:17:45
# 	Test: 3091/3797 - accuracy = 0.489 -  ETA = 2:17:43
# 	Test: 3092/3797 - accuracy = 0.489 -  ETA = 2:17:41
# 	Test: 3093/3797 - accuracy = 0.489 -  ETA = 2:17:39
# 	Test: 3094/3797 - accuracy = 0.489 -  ETA = 2:17:37
# 	Test: 3095/3797 - accuracy = 0.489 -  ETA = 2:17:35
# 	Test: 3096/3797 - accuracy = 0.489 -  ETA = 2:17:33
# 	Test: 3097/3797 - accuracy = 0.489 -  ETA = 2:17:31
# 	Test: 3098/3797 - accuracy = 0.489 -  ETA = 2:17:29
# 	Test: 3099/3797 - accuracy = 0.489 -  ETA = 2:17:27
# 	Test: 3100/3797 - accuracy = 0.489 -  ETA = 2:17:25
# 	Test: 3101/3797 - accuracy = 0.489 -  ETA = 2:17:23
# 	Test: 3102/3797 - accuracy = 0.489 -  ETA = 2:17:21
# 	Test: 3103/3797 - accuracy = 0.489 -  ETA = 2:17:19
# 	Test: 3104/3797 - accuracy = 0.489 -  ETA = 2:17:17
# 	Test: 3105/3797 - accuracy = 0.489 -  ETA = 2:17:15
# 	Test: 3106/3797 - accuracy = 0.489 -  ETA = 2:17:13
# 	Test: 3107/3797 - accuracy = 0.489 -  ETA = 2:17:11
# 	Test: 3108/3797 - accuracy = 0.489 -  ETA = 2:17:09
# 	Test: 3109/3797 - accuracy = 0.489 -  ETA = 2:17:07
# 	Test: 3110/3797 - accuracy = 0.489 -  ETA = 2:17:05
# 	Test: 3111/3797 - accuracy = 0.489 -  ETA = 2:17:04
# 	Test: 3112/3797 - accuracy = 0.489 -  ETA = 2:17:02
# 	Test: 3113/3797 - accuracy = 0.489 -  ETA = 2:17:00
# 	Test: 3114/3797 - accuracy = 0.489 -  ETA = 2:16:58
# 	Test: 3115/3797 - accuracy = 0.489 -  ETA = 2:16:56
# 	Test: 3116/3797 - accuracy = 0.489 -  ETA = 2:16:54
# 	Test: 3117/3797 - accuracy = 0.489 -  ETA = 2:16:52
# 	Test: 3118/3797 - accuracy = 0.489 -  ETA = 2:16:50
# 	Test: 3119/3797 - accuracy = 0.489 -  ETA = 2:16:48
# 	Test: 3120/3797 - accuracy = 0.489 -  ETA = 2:16:47
# 	Test: 3121/3797 - accuracy = 0.489 -  ETA = 2:16:45
# 	Test: 3122/3797 - accuracy = 0.489 -  ETA = 2:16:43
# 	Test: 3123/3797 - accuracy = 0.489 -  ETA = 2:16:41
# 	Test: 3124/3797 - accuracy = 0.489 -  ETA = 2:16:39
# 	Test: 3125/3797 - accuracy = 0.489 -  ETA = 2:16:37
# 	Test: 3126/3797 - accuracy = 0.489 -  ETA = 2:16:35
# 	Test: 3127/3797 - accuracy = 0.489 -  ETA = 2:16:33
# 	Test: 3128/3797 - accuracy = 0.489 -  ETA = 2:16:31
# 	Test: 3129/3797 - accuracy = 0.489 -  ETA = 2:16:29
# 	Test: 3130/3797 - accuracy = 0.489 -  ETA = 2:16:27
# 	Test: 3131/3797 - accuracy = 0.489 -  ETA = 2:16:25
# 	Test: 3132/3797 - accuracy = 0.489 -  ETA = 2:16:23
# 	Test: 3133/3797 - accuracy = 0.489 -  ETA = 2:16:21
# 	Test: 3134/3797 - accuracy = 0.489 -  ETA = 2:16:19
# 	Test: 3135/3797 - accuracy = 0.489 -  ETA = 2:16:17
# 	Test: 3136/3797 - accuracy = 0.489 -  ETA = 2:16:15
# 	Test: 3137/3797 - accuracy = 0.489 -  ETA = 2:16:13
# 	Test: 3138/3797 - accuracy = 0.489 -  ETA = 2:16:11
# 	Test: 3139/3797 - accuracy = 0.489 -  ETA = 2:16:09
# 	Test: 3140/3797 - accuracy = 0.489 -  ETA = 2:16:07
# 	Test: 3141/3797 - accuracy = 0.489 -  ETA = 2:16:05
# 	Test: 3142/3797 - accuracy = 0.489 -  ETA = 2:16:03
# 	Test: 3143/3797 - accuracy = 0.489 -  ETA = 2:16:01
# 	Test: 3144/3797 - accuracy = 0.489 -  ETA = 2:15:59
# 	Test: 3145/3797 - accuracy = 0.489 -  ETA = 2:15:57
# 	Test: 3146/3797 - accuracy = 0.489 -  ETA = 2:15:55
# 	Test: 3147/3797 - accuracy = 0.489 -  ETA = 2:15:53
# 	Test: 3148/3797 - accuracy = 0.489 -  ETA = 2:15:52
# 	Test: 3149/3797 - accuracy = 0.489 -  ETA = 2:15:50
# 	Test: 3150/3797 - accuracy = 0.489 -  ETA = 2:15:48
# 	Test: 3151/3797 - accuracy = 0.489 -  ETA = 2:15:46
# 	Test: 3152/3797 - accuracy = 0.489 -  ETA = 2:15:44
# 	Test: 3153/3797 - accuracy = 0.489 -  ETA = 2:15:42
# 	Test: 3154/3797 - accuracy = 0.489 -  ETA = 2:15:40
# 	Test: 3155/3797 - accuracy = 0.489 -  ETA = 2:15:38
# 	Test: 3156/3797 - accuracy = 0.489 -  ETA = 2:15:36
# 	Test: 3157/3797 - accuracy = 0.489 -  ETA = 2:15:34
# 	Test: 3158/3797 - accuracy = 0.489 -  ETA = 2:15:32
# 	Test: 3159/3797 - accuracy = 0.489 -  ETA = 2:15:30
# 	Test: 3160/3797 - accuracy = 0.489 -  ETA = 2:15:28
# 	Test: 3161/3797 - accuracy = 0.489 -  ETA = 2:15:26
# 	Test: 3162/3797 - accuracy = 0.489 -  ETA = 2:15:24
# 	Test: 3163/3797 - accuracy = 0.489 -  ETA = 2:15:22
# 	Test: 3164/3797 - accuracy = 0.489 -  ETA = 2:15:20
# 	Test: 3165/3797 - accuracy = 0.489 -  ETA = 2:15:18
# 	Test: 3166/3797 - accuracy = 0.489 -  ETA = 2:15:16
# 	Test: 3167/3797 - accuracy = 0.489 -  ETA = 2:15:14
# 	Test: 3168/3797 - accuracy = 0.489 -  ETA = 2:15:13
# 	Test: 3169/3797 - accuracy = 0.489 -  ETA = 2:15:11
# 	Test: 3170/3797 - accuracy = 0.489 -  ETA = 2:15:09
# 	Test: 3171/3797 - accuracy = 0.489 -  ETA = 2:15:07
# 	Test: 3172/3797 - accuracy = 0.489 -  ETA = 2:15:05
# 	Test: 3173/3797 - accuracy = 0.489 -  ETA = 2:15:03
# 	Test: 3174/3797 - accuracy = 0.489 -  ETA = 2:15:01
# 	Test: 3175/3797 - accuracy = 0.489 -  ETA = 2:14:59
# 	Test: 3176/3797 - accuracy = 0.489 -  ETA = 2:14:57
# 	Test: 3177/3797 - accuracy = 0.489 -  ETA = 2:14:55
# 	Test: 3178/3797 - accuracy = 0.489 -  ETA = 2:14:53
# 	Test: 3179/3797 - accuracy = 0.489 -  ETA = 2:14:51
# 	Test: 3180/3797 - accuracy = 0.489 -  ETA = 2:14:49
# 	Test: 3181/3797 - accuracy = 0.489 -  ETA = 2:14:47
# 	Test: 3182/3797 - accuracy = 0.489 -  ETA = 2:14:45
# 	Test: 3183/3797 - accuracy = 0.489 -  ETA = 2:14:43
# 	Test: 3184/3797 - accuracy = 0.489 -  ETA = 2:14:41
# 	Test: 3185/3797 - accuracy = 0.489 -  ETA = 2:14:39
# 	Test: 3186/3797 - accuracy = 0.489 -  ETA = 2:14:37
# 	Test: 3187/3797 - accuracy = 0.489 -  ETA = 2:14:35
# 	Test: 3188/3797 - accuracy = 0.489 -  ETA = 2:14:33
# 	Test: 3189/3797 - accuracy = 0.489 -  ETA = 2:14:31
# 	Test: 3190/3797 - accuracy = 0.489 -  ETA = 2:14:29
# 	Test: 3191/3797 - accuracy = 0.489 -  ETA = 2:14:27
# 	Test: 3192/3797 - accuracy = 0.489 -  ETA = 2:14:25
# 	Test: 3193/3797 - accuracy = 0.489 -  ETA = 2:14:23
# 	Test: 3194/3797 - accuracy = 0.489 -  ETA = 2:14:21
# 	Test: 3195/3797 - accuracy = 0.489 -  ETA = 2:14:19
# 	Test: 3196/3797 - accuracy = 0.489 -  ETA = 2:14:17
# 	Test: 3197/3797 - accuracy = 0.489 -  ETA = 2:14:15
# 	Test: 3198/3797 - accuracy = 0.489 -  ETA = 2:14:13
# 	Test: 3199/3797 - accuracy = 0.489 -  ETA = 2:14:11
# 	Test: 3200/3797 - accuracy = 0.489 -  ETA = 2:14:10
# 	Test: 3201/3797 - accuracy = 0.489 -  ETA = 2:14:08
# 	Test: 3202/3797 - accuracy = 0.489 -  ETA = 2:14:06
# 	Test: 3203/3797 - accuracy = 0.489 -  ETA = 2:14:04
# 	Test: 3204/3797 - accuracy = 0.489 -  ETA = 2:14:02
# 	Test: 3205/3797 - accuracy = 0.489 -  ETA = 2:14:00
# 	Test: 3206/3797 - accuracy = 0.489 -  ETA = 2:13:58
# 	Test: 3207/3797 - accuracy = 0.489 -  ETA = 2:13:56
# 	Test: 3208/3797 - accuracy = 0.489 -  ETA = 2:13:54
# 	Test: 3209/3797 - accuracy = 0.489 -  ETA = 2:13:52
# 	Test: 3210/3797 - accuracy = 0.489 -  ETA = 2:13:50
# 	Test: 3211/3797 - accuracy = 0.489 -  ETA = 2:13:48
# 	Test: 3212/3797 - accuracy = 0.489 -  ETA = 2:13:46
# 	Test: 3213/3797 - accuracy = 0.489 -  ETA = 2:13:44
# 	Test: 3214/3797 - accuracy = 0.489 -  ETA = 2:13:42
# 	Test: 3215/3797 - accuracy = 0.489 -  ETA = 2:13:40
# 	Test: 3216/3797 - accuracy = 0.489 -  ETA = 2:13:38
# 	Test: 3217/3797 - accuracy = 0.489 -  ETA = 2:13:36
# 	Test: 3218/3797 - accuracy = 0.489 -  ETA = 2:13:34
# 	Test: 3219/3797 - accuracy = 0.489 -  ETA = 2:13:32
# 	Test: 3220/3797 - accuracy = 0.489 -  ETA = 2:13:30
# 	Test: 3221/3797 - accuracy = 0.489 -  ETA = 2:13:28
# 	Test: 3222/3797 - accuracy = 0.489 -  ETA = 2:13:27
# 	Test: 3223/3797 - accuracy = 0.489 -  ETA = 2:13:25
# 	Test: 3224/3797 - accuracy = 0.489 -  ETA = 2:13:23
# 	Test: 3225/3797 - accuracy = 0.489 -  ETA = 2:13:21
# 	Test: 3226/3797 - accuracy = 0.489 -  ETA = 2:13:19
# 	Test: 3227/3797 - accuracy = 0.489 -  ETA = 2:13:17
# 	Test: 3228/3797 - accuracy = 0.489 -  ETA = 2:13:15
# 	Test: 3229/3797 - accuracy = 0.489 -  ETA = 2:13:13
# 	Test: 3230/3797 - accuracy = 0.489 -  ETA = 2:13:11
# 	Test: 3231/3797 - accuracy = 0.489 -  ETA = 2:13:09
# 	Test: 3232/3797 - accuracy = 0.489 -  ETA = 2:13:07
# 	Test: 3233/3797 - accuracy = 0.489 -  ETA = 2:13:05
# 	Test: 3234/3797 - accuracy = 0.489 -  ETA = 2:13:03
# 	Test: 3235/3797 - accuracy = 0.489 -  ETA = 2:13:01
# 	Test: 3236/3797 - accuracy = 0.489 -  ETA = 2:12:59
# 	Test: 3237/3797 - accuracy = 0.489 -  ETA = 2:12:57
# 	Test: 3238/3797 - accuracy = 0.489 -  ETA = 2:12:55
# 	Test: 3239/3797 - accuracy = 0.489 -  ETA = 2:12:53
# 	Test: 3240/3797 - accuracy = 0.489 -  ETA = 2:12:51
# 	Test: 3241/3797 - accuracy = 0.489 -  ETA = 2:12:50
# 	Test: 3242/3797 - accuracy = 0.489 -  ETA = 2:12:48
# 	Test: 3243/3797 - accuracy = 0.489 -  ETA = 2:12:46
# 	Test: 3244/3797 - accuracy = 0.489 -  ETA = 2:12:44
# 	Test: 3245/3797 - accuracy = 0.489 -  ETA = 2:12:42
# 	Test: 3246/3797 - accuracy = 0.489 -  ETA = 2:12:40
# 	Test: 3247/3797 - accuracy = 0.489 -  ETA = 2:12:38
# 	Test: 3248/3797 - accuracy = 0.489 -  ETA = 2:12:36
# 	Test: 3249/3797 - accuracy = 0.489 -  ETA = 2:12:34
# 	Test: 3250/3797 - accuracy = 0.489 -  ETA = 2:12:32
# 	Test: 3251/3797 - accuracy = 0.489 -  ETA = 2:12:30
# 	Test: 3252/3797 - accuracy = 0.489 -  ETA = 2:12:28
# 	Test: 3253/3797 - accuracy = 0.489 -  ETA = 2:12:26
# 	Test: 3254/3797 - accuracy = 0.489 -  ETA = 2:12:24
# 	Test: 3255/3797 - accuracy = 0.489 -  ETA = 2:12:22
# 	Test: 3256/3797 - accuracy = 0.489 -  ETA = 2:12:20
# 	Test: 3257/3797 - accuracy = 0.489 -  ETA = 2:12:18
# 	Test: 3258/3797 - accuracy = 0.489 -  ETA = 2:12:16
# 	Test: 3259/3797 - accuracy = 0.489 -  ETA = 2:12:14
# 	Test: 3260/3797 - accuracy = 0.489 -  ETA = 2:12:12
# 	Test: 3261/3797 - accuracy = 0.489 -  ETA = 2:12:10
# 	Test: 3262/3797 - accuracy = 0.489 -  ETA = 2:12:08
# 	Test: 3263/3797 - accuracy = 0.489 -  ETA = 2:12:06
# 	Test: 3264/3797 - accuracy = 0.489 -  ETA = 2:12:04
# 	Test: 3265/3797 - accuracy = 0.489 -  ETA = 2:12:02
# 	Test: 3266/3797 - accuracy = 0.489 -  ETA = 2:12:00
# 	Test: 3267/3797 - accuracy = 0.489 -  ETA = 2:11:58
# 	Test: 3268/3797 - accuracy = 0.489 -  ETA = 2:11:56
# 	Test: 3269/3797 - accuracy = 0.489 -  ETA = 2:11:54
# 	Test: 3270/3797 - accuracy = 0.489 -  ETA = 2:11:53
# 	Test: 3271/3797 - accuracy = 0.489 -  ETA = 2:11:51
# 	Test: 3272/3797 - accuracy = 0.489 -  ETA = 2:11:49
# 	Test: 3273/3797 - accuracy = 0.489 -  ETA = 2:11:47
# 	Test: 3274/3797 - accuracy = 0.489 -  ETA = 2:11:45
# 	Test: 3275/3797 - accuracy = 0.489 -  ETA = 2:11:43
# 	Test: 3276/3797 - accuracy = 0.489 -  ETA = 2:11:41
# 	Test: 3277/3797 - accuracy = 0.489 -  ETA = 2:11:39
# 	Test: 3278/3797 - accuracy = 0.489 -  ETA = 2:11:37
# 	Test: 3279/3797 - accuracy = 0.489 -  ETA = 2:11:35
# 	Test: 3280/3797 - accuracy = 0.489 -  ETA = 2:11:33
# 	Test: 3281/3797 - accuracy = 0.489 -  ETA = 2:11:31
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-d1b1b84e8324> in <module>()
# ----> 1 test_acc = test()
#       2 train_loss = np.mean(epoch_loss)
#       3 output_file.write("Epoch %d - train loss = %1.3f - test accuracy = %1.3f\n" % (epoch,train_loss,test_acc))
#       4 output_file.flush()
#       5 saver.save(sess, join(model_path,'model'), global_step=epoch)
#
# <ipython-input-75-eb25a2c158aa> in test()
#      44     for idx,batch in enumerate(val_gen):
#      45         tic = time()
# ---> 46         feed_dict = create_feeddict(batch)
#      47         y_pred = sess.run(out_probas,feed_dict=feed_dict).argmax(axis=1)
#      48         accuracy += np.sum(feed_dict[Pl['answers']][np.arange(batch_size),y_pred])
#
# <ipython-input-75-eb25a2c158aa> in create_feeddict(batch)
#      16         box[:,[2,4]] = (box[:,[2,4]]*im_l.shape[0]/im.size[0])/16 + box[:,[1,3]]
#      17         boxes[batch_id*max_bb:(batch_id+1)*max_bb] = box
# ---> 18         questions[batch_id] = np.pad(q,(0,max_q-len(q)),'constant')
#      19         question_mask[len(q)-1,batch_id] = 1
#      20         multiple_choice.append(mc)
#
# /usr/local/lib/python3.4/dist-packages/numpy/lib/arraypad.py in pad(array, pad_width, mode, **kwargs)
#    1316
#    1317     narray = np.array(array)
# -> 1318     pad_width = _validate_lengths(narray, pad_width)
#    1319
#    1320     allowedkwargs = {
#
# /usr/local/lib/python3.4/dist-packages/numpy/lib/arraypad.py in _validate_lengths(narray, number_elements)
#    1107         if (chk[0] < 0) or (chk[1] < 0):
#    1108             fmt = "%s cannot contain negative values."
# -> 1109             raise ValueError(fmt % (number_elements,))
#    1110     return normshp
#    1111
#
# ValueError: (0, -1) cannot contain negative values.
