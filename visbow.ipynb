# %%
# %load_ext autoreload
# %autoreload 2
from os import listdir, mkdir
from os.path import join, exists
from time import time
import json


import tensorflow as tf
import numpy as np


import skimage
from skimage.transform import resize
from scipy.misc import imread
from collections import Counter
from time import time

from utils import load_dataset, load_vocab,read_features, Dataset, load_emb_matrix
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class VisBOW(object):
    def __init__(self, hyperparams):
        self.dq = hyperparams['dq']
        self.da = hyperparams['da']
        self.di = hyperparams['di']
        self.Nq = hyperparams['Nq']
        self.Na = hyperparams['Na']
        self.trainable_embeddings = hyperparams['trainable_embeddings']
        
        with tf.device('/cpu:0'):
            self.qemb_W = tf.get_variable('qemb_w',
                                          initializer=tf.random_uniform([self.Nq, self.dq], -0.1, 0.1),
                                          trainable = self.trainable_embeddings)
        
        self.W = tf.get_variable('W',shape = [self.dq + self.di, self.Na],
                                 initializer=tf.contrib.layers.xavier_initializer())
        self.b = tf.get_variable('b',
                                 initializer=tf.zeros_initializer([self.Na]))
    def build_model(self):
        
        p_image = tf.placeholder(tf.float32,
                                [None, self.di],
                                 name="p_image")        
        p_question = tf.placeholder(tf.int32, 
                                    [None, None],
                                    name="p_question")
        p_answer = tf.placeholder(tf.float32, 
                                  [None,self.Na],
                                  name="p_answer")
        with tf.device('/cpu:0'):
            question_seq = tf.nn.embedding_lookup(self.qemb_W, p_question)
            question_emb = tf.reduce_sum(question_seq, reduction_indices=[1])
        concat = tf.concat(1, [p_image, question_emb])
        answer_logits = tf.nn.xw_plus_b(concat,self.W,self.b)
        cross_entropy = tf.nn.softmax_cross_entropy_with_logits(answer_logits, p_answer) # (batch_size, )
        
        answer_pred = tf.argmax(answer_logits,1)
        loss = tf.reduce_mean(cross_entropy)
        loss_s = tf.scalar_summary('train loss', loss, name='train_loss')
        train_op = tf.train.AdamOptimizer().minimize(loss)
        
        
        p_acc = tf.placeholder(tf.float32,name='acc',shape=None)
        test_acc_s = tf.scalar_summary("test acc",p_acc,name="test_acc")

        output = {'train_op':train_op,
                 'loss':loss,
                  'loss_s':loss_s,
                 'question':p_question,
                 'answer':p_answer,
                  'acc':p_acc,
                  'acc_s':test_acc_s,
                 'answer_pred':answer_pred,
                 'image':p_image}
        return output

# %%
train_set = Dataset("/home/hbenyounes/vqa/datasets/coco/train/images.feat",
                    "/home/hbenyounes/vqa/datasets/coco/train/img_ids.txt",
                    "/home/hbenyounes/vqa/datasets/coco/train/questions.idxs",
                    "/home/hbenyounes/vqa/datasets/coco/train/answers.idxs")


test_set = Dataset("/home/hbenyounes/vqa/datasets/coco/test/images.feat",
                    "/home/hbenyounes/vqa/datasets/coco/test/img_ids.txt",
                    "/home/hbenyounes/vqa/datasets/coco/test/questions.idxs",
                    "/home/hbenyounes/vqa/datasets/coco/test/answers.idxs")

q_i2w, q_w2i = load_vocab('datasets/coco/train/questions.vocab')
a_i2w, a_w2i = load_vocab('datasets/coco/train/answers.vocab')
# Out:
# Parse features file
# Parse questions file
# Parse answers file
# Parse features file
# Parse questions file
# Parse answers file

# %%
print("Graph initialization")
model_name = "model8"
root_path = "/home/hbenyounes/vqa/visbow/"
embedding_path = '/home/hbenyounes/vqa/GoogleNews.model'
if not exists(join(root_path, model_name)):
    mkdir(join(root_path, model_name))
vector_size = 600
max_q = train_set.max_q
H = {"dq":vector_size,
     "da":vector_size/2, 
     "di":4096,
     "Nq":len(q_i2w),
     "Na":len(a_i2w),
     "batch_size":200,
     "trainable_embeddings":True,
     "word2vec":False}
tf.reset_default_graph()
model = VisBOW(H)
M = model.build_model()
if H['word2vec']:
    q_i2w, q_w2i = load_vocab('datasets/coco/train/questions.vocab')
    print("Load word2Vec")
    embeddings = {}
    for n,l in enumerate(open(embedding_path,encoding='utf-8')):
        l = l.strip().split()
        w = l[0]
        vec = [float(x) for x in l[1:]]
        embeddings[w] = vec
    emb,c = load_emb_matrix(q_i2w, embeddings, vector_size)
    del embeddings
    
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.6)
sess = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options, 
                                                   intra_op_parallelism_threads=1))

saver = tf.train.Saver(max_to_keep=100)
writer = tf.train.SummaryWriter(join(root_path,model_name,'tf_log'), sess.graph)

init = tf.initialize_all_variables()
sess.run(init)

if H['word2vec']:
    sess.run(model.qemb_W.assign(emb))
n_parameters = sum( [np.prod(v.get_shape(),dtype='int') for v in tf.trainable_variables()])
H['n_parameters'] = n_parameters
# Out:
# Graph initialization

# %%
def create_feed_dict(batch,Na,batch_size,max_q=None):
    if max_q is None:
        max_q = max([len(b[1]) for b in batch])
    V = np.zeros((batch_size, len(batch[0][0])), 'float32')
    Q = np.zeros((batch_size, max_q), 'int32')
    ans = np.zeros((batch_size,Na),'int32')
    
    for i,(im,s,a) in enumerate(batch):
        V[i] = im
        Q[i] = np.pad(s, (0,max_q-len(s)), 'constant')
        ans[i,a] = 1
    return V,Q,ans

def test(verbose=None):
    acc = []
    test_batches = test_set.batch_gen(H['batch_size'])
    for idx,batch in enumerate(test_batches):    
        if verbose:
            if idx%20==0:
                print("%d - accuracy = %1.3f"%(idx, np.mean(acc)))
        V,Q,ans = create_feed_dict(batch,H['Na'],H['batch_size'])
        a_pred = sess.run(M['answer_pred'], 
                          feed_dict={M['question']:Q,
                                     M['answer']:ans,
                                     M['image']:V})
        equals = 1*np.equal(ans.argmax(axis=1),a_pred)
        equals = list(equals[:len(batch)])
        acc += equals
    return acc

# %%
break_all = False
ct = 0
toc = time()
with tf.device('/gpu:0'):
    n_epochs = 100
    max_test_acc = -np.Inf
    patience = 0
    for epoch in range(0,n_epochs):
        epoch_loss = []
        times = 0.
        times_fd = 0.
        n_batches = train_set.N // H['batch_size']
        train_batches = train_set.batch_gen(H['batch_size'])
        for idx,batch in enumerate(train_batches):
            step = idx + epoch*n_batches
            tic = time()
            if idx%(n_batches//10)==0:
                ct += 1
                print("Epoch %d - %d/%d : loss = %1.4f - elapsed = %1.3fs "%(epoch,idx,
                                       n_batches,
                                       np.mean(epoch_loss),
                                       times))
                print("time sess.run = %1.3fs" % times_fd)
                times_fd = 0.
            V,Q,ans = create_feed_dict(batch,H['Na'],H['batch_size'])
            tic_fd = time()
            _,l,l_s = sess.run([M['train_op'],
                                M['loss'],
                                M['loss_s']], 
                                   feed_dict={M['question']:Q,
                                      M['answer']:ans,
                                      M['image']:V})
            toc_fd = time()
            times_fd += toc_fd - tic_fd
            writer.add_summary(l_s,step)
            
            if np.isnan(l):
                break_all = True
            epoch_loss.append(l)
            toc = time()
            times += toc - tic
            if break_all:
                print("Loss is nan at iteration %d" % (idx+n_batches*epoch))
                break
        if break_all:
            break
        with tf.device('/cpu:0'):
            acc = np.mean(test())
            test_acc_s = sess.run(M['acc_s'], feed_dict={M['acc']:acc})
            writer.add_summary(test_acc_s,step)
            print("Epoch %d - Test accuracy = %1.3f" % (epoch+1, acc))
        if acc > max_test_acc:
            patience += 3
            saver.save(sess, join(root_path,model_name,'model'), global_step=epoch)
        max_test_acc = max(acc, max_test_acc)
        if epoch >= patience:
            print("EARLY STOPPING")
            break
            
H['max_test_acc'] = max_test_acc
with open(join(root_path, model_name, 'hyperparams'),'w') as f:
    for h in H:
        f.write("%s = %s\n" % (h, str(H[h])))
    f.write('\n\nMaximal test accuracy = %1.4f\n' % max_test_acc)
# Out:
# /usr/local/lib/python3.4/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Epoch 0 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 0 - 39/393 : loss = 4.9059 - elapsed = 5.841s
# time sess.run = 3.948s
# Epoch 0 - 78/393 : loss = 4.2566 - elapsed = 11.491s
# time sess.run = 3.848s
# Epoch 0 - 117/393 : loss = 3.9164 - elapsed = 17.333s
# time sess.run = 3.859s
# Epoch 0 - 156/393 : loss = 3.6988 - elapsed = 23.133s
# time sess.run = 3.972s
# Epoch 0 - 195/393 : loss = 3.5620 - elapsed = 28.963s
# time sess.run = 3.897s
# Epoch 0 - 234/393 : loss = 3.4541 - elapsed = 35.031s
# time sess.run = 4.129s
# Epoch 0 - 273/393 : loss = 3.3617 - elapsed = 41.243s
# time sess.run = 4.235s
# Epoch 0 - 312/393 : loss = 3.2812 - elapsed = 47.451s
# time sess.run = 4.263s
# Epoch 0 - 351/393 : loss = 3.2175 - elapsed = 53.727s
# time sess.run = 4.323s
# Epoch 0 - 390/393 : loss = 3.1640 - elapsed = 59.938s
# time sess.run = 4.260s
# Epoch 1 - Test accuracy = 0.442
# Epoch 1 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 1 - 39/393 : loss = 1.3328 - elapsed = 5.881s
# time sess.run = 3.937s
# Epoch 1 - 78/393 : loss = 1.3694 - elapsed = 11.616s
# time sess.run = 3.768s
# Epoch 1 - 117/393 : loss = 1.3894 - elapsed = 17.538s
# time sess.run = 3.987s
# Epoch 1 - 156/393 : loss = 1.4214 - elapsed = 23.511s
# time sess.run = 4.024s
# Epoch 1 - 195/393 : loss = 1.4435 - elapsed = 29.759s
# time sess.run = 4.296s
# Epoch 1 - 234/393 : loss = 1.4717 - elapsed = 35.628s
# time sess.run = 3.953s
# Epoch 1 - 273/393 : loss = 1.4909 - elapsed = 41.747s
# time sess.run = 4.170s
# Epoch 1 - 312/393 : loss = 1.5175 - elapsed = 47.748s
# time sess.run = 4.070s
# Epoch 1 - 351/393 : loss = 1.5346 - elapsed = 53.729s
# time sess.run = 4.050s
# Epoch 1 - 390/393 : loss = 1.5500 - elapsed = 59.704s
# time sess.run = 4.073s
# Epoch 2 - Test accuracy = 0.472
# Epoch 2 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 2 - 39/393 : loss = 0.9242 - elapsed = 5.863s
# time sess.run = 3.936s
# Epoch 2 - 78/393 : loss = 0.9170 - elapsed = 11.608s
# time sess.run = 3.826s
# Epoch 2 - 117/393 : loss = 0.9426 - elapsed = 17.567s
# time sess.run = 4.025s
# Epoch 2 - 156/393 : loss = 0.9593 - elapsed = 23.519s
# time sess.run = 4.020s
# Epoch 2 - 195/393 : loss = 0.9847 - elapsed = 29.321s
# time sess.run = 3.895s
# Epoch 2 - 234/393 : loss = 1.0033 - elapsed = 35.310s
# time sess.run = 4.045s
# Epoch 2 - 273/393 : loss = 1.0221 - elapsed = 40.997s
# time sess.run = 3.764s
# Epoch 2 - 312/393 : loss = 1.0409 - elapsed = 46.830s
# time sess.run = 3.882s
# Epoch 2 - 351/393 : loss = 1.0562 - elapsed = 52.573s
# time sess.run = 3.801s
# Epoch 2 - 390/393 : loss = 1.0760 - elapsed = 58.402s
# time sess.run = 3.929s
# Epoch 3 - Test accuracy = 0.488
# Epoch 3 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 3 - 39/393 : loss = 0.6900 - elapsed = 5.888s
# time sess.run = 3.976s
# Epoch 3 - 78/393 : loss = 0.7179 - elapsed = 11.734s
# time sess.run = 3.932s
# Epoch 3 - 117/393 : loss = 0.7238 - elapsed = 17.626s
# time sess.run = 3.962s
# Epoch 3 - 156/393 : loss = 0.7369 - elapsed = 23.363s
# time sess.run = 3.806s
# Epoch 3 - 195/393 : loss = 0.7599 - elapsed = 29.088s
# time sess.run = 3.767s
# Epoch 3 - 234/393 : loss = 0.7749 - elapsed = 34.649s
# time sess.run = 3.645s
# Epoch 3 - 273/393 : loss = 0.7896 - elapsed = 40.404s
# time sess.run = 3.817s
# Epoch 3 - 312/393 : loss = 0.8125 - elapsed = 46.177s
# time sess.run = 3.809s
# Epoch 3 - 351/393 : loss = 0.8281 - elapsed = 51.923s
# time sess.run = 3.805s
# Epoch 3 - 390/393 : loss = 0.8486 - elapsed = 57.667s
# time sess.run = 3.814s
# Epoch 4 - Test accuracy = 0.484
# Epoch 4 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 4 - 39/393 : loss = 0.6149 - elapsed = 5.682s
# time sess.run = 3.741s
# Epoch 4 - 78/393 : loss = 0.6080 - elapsed = 11.383s
# time sess.run = 3.760s
# Epoch 4 - 117/393 : loss = 0.6016 - elapsed = 17.189s
# time sess.run = 3.860s
# Epoch 4 - 156/393 : loss = 0.6119 - elapsed = 22.969s
# time sess.run = 3.801s
# Epoch 4 - 195/393 : loss = 0.6259 - elapsed = 28.766s
# time sess.run = 3.821s
# Epoch 4 - 234/393 : loss = 0.6442 - elapsed = 34.390s
# time sess.run = 3.674s
# Epoch 4 - 273/393 : loss = 0.6582 - elapsed = 40.373s
# time sess.run = 4.063s
# Epoch 4 - 312/393 : loss = 0.6771 - elapsed = 46.522s
# time sess.run = 4.214s
# Epoch 4 - 351/393 : loss = 0.6898 - elapsed = 52.206s
# time sess.run = 3.783s
# Epoch 4 - 390/393 : loss = 0.6990 - elapsed = 57.891s
# time sess.run = 3.785s
# Epoch 5 - Test accuracy = 0.487
# Epoch 5 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 5 - 39/393 : loss = 0.5025 - elapsed = 6.014s
# time sess.run = 4.035s
# Epoch 5 - 78/393 : loss = 0.5095 - elapsed = 12.130s
# time sess.run = 4.178s
# Epoch 5 - 117/393 : loss = 0.5311 - elapsed = 17.777s
# time sess.run = 3.739s
# Epoch 5 - 156/393 : loss = 0.5308 - elapsed = 23.400s
# time sess.run = 3.668s
# Epoch 5 - 195/393 : loss = 0.5426 - elapsed = 29.026s
# time sess.run = 3.692s
# Epoch 5 - 234/393 : loss = 0.5464 - elapsed = 34.787s
# time sess.run = 3.824s
# Epoch 5 - 273/393 : loss = 0.5574 - elapsed = 41.086s
# time sess.run = 4.350s
# Epoch 5 - 312/393 : loss = 0.5757 - elapsed = 47.533s
# time sess.run = 4.501s
# Epoch 5 - 351/393 : loss = 0.5897 - elapsed = 53.833s
# time sess.run = 4.368s
# Epoch 5 - 390/393 : loss = 0.6017 - elapsed = 60.131s
# time sess.run = 4.322s
# Epoch 6 - Test accuracy = 0.495
# Epoch 6 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 6 - 39/393 : loss = 0.4449 - elapsed = 6.105s
# time sess.run = 4.170s
# Epoch 6 - 78/393 : loss = 0.4384 - elapsed = 11.870s
# time sess.run = 3.892s
# Epoch 6 - 117/393 : loss = 0.4437 - elapsed = 17.463s
# time sess.run = 3.676s
# Epoch 6 - 156/393 : loss = 0.4507 - elapsed = 23.114s
# time sess.run = 3.724s
# Epoch 6 - 195/393 : loss = 0.4543 - elapsed = 28.936s
# time sess.run = 3.871s
# Epoch 6 - 234/393 : loss = 0.4619 - elapsed = 34.936s
# time sess.run = 4.039s
# Epoch 6 - 273/393 : loss = 0.4735 - elapsed = 41.094s
# time sess.run = 4.197s
# Epoch 6 - 312/393 : loss = 0.4947 - elapsed = 47.262s
# time sess.run = 4.230s
# Epoch 6 - 351/393 : loss = 0.5133 - elapsed = 53.373s
# time sess.run = 4.193s
# Epoch 6 - 390/393 : loss = 0.5221 - elapsed = 59.351s
# time sess.run = 4.040s
# Epoch 7 - Test accuracy = 0.490
# Epoch 7 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 7 - 39/393 : loss = 0.3884 - elapsed = 5.806s
# time sess.run = 3.875s
# Epoch 7 - 78/393 : loss = 0.3828 - elapsed = 11.431s
# time sess.run = 3.669s
# Epoch 7 - 117/393 : loss = 0.3841 - elapsed = 17.118s
# time sess.run = 3.745s
# Epoch 7 - 156/393 : loss = 0.3961 - elapsed = 22.831s
# time sess.run = 3.755s
# Epoch 7 - 195/393 : loss = 0.4111 - elapsed = 28.582s
# time sess.run = 3.814s
# Epoch 7 - 234/393 : loss = 0.4187 - elapsed = 34.167s
# time sess.run = 3.669s
# Epoch 7 - 273/393 : loss = 0.4319 - elapsed = 39.870s
# time sess.run = 3.777s
# Epoch 7 - 312/393 : loss = 0.4467 - elapsed = 45.503s
# time sess.run = 3.734s
# Epoch 7 - 351/393 : loss = 0.4507 - elapsed = 51.279s
# time sess.run = 3.861s
# Epoch 7 - 390/393 : loss = 0.4609 - elapsed = 56.958s
# time sess.run = 3.701s
# Epoch 8 - Test accuracy = 0.500
# Epoch 8 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 8 - 39/393 : loss = 0.3254 - elapsed = 5.606s
# time sess.run = 3.687s
# Epoch 8 - 78/393 : loss = 0.3474 - elapsed = 11.177s
# time sess.run = 3.656s
# Epoch 8 - 117/393 : loss = 0.3499 - elapsed = 16.842s
# time sess.run = 3.744s
# Epoch 8 - 156/393 : loss = 0.3548 - elapsed = 22.559s
# time sess.run = 3.776s
# Epoch 8 - 195/393 : loss = 0.3647 - elapsed = 28.486s
# time sess.run = 3.986s
# Epoch 8 - 234/393 : loss = 0.3746 - elapsed = 34.634s
# time sess.run = 4.224s
# Epoch 8 - 273/393 : loss = 0.3873 - elapsed = 40.542s
# time sess.run = 3.975s
# Epoch 8 - 312/393 : loss = 0.4028 - elapsed = 46.272s
# time sess.run = 3.818s
# Epoch 8 - 351/393 : loss = 0.4177 - elapsed = 51.927s
# time sess.run = 3.726s
# Epoch 8 - 390/393 : loss = 0.4261 - elapsed = 57.598s
# time sess.run = 3.714s
# Epoch 9 - Test accuracy = 0.498
# Epoch 9 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 9 - 39/393 : loss = 0.3001 - elapsed = 5.907s
# time sess.run = 3.953s
# Epoch 9 - 78/393 : loss = 0.3073 - elapsed = 12.161s
# time sess.run = 4.264s
# Epoch 9 - 117/393 : loss = 0.3285 - elapsed = 18.214s
# time sess.run = 4.096s
# Epoch 9 - 156/393 : loss = 0.3382 - elapsed = 23.897s
# time sess.run = 3.730s
# Epoch 9 - 195/393 : loss = 0.3536 - elapsed = 29.883s
# time sess.run = 4.024s
# Epoch 9 - 234/393 : loss = 0.3589 - elapsed = 35.699s
# time sess.run = 3.839s
# Epoch 9 - 273/393 : loss = 0.3671 - elapsed = 41.848s
# time sess.run = 4.201s
# Epoch 9 - 312/393 : loss = 0.3736 - elapsed = 47.969s
# time sess.run = 4.146s
# Epoch 9 - 351/393 : loss = 0.3806 - elapsed = 54.059s
# time sess.run = 4.134s
# Epoch 9 - 390/393 : loss = 0.3880 - elapsed = 60.096s
# time sess.run = 4.086s
# Epoch 10 - Test accuracy = 0.497
# Epoch 10 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 10 - 39/393 : loss = 0.2651 - elapsed = 6.019s
# time sess.run = 4.088s
# Epoch 10 - 78/393 : loss = 0.2709 - elapsed = 11.749s
# time sess.run = 3.763s
# Epoch 10 - 117/393 : loss = 0.2755 - elapsed = 17.413s
# time sess.run = 3.702s
# Epoch 10 - 156/393 : loss = 0.2918 - elapsed = 23.376s
# time sess.run = 4.012s
# Epoch 10 - 195/393 : loss = 0.2961 - elapsed = 29.444s
# time sess.run = 4.120s
# Epoch 10 - 234/393 : loss = 0.3095 - elapsed = 35.490s
# time sess.run = 4.107s
# Epoch 10 - 273/393 : loss = 0.3207 - elapsed = 41.331s
# time sess.run = 3.877s
# Epoch 10 - 312/393 : loss = 0.3268 - elapsed = 47.174s
# time sess.run = 3.877s
# Epoch 10 - 351/393 : loss = 0.3373 - elapsed = 52.946s
# time sess.run = 3.806s
# Epoch 10 - 390/393 : loss = 0.3512 - elapsed = 58.737s
# time sess.run = 3.831s
# Epoch 11 - Test accuracy = 0.502
# Epoch 11 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 11 - 39/393 : loss = 0.2884 - elapsed = 5.726s
# time sess.run = 3.774s
# Epoch 11 - 78/393 : loss = 0.2894 - elapsed = 11.685s
# time sess.run = 4.056s
# Epoch 11 - 117/393 : loss = 0.2864 - elapsed = 17.607s
# time sess.run = 4.004s
# Epoch 11 - 156/393 : loss = 0.2871 - elapsed = 23.441s
# time sess.run = 3.895s
# Epoch 11 - 195/393 : loss = 0.2929 - elapsed = 29.405s
# time sess.run = 4.032s
# Epoch 11 - 234/393 : loss = 0.3033 - elapsed = 35.258s
# time sess.run = 3.923s
# Epoch 11 - 273/393 : loss = 0.3154 - elapsed = 41.158s
# time sess.run = 3.955s
# Epoch 11 - 312/393 : loss = 0.3196 - elapsed = 47.052s
# time sess.run = 3.926s
# Epoch 11 - 351/393 : loss = 0.3230 - elapsed = 52.856s
# time sess.run = 3.861s
# Epoch 11 - 390/393 : loss = 0.3323 - elapsed = 58.928s
# time sess.run = 4.143s
# Epoch 12 - Test accuracy = 0.498
# Epoch 12 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 12 - 39/393 : loss = 0.3103 - elapsed = 5.905s
# time sess.run = 3.991s
# Epoch 12 - 78/393 : loss = 0.2890 - elapsed = 11.928s
# time sess.run = 4.054s
# Epoch 12 - 117/393 : loss = 0.2751 - elapsed = 17.652s
# time sess.run = 3.768s
# Epoch 12 - 156/393 : loss = 0.2803 - elapsed = 23.313s
# time sess.run = 3.714s
# Epoch 12 - 195/393 : loss = 0.2794 - elapsed = 29.201s
# time sess.run = 3.914s
# Epoch 12 - 234/393 : loss = 0.2813 - elapsed = 35.289s
# time sess.run = 4.121s
# Epoch 12 - 273/393 : loss = 0.2943 - elapsed = 41.266s
# time sess.run = 4.057s
# Epoch 12 - 312/393 : loss = 0.2978 - elapsed = 47.221s
# time sess.run = 4.031s
# Epoch 12 - 351/393 : loss = 0.3031 - elapsed = 52.953s
# time sess.run = 3.835s
# Epoch 12 - 390/393 : loss = 0.3101 - elapsed = 58.777s
# time sess.run = 3.925s
# Epoch 13 - Test accuracy = 0.505
# Epoch 13 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 13 - 39/393 : loss = 0.2359 - elapsed = 6.107s
# time sess.run = 4.160s
# Epoch 13 - 78/393 : loss = 0.2259 - elapsed = 12.108s
# time sess.run = 4.085s
# Epoch 13 - 117/393 : loss = 0.2266 - elapsed = 17.848s
# time sess.run = 3.833s
# Epoch 13 - 156/393 : loss = 0.2280 - elapsed = 23.714s
# time sess.run = 3.929s
# Epoch 13 - 195/393 : loss = 0.2325 - elapsed = 29.622s
# time sess.run = 3.965s
# Epoch 13 - 234/393 : loss = 0.2366 - elapsed = 35.527s
# time sess.run = 3.975s
# Epoch 13 - 273/393 : loss = 0.2446 - elapsed = 41.299s
# time sess.run = 3.797s
# Epoch 13 - 312/393 : loss = 0.2570 - elapsed = 47.122s
# time sess.run = 3.863s
# Epoch 13 - 351/393 : loss = 0.2657 - elapsed = 52.998s
# time sess.run = 3.896s
# Epoch 13 - 390/393 : loss = 0.2711 - elapsed = 58.738s
# time sess.run = 3.778s
# Epoch 14 - Test accuracy = 0.500
# Epoch 14 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 14 - 39/393 : loss = 0.2319 - elapsed = 5.676s
# time sess.run = 3.769s
# Epoch 14 - 78/393 : loss = 0.2175 - elapsed = 11.555s
# time sess.run = 3.909s
# Epoch 14 - 117/393 : loss = 0.2132 - elapsed = 17.594s
# time sess.run = 4.074s
# Epoch 14 - 156/393 : loss = 0.2151 - elapsed = 23.770s
# time sess.run = 4.189s
# Epoch 14 - 195/393 : loss = 0.2176 - elapsed = 29.971s
# time sess.run = 4.258s
# Epoch 14 - 234/393 : loss = 0.2294 - elapsed = 36.059s
# time sess.run = 4.120s
# Epoch 14 - 273/393 : loss = 0.2363 - elapsed = 41.872s
# time sess.run = 3.901s
# Epoch 14 - 312/393 : loss = 0.2430 - elapsed = 47.847s
# time sess.run = 4.025s
# Epoch 14 - 351/393 : loss = 0.2510 - elapsed = 53.877s
# time sess.run = 4.055s
# Epoch 14 - 390/393 : loss = 0.2617 - elapsed = 59.652s
# time sess.run = 3.819s
# Epoch 15 - Test accuracy = 0.495
# Epoch 15 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 15 - 39/393 : loss = 0.2368 - elapsed = 5.634s
# time sess.run = 3.682s
# Epoch 15 - 78/393 : loss = 0.2450 - elapsed = 11.441s
# time sess.run = 3.842s
# Epoch 15 - 117/393 : loss = 0.2375 - elapsed = 17.205s
# time sess.run = 3.808s
# Epoch 15 - 156/393 : loss = 0.2457 - elapsed = 23.078s
# time sess.run = 3.906s
# Epoch 15 - 195/393 : loss = 0.2531 - elapsed = 28.999s
# time sess.run = 3.983s
# Epoch 15 - 234/393 : loss = 0.2569 - elapsed = 34.831s
# time sess.run = 3.880s
# Epoch 15 - 273/393 : loss = 0.2587 - elapsed = 40.938s
# time sess.run = 4.122s
# Epoch 15 - 312/393 : loss = 0.2592 - elapsed = 47.010s
# time sess.run = 4.132s
# Epoch 15 - 351/393 : loss = 0.2634 - elapsed = 53.275s
# time sess.run = 4.295s
# Epoch 15 - 390/393 : loss = 0.2711 - elapsed = 59.315s
# time sess.run = 4.096s
# Epoch 16 - Test accuracy = 0.503
# Epoch 16 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 16 - 39/393 : loss = 0.1881 - elapsed = 5.957s
# time sess.run = 4.027s
# Epoch 16 - 78/393 : loss = 0.2212 - elapsed = 12.182s
# time sess.run = 4.310s
# Epoch 16 - 117/393 : loss = 0.2421 - elapsed = 18.119s
# time sess.run = 4.011s
# Epoch 16 - 156/393 : loss = 0.2432 - elapsed = 24.046s
# time sess.run = 3.951s
# Epoch 16 - 195/393 : loss = 0.2498 - elapsed = 29.949s
# time sess.run = 3.940s
# Epoch 16 - 234/393 : loss = 0.2511 - elapsed = 35.720s
# time sess.run = 3.849s
# Epoch 16 - 273/393 : loss = 0.2559 - elapsed = 41.799s
# time sess.run = 4.135s
# Epoch 16 - 312/393 : loss = 0.2620 - elapsed = 47.864s
# time sess.run = 4.128s
# Epoch 16 - 351/393 : loss = 0.2697 - elapsed = 53.903s
# time sess.run = 4.081s
# Epoch 16 - 390/393 : loss = 0.2760 - elapsed = 59.937s
# time sess.run = 4.113s
# Epoch 17 - Test accuracy = 0.497
# Epoch 17 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 17 - 39/393 : loss = 0.2361 - elapsed = 6.073s
# time sess.run = 4.109s
# Epoch 17 - 78/393 : loss = 0.2033 - elapsed = 11.836s
# time sess.run = 3.841s
# Epoch 17 - 117/393 : loss = 0.1993 - elapsed = 17.692s
# time sess.run = 3.884s
# Epoch 17 - 156/393 : loss = 0.1989 - elapsed = 23.658s
# time sess.run = 4.007s
# Epoch 17 - 195/393 : loss = 0.2011 - elapsed = 29.834s
# time sess.run = 4.248s
# Epoch 17 - 234/393 : loss = 0.2047 - elapsed = 35.920s
# time sess.run = 4.158s
# Epoch 17 - 273/393 : loss = 0.2120 - elapsed = 41.842s
# time sess.run = 4.002s
# Epoch 17 - 312/393 : loss = 0.2199 - elapsed = 47.691s
# time sess.run = 3.910s
# Epoch 17 - 351/393 : loss = 0.2256 - elapsed = 53.579s
# time sess.run = 3.911s
# Epoch 17 - 390/393 : loss = 0.2325 - elapsed = 59.329s
# time sess.run = 3.794s
# Epoch 18 - Test accuracy = 0.498
# Epoch 18 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 18 - 39/393 : loss = 0.1801 - elapsed = 5.710s
# time sess.run = 3.760s
# Epoch 18 - 78/393 : loss = 0.1778 - elapsed = 11.695s
# time sess.run = 4.054s
# Epoch 18 - 117/393 : loss = 0.1829 - elapsed = 17.782s
# time sess.run = 4.127s
# Epoch 18 - 156/393 : loss = 0.1928 - elapsed = 23.955s
# time sess.run = 4.225s
# Epoch 18 - 195/393 : loss = 0.1928 - elapsed = 30.155s
# time sess.run = 4.240s
# Epoch 18 - 234/393 : loss = 0.2033 - elapsed = 36.302s
# time sess.run = 4.207s
# Epoch 18 - 273/393 : loss = 0.2101 - elapsed = 42.402s
# time sess.run = 4.175s
# Epoch 18 - 312/393 : loss = 0.2129 - elapsed = 48.377s
# time sess.run = 4.067s
# Epoch 18 - 351/393 : loss = 0.2216 - elapsed = 54.184s
# time sess.run = 3.846s
# Epoch 18 - 390/393 : loss = 0.2296 - elapsed = 60.081s
# time sess.run = 3.952s
# Epoch 19 - Test accuracy = 0.499
# Epoch 19 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 19 - 39/393 : loss = 0.1909 - elapsed = 5.813s
# time sess.run = 3.838s
# Epoch 19 - 78/393 : loss = 0.1907 - elapsed = 11.921s
# time sess.run = 4.113s
# Epoch 19 - 117/393 : loss = 0.1918 - elapsed = 17.780s
# time sess.run = 3.880s
# Epoch 19 - 156/393 : loss = 0.1977 - elapsed = 23.873s
# time sess.run = 4.127s
# Epoch 19 - 195/393 : loss = 0.2080 - elapsed = 29.910s
# time sess.run = 4.070s
# Epoch 19 - 234/393 : loss = 0.2082 - elapsed = 36.011s
# time sess.run = 4.145s
# Epoch 19 - 273/393 : loss = 0.2376 - elapsed = 42.168s
# time sess.run = 4.191s
# Epoch 19 - 312/393 : loss = 0.2458 - elapsed = 48.209s
# time sess.run = 4.088s
# Epoch 19 - 351/393 : loss = 0.2527 - elapsed = 54.153s
# time sess.run = 3.983s
# Epoch 19 - 390/393 : loss = 0.2587 - elapsed = 59.966s
# time sess.run = 3.872s
# Epoch 20 - Test accuracy = 0.501
# Epoch 20 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 20 - 39/393 : loss = 0.2103 - elapsed = 5.968s
# time sess.run = 3.999s
# Epoch 20 - 78/393 : loss = 0.2033 - elapsed = 11.842s
# time sess.run = 3.910s
# Epoch 20 - 117/393 : loss = 0.2032 - elapsed = 17.956s
# time sess.run = 4.161s
# Epoch 20 - 156/393 : loss = 0.2096 - elapsed = 24.038s
# time sess.run = 4.166s
# Epoch 20 - 195/393 : loss = 0.2097 - elapsed = 30.021s
# time sess.run = 4.080s
# Epoch 20 - 234/393 : loss = 0.2166 - elapsed = 36.056s
# time sess.run = 4.147s
# Epoch 20 - 273/393 : loss = 0.2227 - elapsed = 42.159s
# time sess.run = 4.170s
# Epoch 20 - 312/393 : loss = 0.2240 - elapsed = 48.394s
# time sess.run = 4.274s
# Epoch 20 - 351/393 : loss = 0.2275 - elapsed = 54.562s
# time sess.run = 4.235s
# Epoch 20 - 390/393 : loss = 0.2298 - elapsed = 60.659s
# time sess.run = 4.175s
# Epoch 21 - Test accuracy = 0.504
# Epoch 21 - 0/393 : loss = nan - elapsed = 0.000s
# time sess.run = 0.000s
# Epoch 21 - 39/393 : loss = 0.1726 - elapsed = 6.034s
# time sess.run = 4.094s
# Epoch 21 - 78/393 : loss = 0.1779 - elapsed = 11.948s
# time sess.run = 4.021s
# Epoch 21 - 117/393 : loss = 0.1726 - elapsed = 18.084s
# time sess.run = 4.212s
# Epoch 21 - 156/393 : loss = 0.1762 - elapsed = 24.012s
# time sess.run = 3.995s
# Epoch 21 - 195/393 : loss = 0.1752 - elapsed = 29.904s
# time sess.run = 3.957s
# Epoch 21 - 234/393 : loss = 0.1795 - elapsed = 35.916s
# time sess.run = 4.076s
# Epoch 21 - 273/393 : loss = 0.1867 - elapsed = 41.840s
# time sess.run = 4.002s
# Epoch 21 - 312/393 : loss = 0.1921 - elapsed = 47.705s
# time sess.run = 3.982s
# Epoch 21 - 351/393 : loss = 0.1979 - elapsed = 53.968s
# time sess.run = 4.345s
# Epoch 21 - 390/393 : loss = 0.2035 - elapsed = 60.155s
# time sess.run = 4.246s
# Epoch 22 - Test accuracy = 0.501
# EARLY STOPPING

# %%
H['max_test_acc'] = max_test_acc
with open(join(root_path, model_name, 'hyperparams'),'w') as f:
    for h in H:
        f.write("%s = %s\n" % (h, str(H[h])))
    f.write('\n\nMaximal test accuracy = %1.4f\n' % max_test_acc)
